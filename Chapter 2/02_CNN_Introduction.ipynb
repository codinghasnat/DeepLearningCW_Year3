# %% [markdown]
# <a href="https://colab.research.google.com/github/MatchLab-Imperial/deep-learning-course/blob/master/02_CNN_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Convolutional Neural Networks
#
# This tutorial addresses the basic concepts regarding Convolutional Neural Networks and their implementation using the Keras framework.
# Convolutional Neural Networks (CNNs) are a class of feed-forward artificial neural architecture. They are applied to analyse visual 2D imagery, meaning that we can feed images directly into a CNN without the need to flatten them into a 1D vector as done in the previous tutorial.
# CNNs have revolutionised the field of computer vision in the last decade. In 2012 Alex Krizhevsky introduced the AlexNet architecture to win the ImageNet Challenge (one of the most important competitions on image classification within the Computer Vision community), by reducing the top-5 error more than 10 percentage points, which was an incredible improvement at that time. As of now, CNNs are used not only on image classification but in many other computer vision tasks.
#
# ![](https://cdn-5f733ed3c1ac190fbc56ef88.closte.com/wp-content/uploads/2017/03/alexnet_small-1.png)
#
# The image above is from [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/) and shows the proposed AlexNet architecture. It is composed of 5 convolutional layers followed by 3 fully connected layers. Nowadays, we can find much deeper and more complex architectures, which outperform AlexNet on the ImageNet Challenge.

# %% [markdown]
# ## CNN Structure
#
# The basic pipeline of common CNNs consists of an image as input and a stack of convolutional layers that extract a feature representation from the input image. The final shape of the image representation is conditioned on the type of problem/task that the architecture is facing. For instance, the output of the last layer in a classification problem is a probability vector. Each dimension of the probability vector represents how likely is that the input image belongs to a specific class. However, the architecture design is up to us, and therefore, we could code a network that outputs a single value for regression problems, or that generates a new image map for semantic segmentation. Now, let's dig in a bit into CNN and introduce some layers that are widely used.

# %% [markdown]
# ### 2D Convolutional Layer
#
# The most common layer in any CNN architecture is the 2D convolutional layer. Convolutional layers are specifically designed to extract features from images or even extract features from previously extracted features. As shown in the following illustration, 2D convolutions apply the same filter to the full image. And therefore, due to its nature, 2D convolutional filters exploit the local information presented in images, making them a powerful tool for image analysis.
#
# ![](https://cdn-images-1.medium.com/max/800/1*Fw-ehcNBR9byHtho-Rxbtw.gif)
#
# Image [source](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1).
#
# The latest deep learning frameworks have made possible the integration of convolutional layers easily on our architectures with only a single line of code. We will address here how 2D convolutions work since full understanding is needed to comprehend how any CNN operates. The following images and some explanations can be further explored on the original [Irhum Shafkat's blog](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1) or in the [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/) book. Both are strongly recommended.
#
# To understand 2D convolutions, we need to define first what a kernel is. Kernels are simply matrices of numbers. The numbers on the kernels are the so-called weights, and the weights on the kernels change as we train the network. Hence, network training aims to optimise the network's parameters (update the kernel weights) such that the cost function is minimised.
#
# The 2D convolution operation takes the network's kernels and "slides" them over the input image (alike to a sliding window) as in the following image from [PyImageSearch](https://www.pyimagesearch.com/2015/03/23/sliding-windows-for-object-detection-with-python-and-opencv/) blog:
#
# ![](https://pyimagesearch.com/wp-content/uploads/2014/10/sliding_window_example.gif)
#
# In each step, the network performs an element-wise multiplication with the elements that are currently on. The results of this elementwise multiplication are added to obtain the output value of the operation. CNNs repeat previous step for all the positions of the sliding window, composing at the end the feature map. This generated feature map can go through another 2D convolutional layer and create more powerful features.
#
# >
#
# ![](https://cdn-images-1.medium.com/max/800/1*Zx-ZMLKab7VOCQTxdZ1OAw.gif)
#
# >
# The previous image shows the 2D convolution operation. Thus, the new feature values are the weighted sum of all the elements in the sliding window after the elementwise multiplication between input and kernel.  The bigger the size of the kernel is, the more feature elements contribute to the final output value. In contrast to fully connected layers, where a new feature value is a weighted sum over **all** input values, as mentioned, 2D convolutions compute features based on local areas. In other words, instead of looking at every input component, they consider only features coming from close locations.
#
# In the above example, the input image on the left has a size of 5x5 and the dimension of the resulting feature map is 3x3, showing that the size of the output maps is not always equal to the input. Hence, the output size can be computed by doing:
#
# $O = W - K + 1$,
#
# where $O$ is the output height/length, $W$ is the input height/length and $K$ is the kernel size. The output size is not only conditioned on the input size but also on the kernel size. Check in the following code cell how the output feature map shape changes as you increase the kernel size. In Keras, we define the layer by using `Conv2D` from `keras.layers` (documentation [here](https://keras.io/layers/convolutional/#conv2d)).

# %%
#Conv2D: Convolutional Layer 2d images.
#Dense : Fully connected layers
#Flatten, makes 1D array.
#Shape (Items, (number of parameters))
  #Reshape makes it standard size and ready for dissection
  #We divide by 255 to standardise.

#Sequential: The layers are going to be stacked up in the sequence
model = Sequential([
  Conv2D( NumberOfFilters, (3,3), activation = 'relu', input_shape = (100,100,3)) #3,3 represents the size of the filters we want to use, height width. (100,100) Our input is expecting a 100x100 input shape.RGB
  MaxPoolin2D((2,2)),
  Conv2D( NumberOfFilters, (3,3), activation = 'relu'), #3,3 represents the size of the filters we want to use, height width. (100,100) Our input is expecting a 100x100 input shape.RGB
  MaxPoolin2D((2,2)),
  Flatten(),
  Dense(64, activation = 'relu') #First Fully Connected Layer, 64 Neurons.
  Dense(1, activation = "sigmoid") #Final Fully Connected Layer, binary classification layer.
])

#OR add layers to the empty sequential model.

model = Sequential()
model.add(Conv2D( NumberOfFilters, (3,3), activation = 'relu', input_shape = (100,100,3))) #3,3 represents the size of the filters we want to use, height width. (100,100) Our input is expecting a 100x100 input shape.RGB
model.add(MaxPoolin2D((2,2))),
model.add(Conv2D( NumberOfFilters, (3,3), activation = 'relu')), #3,3 represents the size of the filters we want to use, height width. (100,100) Our input is expecting a 100x100 input shape.RGB
model.add(MaxPoolin2D((2,2))),
model.add(Flatten()),
model.add(Dense(64, activation = 'relu')), #First Fully Connected Layer, 64 Neurons.
model.add(Dense(1, activation = "sigmoid")) #Final Fully Connected Layer, binary classification layer.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential #
from keras.layers import Conv2D #Convolutional Layer 2d images.
#Dense : Fully connected layers
#Flatten, makes 

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1)))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))

# %% [markdown]
# Moreover, the kernel size and the input size are not the only parameters affecting the output size. We are going to introduce two extra elements that change the size of the output map: the padding and the stride.

# %% [markdown]
# ### Adding Padding to Input Features
#
# In some tasks, such as [image translation](https://arxiv.org/pdf/1611.07004.pdf), we need the output size to be equal to the input size. The solution to that is using padding, where extra edges are added to the input features so that the dimension is not reduced after the convolutional layer. Normally those pixels have $0$ value (termed zero-padding), but depending on the application other methods could be used, e.g., reflection or symmetric padding.
#
# ![](https://cdn-images-1.medium.com/max/800/1*1okwhewf5KCtIPaFib4XaA.gif)
#
# If padding is used, the new output size can be computed by doing:
#
# $O = W - K + 2P+ 1$,
#
# where $P$ is the padding value. $P$ must be set in concordance with the kernel size if dimensionality wants to be preserved. Padding can be added to the `Conv2d` layer in Keras by using the padding argument and selecting one of the two settings: `valid`, which is the default value and means no padding; and `same`, which adapts the padding value to have the same output size as input size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))

# %% [markdown]
# ### Using Stride in Convolutional Layers
#
# The stride operation allows the convolutional layers to skip some of the sliding windows explained above. Hence, instead of jumping one pixel apart, we can define the number of skipped elements before computing the weighting sum between the kernel's weights and input features. A stride of 1 means that features will be extracted from all windows a pixel apart, so basically, every single window is computed. A stride of 2 means that we are selecting windows 2 pixels apart, skipping every other window in the process. Strides reduce the number of computations and consequently the size of the output map. In practice, as we go deeper into the CNN, the spatial size of the feature map gets smaller while the number of channels increases. Moreover, we can further reduce the size of the feature map using pooling operations, which we introduce later in this tutorial.
#
# ![](https://cdn-images-1.medium.com/max/800/1*BMngs93_rm2_BpJFH2mS0Q.gif)
#
# If strides are used, the new output size can be computed as:
#
# $O = \dfrac{W - K + 2P}{S}+ 1$,
#
# where $S$ is the stride value. The stride is set in the layer by using the `strides` argument.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))

# %% [markdown]
# ## Differences Between Kernel and Filters
#
# The examples above take as input a single-channel image and compute a feature map with also one channel. However, when dealing with RGB images or feature maps, the input is no longer a single-channel map but, instead, they can have multiple channels. In the case of an RGB image, for each 2D convolution, we will need to define 3 kernels to interact with each of the image's channel colours. This group of kernels is called a filter. Thus, a filter is a collection of kernels that produces a single output.
#
# As a regular practice when defining Deep Learning models, we increase the number of filters in each convolutional layer as we go deeper into the model. Due to the element-wise multiplication, the number of kernels on each filter must be the same that the number of channels in the input feature map. Keras already deals with the number of kernels inside each filter. Keras keeps track of the input size in each convolutional layer unlike other frameworks (Pytorch or TensorFlow). Hence, in Keras, we must only decide the number of filters (output channels) in each layer.
#
# The next figure shows how the convolution is performed when having three input channels. First, one filter uses its three independent kernels to convolve with the RGB channels of the input image:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*8dx6nxpUh2JqvYWPadTwMQ.gif)
#
# Next, each of the processed feature maps is added together to obtain a single channel:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*CYB2dyR3EhFs1xNLK8ewiA.gif)
#
# Finally, we add the bias term to obtain the feature map. There is a single bias for the full output channel map. This operation is repeated for all the filters inside the convolutional layer.
#
# Now, we show how to use a `Conv2D` layer that takes an input image with 3 channels and generates an output map with 32 channels.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))

# %% [markdown]
# ## Activation Functions
#
# As seen in previous tutorials, after a `Dense` layer we usually can find an activation function. We introduce here how to use them after `Conv2D` layers. Those activation functions are a set of operators that maps the feature values to a new set of values, the mapping depends on the function at hand. The main reason for using activation functions is that they add non-linearities to the network, giving more expressive power to the network, which will be able to reproduce more complex functions.
#
#
# The complete list of activation functions that Keras offers can be found [here](https://keras.io/activations/). We introduce here some of them:
#
# *  **Sigmoid Function** sets the output in the range (0, 1). The sigmoid function is widely used in binary classification problems since its output can be taken as a probability value. `keras.activations.sigmoid(x)`:
#
# >![](https://i.ibb.co/Ph8dsTv/sigmoid.png)
#
# *  **Tanh Function** is a logistic function as sigmoid, but the range of the tanh function is (-1, 1). Contrary to sigmoid function, where the values close to 0 are set around 0.5, in the tanh function they will be still mapped around the 0 value. `keras.activations.tanh(x)`:
#
# >![](https://i.ibb.co/68g7LpL/tanh.png)
#
# *  **ReLU Function** is the most common activation function you can find in any current CNN as in general works better than the rest. The range of this function is in \[0, inf). It sets all negative values to 0 and hence is computationally easy to implement. As a drawback, during training some neurons *die*, meaning that the output is 0 for all available data points and no gradient is propagated there. `keras.activations.relu(x, alpha=0.0, max_value=None, threshold=0.0)`:
#
# >![](https://i.ibb.co/Zd9H8Z4/relu.png)
#
# *  **LeakyReLU Function** is a modified version of the ReLU activation above, which attempts to solve the problem of dying neurons that ReLU has. While ReLU does not backpropagate negative values, Leaky ReLU smooths those values without setting them to 0. That allows the gradients to backpropagate through the network even for negative values. `keras.layers.LeakyReLU(alpha=0.3)`:
#
# >![](https://i.ibb.co/dmnJ6h1/leakyrelu.png)
#
# *  **Softmax Function** is another widely activation function for multi-class classification problems and usually is employed as the last activation function in the classification model. This function sets all of the output elements to the range (0, 1). However, the softmax function does not take independently the input values to map it into its probability value. Softmax Function takes an un-normalized vector, $s$, and normalizes it into a probability distribution, $p$, following the softmax expression. As the output is a probability, the output elements add up to 1. `keras.activations.softmax(x, axis=-1)`. Thus, the output value $p_i$ is computed as:
#
# > $p_{i} = \dfrac{e^{s_i}}{\sum_{\substack{j}}^{N} e^{s_j}}$

# %% [markdown]
# The following example shows the feature maps before and after of the ReLU activation function. All values that are negative are set to 0 after the activation function.

# %%
import numpy as np
import keras
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential, Model
from keras.layers import Conv2D, Activation

# Generate dummy data
input_feature = np.random.random((1, 3, 3, 1)) - 0.5

# input: 3x3 image with 1 channel -> (3, 3, 1) tensor.
# This applies a 1 convolution filter of size 3x3 each.
# This applies a ReLU activation function
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(3, 3, 1), padding='same', strides=1, name='conv'))
model.add(Activation('relu'))

model_before_ReLU = Model(inputs=model.input, outputs=model.get_layer('conv').output)

output_feature = model_before_ReLU.predict(input_feature)
output_ReLu_feature = model.predict(input_feature)

print('Output Network without activation function')
print(output_feature)

print('')
print('Output Network after ReLU activation function')
print(output_ReLu_feature)

# %% [markdown]
# ## Pooling Layer
#
# It is a common practice to insert a pooling layer between convolutional layers in CNNs. In a standard CNN architecture, we set the feature sizes to become smaller progressively to reduce the computation in the networks, and to merge the information from different spatial locations. To reduce the feature map sizes, we can either use bigger stride size in the convolutional layers or we can use pooling layers. Pooling layers perform a spatial sliding window and apply an operation to reduce the spatial size. Those operations vary depending on the architecture, being the max, mean and min pooling the most typical ones. Here, we will explain the max pooling, although all the others work similarly. Max pooling keeps only the max value in a neighbourhood, where the neighbourhood is defined by the size of the kernel. Let's visualise it, the next example shows the result of a Max Pooling layer with a 2x2 kernel and a stride of 2.
#
# ![](https://i.ibb.co/Xp454S4/MaxPool.png)
#
# As in convolutional layers, the final size is conditioned to the stride size of the pooling layer. However, contrary to convolutional layers, pooling layers operate independently on each of the input channels, without modifying the depth of the feature maps. To add max pooling to our model we need to import `MaxPooling2d` from `keras.layers` and define the stride and pooling size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=1 applies applies stride of 1
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))

# %% [markdown]
# # Example: Classification on MNIST
#
# As opposed to the *Introduction to Keras* tutorial, in this section, we show how to perform image classification when the input data is a 2D image instead of a flat 1D vector.
#
# As discussed above, Convolutional Neural Networks aim to extract and exploit the local relationships on 2D maps, hence, CNNs are much more convenient for images than Multi-layer Perceptron models.
#
# First of all, we load the MNIST dataset from Keras' framework. The definition of the data is almost identical than in the Keras tutorial, although this time we are not reshaping the input images into a 1D vector.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, BatchNormalization
from keras.utils import np_utils
from keras.datasets import mnist
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten
import numpy as np

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = mnist.load_data()

shape = x_train.shape

# Normalize and reshape the input images
x_train = np.expand_dims(x_train.astype('float32'), -1)
x_test = np.expand_dims(x_test.astype('float32'), -1)

x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

# %% [markdown]
# As illustrated in the cell, this time the input image before the model is 28x28x1.
#
# Now we can define a model composed of convolutional layers, activation functions, and maxpool operators:

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# As explained in the previous tutorial, in a classification problem, the output of the model is a probability vector. Each dimension of the vector indicates how likely is that the input image belongs to a specific class.
#
# Up to now, the resulting feature map of the model is a map with the shape *Batch x Weight' x Height' x Channel*, and it needs to be mapped into a vector with shape *Batch x Num Classes*. A common technique to process this mapping is to add a Flatten layer that will reshape the feature map to *Batch x (Weight' * Height' * Channel)*. Following the Flatten layer, we add a dense layer which maps this new feature map to the desired output size.

# %%
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# %% [markdown]
# Let's visualize the output shape in each layer.

# %%
model.summary()

# %% [markdown]
# Finally, we can train our CNN and check its performance on MNIST.

# %%
# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=10,  verbose=0)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

# %% [markdown]
# # Coursework

# %% [markdown]
# ## Task 1: Classification
#
# At this point, we know what is a CNN, how they work, and the components needed to design them. In this first task, we want you to create a CNN that is able to outperform the Multi-layer Perceptron model from Tutorial 1. For the first part of the coursework, we train on CIFAR10, a  classical dataset for image classification. Note that in these tutorials, we mainly use the official test sets of several standard datasets as our validation data. The reason we use the given test sets as validation data for the tutorials is that is an easy way to make sure that we all work with the same split and report results using the same data. However, in a proper machine learning setup, your validation set should be separate from the test set, so you can tune the model/parameters on the validation set and then check the final performance in the test set. Thus, even though the variables are `x_test` and `y_test`, they represent our validation set.
#
# Let's first load the dataset and visualise some examples:

# %%
#Importing
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(X_train.shape[1:]))
print('Total number of training samples: {0}'.format(X_train.shape[0]))
print('Total number of validation samples: {0}'.format(X_test.shape[0]))

# Let's visualize some examples
N=5
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
items = list(range(0, 10))
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    axes[row,col].imshow(X_train[idx], cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    y_target = int(y_train[idx])
    target = str(items[y_target])
    axes[row,col].set_title(target)
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])

# %% [markdown]
# CIFAR10 contains 50,000 32x32 color training images, labeled over 10 categories and 10,000 test images. As mentioned, we use those test images as our validation set in this tutorial. We need to preprocess the images for the 1D neural network defined in the previous tutorial:

# %%
# Preprocess dataset for a 1D neural network
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize the image
X_train /= 255
X_test /= 255

#Make it a 1D array
X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2]*3)
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2]*3)


print('New X_train shape: {0}'.format(X_train_flatten.shape))

Y_train_class = np_utils.to_categorical(y_train, 10)
Y_test_class = np_utils.to_categorical(y_test, 10)

print('New Y_train shape: {0}'.format(Y_train_class.shape))

# %% [markdown]
# Now, we are ready to define the Multi-layer Perceptron model and train it.

# %%
model = Sequential()

#32 Neurons and ReLU activation function
model.add(Dense(32, activation='relu', input_shape=(X_train_flatten.shape[1:])))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(X_train_flatten, Y_train_class, batch_size=32, epochs=20)
'''trains the model using the training data (X_train_flatten and Y_train_class)'''

score = model.evaluate(X_test_flatten, Y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

# %% [markdown]
# ### Problem Definition
#
# In this exercise, you are asked to test several CNN architectures in the code provided below. Do not modify the optimizer, loss used or parameters related to the training such as the learning rate, they will be investigated in future tutorials. You must focus on the architecture itself: number of convolutional layers, number of filters in every layer, activation functions, pooling operators, among others. Batch Normalization and Dropout layers, which are quite used in CNN architectures, will be also investigated in a future tutorial so you do not have to discuss them.
#
#
# **Report**:
# *   Present a bar figure with the training and validation accuracies for different design choices. Discuss only the parameters that have a significant influence on the network's performance. Explain any discrepancy between training and validation accuracies.
# *   Present a sketch that introduces your best architecture. See some examples on how to display networks in [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/).

# %%
#Increase neuron to 512

import time
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

start_time = time.time()


model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))


model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))


# Flatten layer
model.add(Flatten())

# Fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))


# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

end_time = time.time()
print("Time Elapsed: " + str(end_time - start_time))
model.summary()

# %%
#Increase neuron to 512

import time
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

start_time = time.time()



model3 = Sequential()
model3.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu', input_shape = (32,32,3)))
model3.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu'))
model3.add(MaxPooling2D(2,2))



model3.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'relu'))
model3.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'relu'))
model3.add(MaxPooling2D(2,2))


model3.add(Flatten())

model3.add(Dense(units = 1024, activation = 'relu'))

model3.add(Dense(units = 1024, activation = 'relu'))

model3.add(Dense(units = 10, activation = 'softmax'))

# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

end_time = time.time()
print("Time Elapsed: " + str(end_time - start_time))
model.summary()

# %%
#Increase neuron to 512

import time
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

start_time = time.time()

model4 = Sequential()
model4.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model4.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Flatten())
model4.add(Dense(128, activation='relu'))

model4.add(Dense(10, activation='softmax'))

# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

end_time = time.time()
print("Time Elapsed: " + str(end_time - start_time))
model.summary()

# %%
#Increase neuron to 512

import time
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

start_time = time.time()

model4 = Sequential()
model4.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model4.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))


model4.add(Flatten())
model4.add(Dense(256, activation='relu'))

model4.add(Dense(10, activation='softmax'))

# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

end_time = time.time()
print("Time Elapsed: " + str(end_time - start_time))
model.summary()

# %%
#Optimum Test

import time
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

start_time = time.time()


model = Sequential()
model.add(Conv2D(128, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))


# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

end_time = time.time()
print("Time Elapsed: " + str(end_time - start_time))
model.summary()

# %%
import time
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt

# Load CIFAR-10 data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

start_time = time.time()

#TESTING OPTIMAL

model4 = Sequential()
model4.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model4.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', padding='same'))


model4.add(Flatten())
model4.add(Dense(256, activation='relu'))

model4.add(Dense(10, activation='softmax'))


# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model4.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

history = model4.fit(x_train, y_train_class, batch_size=32, epochs=20, validation_data=(x_test, y_test_class), verbose=0)

end_time = time.time()

# Print all values in the history object
print(history.history)

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')

# Plot loss
plt.plot(history.history['loss'], label='Training Loss', color='green')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')

plt.title('Proposed Optimal Solution for Multi Layer')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.savefig('MultiLayer Optimised Solution.png')
plt.show()

print("Time Elapsed: " + str(end_time - start_time))
model4.summary()

# %%
plt.figure(figsize=(10,6))

# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')

# Plot loss
plt.plot(history.history['loss'], label='Training Loss', color='green')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')

plt.title('Proposed Optimal Solution for Multi-Layer')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.legend()
plt.savefig('ML Optimised Solution10.png')
plt.show()

# %%
# Train the model
# Access accuracy values for training and validation
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Print accuracy values for each epoch
for epoch, acc, val_acc in zip(range(1, 21), training_accuracy, validation_accuracy):
    print(f'Epoch {epoch}: Training Accuracy = {acc:.4f}, Validation Accuracy = {val_acc:.4f}')
# Evaluate the model on the test data
test_loss, test_accuracy = model4.evaluate(x_test, y_test_class, verbose=0)
print('Validation accuracy:', score[1])

score = model4.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

# %% [markdown]
# ---
# ---
#
# ## Task 2: Regression
#
# Now we face a regression task instead of a classification problem. Loss function, activations, and dataset will change in the following task. Thus, instead of having one vector with the probabilities of each class, in this regression problem, the output is a single scalar.
#
# For this second task, we chose the task of estimating house prices based on input images. To get the data run the following script, which clones Ahmed and Moustafa’s [repository](https://github.com/emanhamed/Houses-dataset) into colmap.

# %%
# !git clone https://github.com/emanhamed/Houses-dataset
# %cd /content/Houses-dataset/Houses\ Dataset

# %% [markdown]
# This dataset contains four images of the house (kitchen, frontal, bedroom and bathroom), and attributes (number of bedrooms, number of bathrooms, zip code...). For our exercise, we only use the images of the house. We start with front door images.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import seed

house_section = 'frontal' # select between: kitchen, frontal, bedroom or bathroom

print('We have selected {} images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.'.format(house_section))
images = []
for i_im in range(1, 536):
  image_path = 'Houses-dataset/Houses Dataset/' + str(i_im) + '_' + house_section + '.jpg'
  image = cv2.imread(image_path)
  image = cv2.resize(image, (64, 64))
  images.append(image)

labels = []
f = open('Houses-dataset/Houses Dataset/HousesInfo.txt', "r")
for x in f:
  label = (x).split(' ')[-1].split('\n')[0]
  labels.append(label)

# Let's visualize some examples
N=3
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col    
    tmp = cv2.cvtColor(images[idx],cv2.COLOR_BGR2RGB)
    axes[row,col].imshow(tmp, cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    target = int(labels[idx])
    axes[row,col].set_title(str(target) + '$')
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# We have selected frontal images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.

# %% [markdown]
# Prepare the dataset for training the model:

# %%
seed(1234)
images = np.asarray(images).astype('float32')
labels = np.asarray(labels).astype('float32')

# Normalize the image
max_price = labels.max()
images /= 255.
labels /= max_price

random_idx = np.random.permutation(len(images))
images = images[random_idx]
labels = labels[random_idx]

split_size_val = int(0.8*len(images))
X_train, X_val = images[:split_size_val], images[split_size_val+1:]
Y_train, Y_val = labels[:split_size_val], labels[split_size_val+1:]

# Print shape of training and val images 
print('X_train image shape: {0}'.format(X_train.shape))
print('X_val image shape: {0}'.format(X_val.shape))

# Print shape of training and val labels 
print('Y_train labels shape: {0}'.format(Y_train.shape))
print('Y_val labels shape: {0}'.format(Y_val.shape))
# Out:
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)

# %% [markdown]
# ### Problem Definition
#
# Similar to the previous task, you are asked to design a CNN architecture able to perform the estimation of house prices based on the `frontal` house image. Design a new model by changing parameters such as the number of convolutional layers, activation functions, strides, or pooling operators, among others.

# %%
#3 Layer All RELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model = Sequential()

# . . . 
# Convolutional and Pooling Layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Flatten Layer
model.add(Flatten())
# Fully Connected Layers
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))

# Output Layer
model.add(Dense(1, activation='linear'))  # Assuming house price prediction, use linear activation
# . . . . 

model.summary()
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 8))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history.history['loss'], label='Training Loss', color='green')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')

plt.title('3 Layer RELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('3 Layer RELU.png')
plt.show()

#-----

prices_predicted = model.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# Model: "sequential_84"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_240 (Conv2D)         (None, 62, 62, 32)        896
#
#  max_pooling2d_175 (MaxPooli  (None, 31, 31, 32)       0
#  ng2D)
#
#  conv2d_241 (Conv2D)         (None, 29, 29, 64)        18496
#
#  max_pooling2d_176 (MaxPooli  (None, 14, 14, 64)       0
#  ng2D)
#
#  conv2d_242 (Conv2D)         (None, 12, 12, 128)       73856
#
#  max_pooling2d_177 (MaxPooli  (None, 6, 6, 128)        0
#  ng2D)
#
#  flatten_76 (Flatten)        (None, 4608)              0
#
#  dense_168 (Dense)           (None, 128)               589952
#
#  dense_169 (Dense)           (None, 64)                8256
#
#  dense_170 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 691,521
# Trainable params: 691,521
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training model...
# /Users/hasnatchowdhury/opt/anaconda3/envs/machineLearning/lib/python3.10/site-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Train on 428 samples, validate on 106 samples
# 2024-01-24 01:27:39.758874: W tensorflow/c/c_api.cc:300] Operation '{name:'training_58/Adam/conv2d_242/kernel/m/Assign' id:21450 op device:{requested: '', assigned: ''} def:{{{node training_58/Adam/conv2d_242/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_58/Adam/conv2d_242/kernel/m, training_58/Adam/conv2d_242/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 416/428 [============================>.] - ETA: 0s - loss: 270.6839 - mean_absolute_percentage_error: 270.6839
# /Users/hasnatchowdhury/opt/anaconda3/envs/machineLearning/lib/python3.10/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-01-24 01:27:41.824928: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_37/mul' id:21276 op device:{requested: '', assigned: ''} def:{{{node loss_37/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_37/mul/x, loss_37/dense_170_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 2s 5ms/sample - loss: 265.0464 - mean_absolute_percentage_error: 265.0464 - val_loss: 71.8885 - val_mean_absolute_percentage_error: 71.8885
# Epoch 2/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 70.6682 - mean_absolute_percentage_error: 70.6682 - val_loss: 74.6738 - val_mean_absolute_percentage_error: 74.6738
# Epoch 3/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 69.8626 - mean_absolute_percentage_error: 69.8626 - val_loss: 65.7809 - val_mean_absolute_percentage_error: 65.7809
# Epoch 4/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 64.6443 - mean_absolute_percentage_error: 64.6443 - val_loss: 63.9296 - val_mean_absolute_percentage_error: 63.9296
# Epoch 5/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 69.0149 - mean_absolute_percentage_error: 69.0149 - val_loss: 66.6423 - val_mean_absolute_percentage_error: 66.6423
# Epoch 6/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 65.6314 - mean_absolute_percentage_error: 65.6314 - val_loss: 65.3326 - val_mean_absolute_percentage_error: 65.3326
# Epoch 7/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 66.6970 - mean_absolute_percentage_error: 66.6970 - val_loss: 63.6821 - val_mean_absolute_percentage_error: 63.6821
# Epoch 8/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 61.9120 - mean_absolute_percentage_error: 61.9120 - val_loss: 59.0715 - val_mean_absolute_percentage_error: 59.0715
# Epoch 9/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 63.8270 - mean_absolute_percentage_error: 63.8270 - val_loss: 58.7678 - val_mean_absolute_percentage_error: 58.7678
# Epoch 10/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 59.4298 - mean_absolute_percentage_error: 59.4298 - val_loss: 57.1400 - val_mean_absolute_percentage_error: 57.1400
# Epoch 11/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 55.9412 - mean_absolute_percentage_error: 55.9412 - val_loss: 54.0480 - val_mean_absolute_percentage_error: 54.0480
# Epoch 12/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 53.9397 - mean_absolute_percentage_error: 53.9397 - val_loss: 54.9135 - val_mean_absolute_percentage_error: 54.9135
# Epoch 13/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 53.8980 - mean_absolute_percentage_error: 53.8980 - val_loss: 53.4639 - val_mean_absolute_percentage_error: 53.4639
# Epoch 14/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 54.1457 - mean_absolute_percentage_error: 54.1457 - val_loss: 52.9861 - val_mean_absolute_percentage_error: 52.9860
# Epoch 15/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 45.2989 - mean_absolute_percentage_error: 45.2989 - val_loss: 57.2479 - val_mean_absolute_percentage_error: 57.2479
# Epoch 16/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 42.8733 - mean_absolute_percentage_error: 42.8733 - val_loss: 52.5950 - val_mean_absolute_percentage_error: 52.5950
# Epoch 17/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 42.0027 - mean_absolute_percentage_error: 42.0027 - val_loss: 53.8642 - val_mean_absolute_percentage_error: 53.8642
# Epoch 18/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 47.4245 - mean_absolute_percentage_error: 47.4245 - val_loss: 61.5983 - val_mean_absolute_percentage_error: 61.5983
# Epoch 19/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 45.2773 - mean_absolute_percentage_error: 45.2773 - val_loss: 64.6938 - val_mean_absolute_percentage_error: 64.6938
# Epoch 20/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.7122 - mean_absolute_percentage_error: 41.7122 - val_loss: 51.8083 - val_mean_absolute_percentage_error: 51.8083
# Epoch 21/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 36.4712 - mean_absolute_percentage_error: 36.4712 - val_loss: 52.6299 - val_mean_absolute_percentage_error: 52.6299
# Epoch 22/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 34.9522 - mean_absolute_percentage_error: 34.9522 - val_loss: 53.3974 - val_mean_absolute_percentage_error: 53.3974
# Epoch 23/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.2776 - mean_absolute_percentage_error: 32.2776 - val_loss: 59.7635 - val_mean_absolute_percentage_error: 59.7635
# Epoch 24/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.0647 - mean_absolute_percentage_error: 31.0647 - val_loss: 51.5345 - val_mean_absolute_percentage_error: 51.5345
# Epoch 25/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.0658 - mean_absolute_percentage_error: 30.0658 - val_loss: 62.6002 - val_mean_absolute_percentage_error: 62.6002
# Epoch 26/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 33.8056 - mean_absolute_percentage_error: 33.8056 - val_loss: 51.1056 - val_mean_absolute_percentage_error: 51.1056
# Epoch 27/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.2940 - mean_absolute_percentage_error: 30.2940 - val_loss: 59.2297 - val_mean_absolute_percentage_error: 59.2297
# Epoch 28/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.2856 - mean_absolute_percentage_error: 28.2856 - val_loss: 55.0844 - val_mean_absolute_percentage_error: 55.0844
# Epoch 29/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.0207 - mean_absolute_percentage_error: 24.0207 - val_loss: 53.7415 - val_mean_absolute_percentage_error: 53.7415
# Epoch 30/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.1980 - mean_absolute_percentage_error: 23.1980 - val_loss: 61.8711 - val_mean_absolute_percentage_error: 61.8711
# Epoch 31/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.2837 - mean_absolute_percentage_error: 23.2837 - val_loss: 52.5388 - val_mean_absolute_percentage_error: 52.5388
# Epoch 32/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.3698 - mean_absolute_percentage_error: 23.3698 - val_loss: 55.4348 - val_mean_absolute_percentage_error: 55.4348
# Epoch 33/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.6953 - mean_absolute_percentage_error: 22.6953 - val_loss: 60.2204 - val_mean_absolute_percentage_error: 60.2204
# Epoch 34/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.1487 - mean_absolute_percentage_error: 23.1487 - val_loss: 60.4593 - val_mean_absolute_percentage_error: 60.4593
# Epoch 35/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 21.0460 - mean_absolute_percentage_error: 21.0460 - val_loss: 56.9743 - val_mean_absolute_percentage_error: 56.9743
# Epoch 36/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.0287 - mean_absolute_percentage_error: 20.0287 - val_loss: 60.4053 - val_mean_absolute_percentage_error: 60.4053
# Epoch 37/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.2431 - mean_absolute_percentage_error: 22.2431 - val_loss: 60.9857 - val_mean_absolute_percentage_error: 60.9857
# Epoch 38/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 21.5723 - mean_absolute_percentage_error: 21.5723 - val_loss: 52.9842 - val_mean_absolute_percentage_error: 52.9842
# Epoch 39/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.5208 - mean_absolute_percentage_error: 20.5208 - val_loss: 58.7915 - val_mean_absolute_percentage_error: 58.7915
# Epoch 40/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 18.4824 - mean_absolute_percentage_error: 18.4824 - val_loss: 55.6463 - val_mean_absolute_percentage_error: 55.6463
# Epoch 41/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 18.2930 - mean_absolute_percentage_error: 18.2930 - val_loss: 61.2560 - val_mean_absolute_percentage_error: 61.2560
# Epoch 42/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 18.2897 - mean_absolute_percentage_error: 18.2897 - val_loss: 56.1874 - val_mean_absolute_percentage_error: 56.1874
# Epoch 43/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 19.5153 - mean_absolute_percentage_error: 19.5153 - val_loss: 65.2779 - val_mean_absolute_percentage_error: 65.2779
# Epoch 44/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.8869 - mean_absolute_percentage_error: 16.8869 - val_loss: 58.3573 - val_mean_absolute_percentage_error: 58.3573
# Epoch 45/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 18.3352 - mean_absolute_percentage_error: 18.3352 - val_loss: 49.9081 - val_mean_absolute_percentage_error: 49.9081
# Epoch 46/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 18.1101 - mean_absolute_percentage_error: 18.1101 - val_loss: 60.6055 - val_mean_absolute_percentage_error: 60.6055
# Epoch 47/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 17.4556 - mean_absolute_percentage_error: 17.4556 - val_loss: 60.9495 - val_mean_absolute_percentage_error: 60.9495
# Epoch 48/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.8880 - mean_absolute_percentage_error: 16.8880 - val_loss: 64.6137 - val_mean_absolute_percentage_error: 64.6137
# Epoch 49/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.5675 - mean_absolute_percentage_error: 16.5675 - val_loss: 58.8614 - val_mean_absolute_percentage_error: 58.8614
# Epoch 50/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.3548 - mean_absolute_percentage_error: 16.3548 - val_loss: 58.5630 - val_mean_absolute_percentage_error: 58.5630
# Epoch 51/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.0323 - mean_absolute_percentage_error: 15.0323 - val_loss: 56.3977 - val_mean_absolute_percentage_error: 56.3977
# Epoch 52/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.5930 - mean_absolute_percentage_error: 15.5930 - val_loss: 71.0173 - val_mean_absolute_percentage_error: 71.0173
# Epoch 53/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.6062 - mean_absolute_percentage_error: 16.6062 - val_loss: 60.7472 - val_mean_absolute_percentage_error: 60.7472
# Epoch 54/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.4612 - mean_absolute_percentage_error: 14.4612 - val_loss: 54.9198 - val_mean_absolute_percentage_error: 54.9198
# Epoch 55/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.3321 - mean_absolute_percentage_error: 14.3321 - val_loss: 60.9616 - val_mean_absolute_percentage_error: 60.9616
# Epoch 56/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.4790 - mean_absolute_percentage_error: 14.4790 - val_loss: 65.8634 - val_mean_absolute_percentage_error: 65.8634
# Epoch 57/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.4140 - mean_absolute_percentage_error: 14.4140 - val_loss: 63.1071 - val_mean_absolute_percentage_error: 63.1071
# Epoch 58/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.1070 - mean_absolute_percentage_error: 14.1070 - val_loss: 58.4323 - val_mean_absolute_percentage_error: 58.4323
# Epoch 59/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.2519 - mean_absolute_percentage_error: 15.2519 - val_loss: 67.1278 - val_mean_absolute_percentage_error: 67.1278
# Epoch 60/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.1544 - mean_absolute_percentage_error: 13.1544 - val_loss: 56.6638 - val_mean_absolute_percentage_error: 56.6638
# Epoch 61/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.1082 - mean_absolute_percentage_error: 13.1082 - val_loss: 68.8542 - val_mean_absolute_percentage_error: 68.8542
# Epoch 62/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.7269 - mean_absolute_percentage_error: 13.7269 - val_loss: 68.0568 - val_mean_absolute_percentage_error: 68.0568
# Epoch 63/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.0853 - mean_absolute_percentage_error: 14.0853 - val_loss: 60.7314 - val_mean_absolute_percentage_error: 60.7314
# Epoch 64/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.1536 - mean_absolute_percentage_error: 14.1536 - val_loss: 62.8542 - val_mean_absolute_percentage_error: 62.8542
# Epoch 65/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.9972 - mean_absolute_percentage_error: 11.9972 - val_loss: 63.7650 - val_mean_absolute_percentage_error: 63.7650
# Epoch 66/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.7140 - mean_absolute_percentage_error: 12.7140 - val_loss: 55.8198 - val_mean_absolute_percentage_error: 55.8198
# Epoch 67/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.7472 - mean_absolute_percentage_error: 13.7472 - val_loss: 64.3733 - val_mean_absolute_percentage_error: 64.3733
# Epoch 68/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.1010 - mean_absolute_percentage_error: 14.1010 - val_loss: 66.1074 - val_mean_absolute_percentage_error: 66.1074
# Epoch 69/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.3937 - mean_absolute_percentage_error: 13.3937 - val_loss: 63.0178 - val_mean_absolute_percentage_error: 63.0178
# Epoch 70/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.2372 - mean_absolute_percentage_error: 13.2372 - val_loss: 62.0827 - val_mean_absolute_percentage_error: 62.0827
# Epoch 71/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.5906 - mean_absolute_percentage_error: 14.5906 - val_loss: 65.1250 - val_mean_absolute_percentage_error: 65.1250
# Epoch 72/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.7546 - mean_absolute_percentage_error: 12.7546 - val_loss: 67.8448 - val_mean_absolute_percentage_error: 67.8448
# Epoch 73/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.5897 - mean_absolute_percentage_error: 13.5897 - val_loss: 55.2318 - val_mean_absolute_percentage_error: 55.2318
# Epoch 74/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.7001 - mean_absolute_percentage_error: 13.7001 - val_loss: 64.4826 - val_mean_absolute_percentage_error: 64.4826
# Epoch 75/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.4415 - mean_absolute_percentage_error: 12.4415 - val_loss: 56.9317 - val_mean_absolute_percentage_error: 56.9317
# Epoch 76/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.3700 - mean_absolute_percentage_error: 11.3700 - val_loss: 68.1484 - val_mean_absolute_percentage_error: 68.1484
# Epoch 77/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.7320 - mean_absolute_percentage_error: 10.7320 - val_loss: 66.0556 - val_mean_absolute_percentage_error: 66.0556
# Epoch 78/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.6575 - mean_absolute_percentage_error: 10.6575 - val_loss: 67.8886 - val_mean_absolute_percentage_error: 67.8886
# Epoch 79/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.3118 - mean_absolute_percentage_error: 11.3118 - val_loss: 68.3346 - val_mean_absolute_percentage_error: 68.3346
# Epoch 80/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.5543 - mean_absolute_percentage_error: 10.5543 - val_loss: 67.8646 - val_mean_absolute_percentage_error: 67.8646
# Epoch 81/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.8098 - mean_absolute_percentage_error: 10.8098 - val_loss: 66.3578 - val_mean_absolute_percentage_error: 66.3578
# Epoch 82/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.5533 - mean_absolute_percentage_error: 9.5533 - val_loss: 70.3609 - val_mean_absolute_percentage_error: 70.3609
# Epoch 83/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.3911 - mean_absolute_percentage_error: 11.3911 - val_loss: 75.7518 - val_mean_absolute_percentage_error: 75.7518
# Epoch 84/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.5593 - mean_absolute_percentage_error: 13.5593 - val_loss: 65.3458 - val_mean_absolute_percentage_error: 65.3458
# Epoch 85/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.7041 - mean_absolute_percentage_error: 11.7041 - val_loss: 79.7226 - val_mean_absolute_percentage_error: 79.7226
# Epoch 86/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.1945 - mean_absolute_percentage_error: 11.1945 - val_loss: 55.7756 - val_mean_absolute_percentage_error: 55.7756
# Epoch 87/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.0474 - mean_absolute_percentage_error: 12.0474 - val_loss: 61.8746 - val_mean_absolute_percentage_error: 61.8746
# Epoch 88/100
# 428/428 [==============================] - 2s 5ms/sample - loss: 11.4575 - mean_absolute_percentage_error: 11.4575 - val_loss: 72.5758 - val_mean_absolute_percentage_error: 72.5758
# Epoch 89/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.6759 - mean_absolute_percentage_error: 10.6759 - val_loss: 64.7352 - val_mean_absolute_percentage_error: 64.7352
# Epoch 90/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.3492 - mean_absolute_percentage_error: 10.3492 - val_loss: 63.2923 - val_mean_absolute_percentage_error: 63.2923
# Epoch 91/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.7863 - mean_absolute_percentage_error: 10.7863 - val_loss: 65.8103 - val_mean_absolute_percentage_error: 65.8103
# Epoch 92/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.0072 - mean_absolute_percentage_error: 10.0072 - val_loss: 65.8226 - val_mean_absolute_percentage_error: 65.8227
# Epoch 93/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.0585 - mean_absolute_percentage_error: 10.0585 - val_loss: 67.9889 - val_mean_absolute_percentage_error: 67.9889
# Epoch 94/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.3530 - mean_absolute_percentage_error: 10.3530 - val_loss: 74.8991 - val_mean_absolute_percentage_error: 74.8991
# Epoch 95/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.6487 - mean_absolute_percentage_error: 10.6487 - val_loss: 65.7160 - val_mean_absolute_percentage_error: 65.7160
# Epoch 96/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.9555 - mean_absolute_percentage_error: 9.9555 - val_loss: 73.0606 - val_mean_absolute_percentage_error: 73.0606
# Epoch 97/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 10.9161 - mean_absolute_percentage_error: 10.9161 - val_loss: 66.3053 - val_mean_absolute_percentage_error: 66.3053
# Epoch 98/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.9235 - mean_absolute_percentage_error: 9.9235 - val_loss: 67.0337 - val_mean_absolute_percentage_error: 67.0337
# Epoch 99/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.0630 - mean_absolute_percentage_error: 9.0630 - val_loss: 68.6866 - val_mean_absolute_percentage_error: 68.6866
# Epoch 100/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.3273 - mean_absolute_percentage_error: 9.3273 - val_loss: 64.1920 - val_mean_absolute_percentage_error: 64.1920
# /Users/hasnatchowdhury/opt/anaconda3/envs/machineLearning/lib/python3.10/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-01-24 01:29:10.358630: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_170/BiasAdd' id:21219 op device:{requested: '', assigned: ''} def:{{{node dense_170/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_170/MatMul, dense_170/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 64.19%
# Time Elapsed: 26021.15186905861

# %%
#2 Layer All RELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model2 = Sequential()

# . . . 
# Convolutional and Pooling Layers
model2.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(128, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))

# Flatten Layer
model2.add(Flatten())
# Fully Connected Layers
model2.add(Dense(128, activation='relu'))
model2.add(Dense(64, activation='relu'))

# Output Layer
model2.add(Dense(1, activation='linear'))  # Assuming house price prediction, use linear activation
# . . . . 

model2.summary()
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model2.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history2 = model2.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history2.history['loss'], label='Training Loss', color='green')
plt.plot(history2.history['val_loss'], label='Validation Loss', color='red')

plt.title('2 Layer RELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('2 Layer RELU.png')
plt.show()

#-----

prices_predicted = model2.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# Model: "sequential_85"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_243 (Conv2D)         (None, 62, 62, 32)        896
#
#  max_pooling2d_178 (MaxPooli  (None, 31, 31, 32)       0
#  ng2D)
#
#  conv2d_244 (Conv2D)         (None, 29, 29, 128)       36992
#
#  max_pooling2d_179 (MaxPooli  (None, 14, 14, 128)      0
#  ng2D)
#
#  flatten_77 (Flatten)        (None, 25088)             0
#
#  dense_171 (Dense)           (None, 128)               3211392
#
#  dense_172 (Dense)           (None, 64)                8256
#
#  dense_173 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 3,257,601
# Trainable params: 3,257,601
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 01:29:12.123908: W tensorflow/c/c_api.cc:300] Operation '{name:'training_60/Adam/conv2d_243/kernel/v/Assign' id:22051 op device:{requested: '', assigned: ''} def:{{{node training_60/Adam/conv2d_243/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_60/Adam/conv2d_243/kernel/v, training_60/Adam/conv2d_243/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 416/428 [============================>.] - ETA: 0s - loss: 736.8920 - mean_absolute_percentage_error: 736.8920
# 2024-01-24 01:29:14.171167: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_38/mul' id:21851 op device:{requested: '', assigned: ''} def:{{{node loss_38/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_38/mul/x, loss_38/dense_173_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 2s 4ms/sample - loss: 717.9581 - mean_absolute_percentage_error: 717.9580 - val_loss: 75.5189 - val_mean_absolute_percentage_error: 75.5189
# Epoch 2/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 68.7743 - mean_absolute_percentage_error: 68.7743 - val_loss: 62.2167 - val_mean_absolute_percentage_error: 62.2167
# Epoch 3/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 67.1703 - mean_absolute_percentage_error: 67.1703 - val_loss: 67.3366 - val_mean_absolute_percentage_error: 67.3366
# Epoch 4/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 62.7480 - mean_absolute_percentage_error: 62.7480 - val_loss: 63.2466 - val_mean_absolute_percentage_error: 63.2466
# Epoch 5/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 64.2268 - mean_absolute_percentage_error: 64.2268 - val_loss: 68.2550 - val_mean_absolute_percentage_error: 68.2551
# Epoch 6/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 63.5513 - mean_absolute_percentage_error: 63.5513 - val_loss: 60.6971 - val_mean_absolute_percentage_error: 60.6971
# Epoch 7/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 61.6016 - mean_absolute_percentage_error: 61.6016 - val_loss: 58.5434 - val_mean_absolute_percentage_error: 58.5434
# Epoch 8/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 55.6194 - mean_absolute_percentage_error: 55.6194 - val_loss: 60.5268 - val_mean_absolute_percentage_error: 60.5268
# Epoch 9/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 59.3124 - mean_absolute_percentage_error: 59.3124 - val_loss: 58.1295 - val_mean_absolute_percentage_error: 58.1295
# Epoch 10/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 55.5744 - mean_absolute_percentage_error: 55.5744 - val_loss: 58.8118 - val_mean_absolute_percentage_error: 58.8118
# Epoch 11/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 52.2270 - mean_absolute_percentage_error: 52.2270 - val_loss: 58.9540 - val_mean_absolute_percentage_error: 58.9540
# Epoch 12/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 48.8366 - mean_absolute_percentage_error: 48.8366 - val_loss: 56.7104 - val_mean_absolute_percentage_error: 56.7104
# Epoch 13/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 45.7722 - mean_absolute_percentage_error: 45.7722 - val_loss: 59.0149 - val_mean_absolute_percentage_error: 59.0149
# Epoch 14/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 43.3402 - mean_absolute_percentage_error: 43.3402 - val_loss: 56.4815 - val_mean_absolute_percentage_error: 56.4815
# Epoch 15/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 51.6300 - mean_absolute_percentage_error: 51.6300 - val_loss: 56.5913 - val_mean_absolute_percentage_error: 56.5913
# Epoch 16/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 50.5154 - mean_absolute_percentage_error: 50.5154 - val_loss: 73.9991 - val_mean_absolute_percentage_error: 73.9991
# Epoch 17/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 48.2369 - mean_absolute_percentage_error: 48.2369 - val_loss: 60.0512 - val_mean_absolute_percentage_error: 60.0512
# Epoch 18/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.7178 - mean_absolute_percentage_error: 41.7178 - val_loss: 60.0167 - val_mean_absolute_percentage_error: 60.0167
# Epoch 19/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 38.1503 - mean_absolute_percentage_error: 38.1503 - val_loss: 57.5815 - val_mean_absolute_percentage_error: 57.5815
# Epoch 20/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.2527 - mean_absolute_percentage_error: 37.2527 - val_loss: 58.8817 - val_mean_absolute_percentage_error: 58.8817
# Epoch 21/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 34.8484 - mean_absolute_percentage_error: 34.8484 - val_loss: 58.5435 - val_mean_absolute_percentage_error: 58.5435
# Epoch 22/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 33.3973 - mean_absolute_percentage_error: 33.3973 - val_loss: 63.5740 - val_mean_absolute_percentage_error: 63.5740
# Epoch 23/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.6241 - mean_absolute_percentage_error: 32.6241 - val_loss: 60.6711 - val_mean_absolute_percentage_error: 60.6711
# Epoch 24/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 27.6785 - mean_absolute_percentage_error: 27.6785 - val_loss: 60.5134 - val_mean_absolute_percentage_error: 60.5134
# Epoch 25/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 27.2927 - mean_absolute_percentage_error: 27.2927 - val_loss: 63.9417 - val_mean_absolute_percentage_error: 63.9417
# Epoch 26/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 26.2143 - mean_absolute_percentage_error: 26.2143 - val_loss: 68.6272 - val_mean_absolute_percentage_error: 68.6272
# Epoch 27/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 27.8042 - mean_absolute_percentage_error: 27.8042 - val_loss: 70.6658 - val_mean_absolute_percentage_error: 70.6657
# Epoch 28/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.0518 - mean_absolute_percentage_error: 28.0518 - val_loss: 64.3106 - val_mean_absolute_percentage_error: 64.3106
# Epoch 29/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 25.3282 - mean_absolute_percentage_error: 25.3282 - val_loss: 67.5590 - val_mean_absolute_percentage_error: 67.5590
# Epoch 30/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.7919 - mean_absolute_percentage_error: 24.7919 - val_loss: 65.4845 - val_mean_absolute_percentage_error: 65.4845
# Epoch 31/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.8251 - mean_absolute_percentage_error: 24.8251 - val_loss: 69.3593 - val_mean_absolute_percentage_error: 69.3593
# Epoch 32/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.3675 - mean_absolute_percentage_error: 22.3675 - val_loss: 70.8637 - val_mean_absolute_percentage_error: 70.8637
# Epoch 33/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 25.8049 - mean_absolute_percentage_error: 25.8049 - val_loss: 77.3206 - val_mean_absolute_percentage_error: 77.3206
# Epoch 34/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.1690 - mean_absolute_percentage_error: 24.1690 - val_loss: 73.7087 - val_mean_absolute_percentage_error: 73.7087
# Epoch 35/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.3180 - mean_absolute_percentage_error: 22.3180 - val_loss: 71.1918 - val_mean_absolute_percentage_error: 71.1918
# Epoch 36/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 21.1827 - mean_absolute_percentage_error: 21.1827 - val_loss: 78.4863 - val_mean_absolute_percentage_error: 78.4863
# Epoch 37/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 23.8476 - mean_absolute_percentage_error: 23.8476 - val_loss: 68.5861 - val_mean_absolute_percentage_error: 68.5861
# Epoch 38/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.7173 - mean_absolute_percentage_error: 20.7173 - val_loss: 76.2116 - val_mean_absolute_percentage_error: 76.2116
# Epoch 39/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 19.5291 - mean_absolute_percentage_error: 19.5291 - val_loss: 71.5417 - val_mean_absolute_percentage_error: 71.5417
# Epoch 40/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 18.3698 - mean_absolute_percentage_error: 18.3698 - val_loss: 79.1255 - val_mean_absolute_percentage_error: 79.1255
# Epoch 41/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.5863 - mean_absolute_percentage_error: 16.5863 - val_loss: 70.1724 - val_mean_absolute_percentage_error: 70.1724
# Epoch 42/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 17.4323 - mean_absolute_percentage_error: 17.4323 - val_loss: 72.0039 - val_mean_absolute_percentage_error: 72.0039
# Epoch 43/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.8739 - mean_absolute_percentage_error: 15.8739 - val_loss: 74.6605 - val_mean_absolute_percentage_error: 74.6605
# Epoch 44/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.4897 - mean_absolute_percentage_error: 16.4897 - val_loss: 76.1272 - val_mean_absolute_percentage_error: 76.1272
# Epoch 45/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 17.2567 - mean_absolute_percentage_error: 17.2567 - val_loss: 72.4001 - val_mean_absolute_percentage_error: 72.4001
# Epoch 46/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.8871 - mean_absolute_percentage_error: 16.8871 - val_loss: 74.0246 - val_mean_absolute_percentage_error: 74.0246
# Epoch 47/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.3866 - mean_absolute_percentage_error: 15.3866 - val_loss: 74.8477 - val_mean_absolute_percentage_error: 74.8477
# Epoch 48/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.1317 - mean_absolute_percentage_error: 15.1317 - val_loss: 73.8305 - val_mean_absolute_percentage_error: 73.8305
# Epoch 49/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.0089 - mean_absolute_percentage_error: 16.0089 - val_loss: 72.5210 - val_mean_absolute_percentage_error: 72.5210
# Epoch 50/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 17.4125 - mean_absolute_percentage_error: 17.4125 - val_loss: 77.1953 - val_mean_absolute_percentage_error: 77.1953
# Epoch 51/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.2908 - mean_absolute_percentage_error: 16.2908 - val_loss: 81.0372 - val_mean_absolute_percentage_error: 81.0372
# Epoch 52/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.4964 - mean_absolute_percentage_error: 16.4964 - val_loss: 79.5507 - val_mean_absolute_percentage_error: 79.5507
# Epoch 53/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 15.5557 - mean_absolute_percentage_error: 15.5557 - val_loss: 73.9342 - val_mean_absolute_percentage_error: 73.9342
# Epoch 54/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.0248 - mean_absolute_percentage_error: 14.0248 - val_loss: 81.8367 - val_mean_absolute_percentage_error: 81.8367
# Epoch 55/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 14.0270 - mean_absolute_percentage_error: 14.0270 - val_loss: 72.1252 - val_mean_absolute_percentage_error: 72.1252
# Epoch 56/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 13.7493 - mean_absolute_percentage_error: 13.7493 - val_loss: 78.7319 - val_mean_absolute_percentage_error: 78.7319
# Epoch 57/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 12.5054 - mean_absolute_percentage_error: 12.5054 - val_loss: 71.6613 - val_mean_absolute_percentage_error: 71.6613
# Epoch 58/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.9495 - mean_absolute_percentage_error: 13.9495 - val_loss: 78.4304 - val_mean_absolute_percentage_error: 78.4304
# Epoch 59/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.6852 - mean_absolute_percentage_error: 12.6852 - val_loss: 80.9375 - val_mean_absolute_percentage_error: 80.9375
# Epoch 60/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.2599 - mean_absolute_percentage_error: 12.2599 - val_loss: 81.8240 - val_mean_absolute_percentage_error: 81.8240
# Epoch 61/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.0776 - mean_absolute_percentage_error: 14.0776 - val_loss: 86.4257 - val_mean_absolute_percentage_error: 86.4257
# Epoch 62/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.0309 - mean_absolute_percentage_error: 15.0309 - val_loss: 70.1575 - val_mean_absolute_percentage_error: 70.1575
# Epoch 63/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.2681 - mean_absolute_percentage_error: 13.2681 - val_loss: 79.7289 - val_mean_absolute_percentage_error: 79.7289
# Epoch 64/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.6294 - mean_absolute_percentage_error: 12.6294 - val_loss: 76.6143 - val_mean_absolute_percentage_error: 76.6143
# Epoch 65/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.2573 - mean_absolute_percentage_error: 12.2573 - val_loss: 85.3140 - val_mean_absolute_percentage_error: 85.3140
# Epoch 66/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.5124 - mean_absolute_percentage_error: 13.5124 - val_loss: 71.0619 - val_mean_absolute_percentage_error: 71.0619
# Epoch 67/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.7436 - mean_absolute_percentage_error: 12.7436 - val_loss: 76.0102 - val_mean_absolute_percentage_error: 76.0102
# Epoch 68/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.4732 - mean_absolute_percentage_error: 13.4732 - val_loss: 88.9076 - val_mean_absolute_percentage_error: 88.9076
# Epoch 69/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.8147 - mean_absolute_percentage_error: 13.8147 - val_loss: 77.1547 - val_mean_absolute_percentage_error: 77.1547
# Epoch 70/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.2017 - mean_absolute_percentage_error: 12.2017 - val_loss: 83.1921 - val_mean_absolute_percentage_error: 83.1921
# Epoch 71/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.8714 - mean_absolute_percentage_error: 11.8714 - val_loss: 85.2512 - val_mean_absolute_percentage_error: 85.2513
# Epoch 72/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.6838 - mean_absolute_percentage_error: 11.6838 - val_loss: 77.0692 - val_mean_absolute_percentage_error: 77.0692
# Epoch 73/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.6565 - mean_absolute_percentage_error: 10.6565 - val_loss: 83.4104 - val_mean_absolute_percentage_error: 83.4104
# Epoch 74/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.4388 - mean_absolute_percentage_error: 10.4388 - val_loss: 78.0009 - val_mean_absolute_percentage_error: 78.0009
# Epoch 75/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.3871 - mean_absolute_percentage_error: 10.3871 - val_loss: 73.9704 - val_mean_absolute_percentage_error: 73.9704
# Epoch 76/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.7299 - mean_absolute_percentage_error: 11.7299 - val_loss: 86.6645 - val_mean_absolute_percentage_error: 86.6645
# Epoch 77/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.9384 - mean_absolute_percentage_error: 10.9384 - val_loss: 74.5244 - val_mean_absolute_percentage_error: 74.5244
# Epoch 78/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.4195 - mean_absolute_percentage_error: 11.4195 - val_loss: 87.0960 - val_mean_absolute_percentage_error: 87.0960
# Epoch 79/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.4990 - mean_absolute_percentage_error: 10.4990 - val_loss: 77.2697 - val_mean_absolute_percentage_error: 77.2697
# Epoch 80/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.1683 - mean_absolute_percentage_error: 10.1683 - val_loss: 85.2902 - val_mean_absolute_percentage_error: 85.2902
# Epoch 81/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.3814 - mean_absolute_percentage_error: 10.3814 - val_loss: 80.6615 - val_mean_absolute_percentage_error: 80.6615
# Epoch 82/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.8558 - mean_absolute_percentage_error: 9.8558 - val_loss: 81.0440 - val_mean_absolute_percentage_error: 81.0440
# Epoch 83/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.0469 - mean_absolute_percentage_error: 10.0469 - val_loss: 84.8893 - val_mean_absolute_percentage_error: 84.8893
# Epoch 84/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.8140 - mean_absolute_percentage_error: 9.8140 - val_loss: 86.0914 - val_mean_absolute_percentage_error: 86.0914
# Epoch 85/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.8851 - mean_absolute_percentage_error: 9.8851 - val_loss: 85.0866 - val_mean_absolute_percentage_error: 85.0866
# Epoch 86/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.0235 - mean_absolute_percentage_error: 10.0235 - val_loss: 83.7133 - val_mean_absolute_percentage_error: 83.7133
# Epoch 87/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.3181 - mean_absolute_percentage_error: 10.3181 - val_loss: 92.3198 - val_mean_absolute_percentage_error: 92.3198
# Epoch 88/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.8949 - mean_absolute_percentage_error: 10.8949 - val_loss: 80.5643 - val_mean_absolute_percentage_error: 80.5643
# Epoch 89/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.4237 - mean_absolute_percentage_error: 11.4237 - val_loss: 82.9349 - val_mean_absolute_percentage_error: 82.9349
# Epoch 90/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.2617 - mean_absolute_percentage_error: 10.2617 - val_loss: 85.5121 - val_mean_absolute_percentage_error: 85.5121
# Epoch 91/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.5911 - mean_absolute_percentage_error: 11.5911 - val_loss: 80.9350 - val_mean_absolute_percentage_error: 80.9350
# Epoch 92/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.0382 - mean_absolute_percentage_error: 11.0382 - val_loss: 85.7260 - val_mean_absolute_percentage_error: 85.7260
# Epoch 93/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.8623 - mean_absolute_percentage_error: 9.8623 - val_loss: 82.9570 - val_mean_absolute_percentage_error: 82.9570
# Epoch 94/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.3695 - mean_absolute_percentage_error: 9.3695 - val_loss: 84.2455 - val_mean_absolute_percentage_error: 84.2455
# Epoch 95/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 8.9752 - mean_absolute_percentage_error: 8.9752 - val_loss: 85.7521 - val_mean_absolute_percentage_error: 85.7521
# Epoch 96/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 8.9009 - mean_absolute_percentage_error: 8.9009 - val_loss: 85.5903 - val_mean_absolute_percentage_error: 85.5903
# Epoch 97/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 8.3510 - mean_absolute_percentage_error: 8.3510 - val_loss: 83.6889 - val_mean_absolute_percentage_error: 83.6889
# Epoch 98/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 7.8657 - mean_absolute_percentage_error: 7.8657 - val_loss: 83.8075 - val_mean_absolute_percentage_error: 83.8075
# Epoch 99/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 7.7198 - mean_absolute_percentage_error: 7.7198 - val_loss: 86.4587 - val_mean_absolute_percentage_error: 86.4587
# Epoch 100/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 7.7368 - mean_absolute_percentage_error: 7.7368 - val_loss: 83.5996 - val_mean_absolute_percentage_error: 83.5996
# 2024-01-24 01:30:52.759450: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_173/BiasAdd' id:21794 op device:{requested: '', assigned: ''} def:{{{node dense_173/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_173/MatMul, dense_173/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 83.60%
# Time Elapsed: 26123.592351198196

# %%
#3 Layer All ELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model1 = Sequential()

# . . . 
# Convolutional and Pooling Layers
model1.add(Conv2D(32, (3, 3), activation='elu', input_shape=(64, 64, 3)))
model1.add(MaxPooling2D((2, 2)))
model1.add(Conv2D(64, (3, 3), activation='elu'))
model1.add(MaxPooling2D((2, 2)))
model1.add(Conv2D(128, (3, 3), activation='elu'))
model1.add(MaxPooling2D((2, 2)))

# Flatten Layer
model1.add(Flatten())
# Fully Connected Layers
model1.add(Dense(128, activation='elu'))
model1.add(Dense(64, activation='elu'))

# Output Layer
model1.add(Dense(1, activation='linear'))  # Assuming house price prediction, use linear activation
# . . . . 

model1.summary()
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model1.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history1 = model1.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history1.history['loss'], label='Training Loss', color='green')
plt.plot(history1.history['val_loss'], label='Validation Loss', color='red')

plt.title('3 Layer ELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('3 Layer ELU.png')
plt.show()

#-----

prices_predicted = model1.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# Model: "sequential_86"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_245 (Conv2D)         (None, 62, 62, 32)        896
#
#  max_pooling2d_180 (MaxPooli  (None, 31, 31, 32)       0
#  ng2D)
#
#  conv2d_246 (Conv2D)         (None, 29, 29, 64)        18496
#
#  max_pooling2d_181 (MaxPooli  (None, 14, 14, 64)       0
#  ng2D)
#
#  conv2d_247 (Conv2D)         (None, 12, 12, 128)       73856
#
#  max_pooling2d_182 (MaxPooli  (None, 6, 6, 128)        0
#  ng2D)
#
#  flatten_78 (Flatten)        (None, 4608)              0
#
#  dense_174 (Dense)           (None, 128)               589952
#
#  dense_175 (Dense)           (None, 64)                8256
#
#  dense_176 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 691,521
# Trainable params: 691,521
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 01:30:54.389306: W tensorflow/c/c_api.cc:300] Operation '{name:'training_62/Adam/learning_rate/Assign' id:22556 op device:{requested: '', assigned: ''} def:{{{node training_62/Adam/learning_rate/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_62/Adam/learning_rate, training_62/Adam/learning_rate/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 416/428 [============================>.] - ETA: 0s - loss: 2715.5160 - mean_absolute_percentage_error: 2715.5159
# 2024-01-24 01:30:56.221429: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_39/mul' id:22411 op device:{requested: '', assigned: ''} def:{{{node loss_39/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_39/mul/x, loss_39/dense_176_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 2s 4ms/sample - loss: 2651.2961 - mean_absolute_percentage_error: 2651.2961 - val_loss: 595.4984 - val_mean_absolute_percentage_error: 595.4985
# Epoch 2/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 307.1876 - mean_absolute_percentage_error: 307.1876 - val_loss: 495.5960 - val_mean_absolute_percentage_error: 495.5959
# Epoch 3/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 251.6682 - mean_absolute_percentage_error: 251.6682 - val_loss: 97.7845 - val_mean_absolute_percentage_error: 97.7845
# Epoch 4/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 163.6272 - mean_absolute_percentage_error: 163.6272 - val_loss: 65.8830 - val_mean_absolute_percentage_error: 65.8830
# Epoch 5/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 173.5715 - mean_absolute_percentage_error: 173.5715 - val_loss: 224.5581 - val_mean_absolute_percentage_error: 224.5581
# Epoch 6/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 221.1572 - mean_absolute_percentage_error: 221.1572 - val_loss: 96.0789 - val_mean_absolute_percentage_error: 96.0789
# Epoch 7/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 96.6721 - mean_absolute_percentage_error: 96.6721 - val_loss: 63.8317 - val_mean_absolute_percentage_error: 63.8317
# Epoch 8/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 105.6626 - mean_absolute_percentage_error: 105.6626 - val_loss: 86.5079 - val_mean_absolute_percentage_error: 86.5079
# Epoch 9/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 106.7873 - mean_absolute_percentage_error: 106.7873 - val_loss: 69.6211 - val_mean_absolute_percentage_error: 69.6211
# Epoch 10/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 82.2139 - mean_absolute_percentage_error: 82.2139 - val_loss: 94.6904 - val_mean_absolute_percentage_error: 94.6904
# Epoch 11/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 95.8406 - mean_absolute_percentage_error: 95.8406 - val_loss: 154.8537 - val_mean_absolute_percentage_error: 154.8537
# Epoch 12/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 115.0477 - mean_absolute_percentage_error: 115.0477 - val_loss: 100.8276 - val_mean_absolute_percentage_error: 100.8276
# Epoch 13/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 140.5389 - mean_absolute_percentage_error: 140.5389 - val_loss: 223.9438 - val_mean_absolute_percentage_error: 223.9438
# Epoch 14/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 175.8906 - mean_absolute_percentage_error: 175.8906 - val_loss: 82.9769 - val_mean_absolute_percentage_error: 82.9769
# Epoch 15/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 133.6650 - mean_absolute_percentage_error: 133.6650 - val_loss: 79.2343 - val_mean_absolute_percentage_error: 79.2343
# Epoch 16/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 78.4457 - mean_absolute_percentage_error: 78.4457 - val_loss: 102.2886 - val_mean_absolute_percentage_error: 102.2887
# Epoch 17/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 76.6168 - mean_absolute_percentage_error: 76.6168 - val_loss: 69.2248 - val_mean_absolute_percentage_error: 69.2248
# Epoch 18/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 70.9938 - mean_absolute_percentage_error: 70.9938 - val_loss: 57.2854 - val_mean_absolute_percentage_error: 57.2854
# Epoch 19/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 65.7101 - mean_absolute_percentage_error: 65.7101 - val_loss: 79.7124 - val_mean_absolute_percentage_error: 79.7124
# Epoch 20/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 66.3663 - mean_absolute_percentage_error: 66.3663 - val_loss: 61.7929 - val_mean_absolute_percentage_error: 61.7929
# Epoch 21/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 53.7744 - mean_absolute_percentage_error: 53.7744 - val_loss: 221.4443 - val_mean_absolute_percentage_error: 221.4444
# Epoch 22/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 197.0359 - mean_absolute_percentage_error: 197.0359 - val_loss: 76.5995 - val_mean_absolute_percentage_error: 76.5995
# Epoch 23/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 81.3490 - mean_absolute_percentage_error: 81.3490 - val_loss: 84.3457 - val_mean_absolute_percentage_error: 84.3457
# Epoch 24/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 68.7249 - mean_absolute_percentage_error: 68.7249 - val_loss: 81.4080 - val_mean_absolute_percentage_error: 81.4080
# Epoch 25/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 67.7281 - mean_absolute_percentage_error: 67.7281 - val_loss: 68.1548 - val_mean_absolute_percentage_error: 68.1548
# Epoch 26/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 99.4134 - mean_absolute_percentage_error: 99.4135 - val_loss: 100.8208 - val_mean_absolute_percentage_error: 100.8208
# Epoch 27/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 73.1338 - mean_absolute_percentage_error: 73.1338 - val_loss: 55.8201 - val_mean_absolute_percentage_error: 55.8201
# Epoch 28/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 60.7190 - mean_absolute_percentage_error: 60.7190 - val_loss: 54.3955 - val_mean_absolute_percentage_error: 54.3955
# Epoch 29/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 49.0686 - mean_absolute_percentage_error: 49.0686 - val_loss: 54.9279 - val_mean_absolute_percentage_error: 54.9279
# Epoch 30/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 47.5961 - mean_absolute_percentage_error: 47.5961 - val_loss: 58.9893 - val_mean_absolute_percentage_error: 58.9893
# Epoch 31/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 45.8627 - mean_absolute_percentage_error: 45.8627 - val_loss: 59.0401 - val_mean_absolute_percentage_error: 59.0401
# Epoch 32/100
# 428/428 [==============================] - 2s 6ms/sample - loss: 42.4248 - mean_absolute_percentage_error: 42.4248 - val_loss: 52.2349 - val_mean_absolute_percentage_error: 52.2349
# Epoch 33/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 48.3000 - mean_absolute_percentage_error: 48.3000 - val_loss: 60.3321 - val_mean_absolute_percentage_error: 60.3321
# Epoch 34/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 44.9228 - mean_absolute_percentage_error: 44.9228 - val_loss: 91.1107 - val_mean_absolute_percentage_error: 91.1107
# Epoch 35/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 56.8212 - mean_absolute_percentage_error: 56.8212 - val_loss: 55.5140 - val_mean_absolute_percentage_error: 55.5140
# Epoch 36/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 39.9781 - mean_absolute_percentage_error: 39.9781 - val_loss: 68.7109 - val_mean_absolute_percentage_error: 68.7109
# Epoch 37/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 43.2223 - mean_absolute_percentage_error: 43.2223 - val_loss: 71.2552 - val_mean_absolute_percentage_error: 71.2552
# Epoch 38/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.1551 - mean_absolute_percentage_error: 40.1551 - val_loss: 68.8381 - val_mean_absolute_percentage_error: 68.8381
# Epoch 39/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 33.0750 - mean_absolute_percentage_error: 33.0750 - val_loss: 74.7223 - val_mean_absolute_percentage_error: 74.7223
# Epoch 40/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 33.7182 - mean_absolute_percentage_error: 33.7182 - val_loss: 56.5984 - val_mean_absolute_percentage_error: 56.5984
# Epoch 41/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 44.0386 - mean_absolute_percentage_error: 44.0386 - val_loss: 58.7173 - val_mean_absolute_percentage_error: 58.7173
# Epoch 42/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 42.6274 - mean_absolute_percentage_error: 42.6274 - val_loss: 76.4401 - val_mean_absolute_percentage_error: 76.4401
# Epoch 43/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 46.1019 - mean_absolute_percentage_error: 46.1019 - val_loss: 73.5011 - val_mean_absolute_percentage_error: 73.5011
# Epoch 44/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 36.5256 - mean_absolute_percentage_error: 36.5256 - val_loss: 55.7657 - val_mean_absolute_percentage_error: 55.7657
# Epoch 45/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 34.5484 - mean_absolute_percentage_error: 34.5484 - val_loss: 76.1144 - val_mean_absolute_percentage_error: 76.1144
# Epoch 46/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 43.6104 - mean_absolute_percentage_error: 43.6104 - val_loss: 86.6800 - val_mean_absolute_percentage_error: 86.6800
# Epoch 47/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.8446 - mean_absolute_percentage_error: 40.8446 - val_loss: 71.9312 - val_mean_absolute_percentage_error: 71.9312
# Epoch 48/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.0927 - mean_absolute_percentage_error: 32.0927 - val_loss: 69.1824 - val_mean_absolute_percentage_error: 69.1824
# Epoch 49/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.9624 - mean_absolute_percentage_error: 31.9624 - val_loss: 72.7010 - val_mean_absolute_percentage_error: 72.7010
# Epoch 50/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.5432 - mean_absolute_percentage_error: 30.5433 - val_loss: 82.4441 - val_mean_absolute_percentage_error: 82.4441
# Epoch 51/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.3500 - mean_absolute_percentage_error: 31.3500 - val_loss: 72.3020 - val_mean_absolute_percentage_error: 72.3020
# Epoch 52/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.2532 - mean_absolute_percentage_error: 30.2532 - val_loss: 65.8605 - val_mean_absolute_percentage_error: 65.8605
# Epoch 53/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 33.2430 - mean_absolute_percentage_error: 33.2430 - val_loss: 62.0052 - val_mean_absolute_percentage_error: 62.0052
# Epoch 54/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 29.9172 - mean_absolute_percentage_error: 29.9172 - val_loss: 60.4626 - val_mean_absolute_percentage_error: 60.4626
# Epoch 55/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.6107 - mean_absolute_percentage_error: 31.6107 - val_loss: 70.6401 - val_mean_absolute_percentage_error: 70.6401
# Epoch 56/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 29.4862 - mean_absolute_percentage_error: 29.4863 - val_loss: 70.8661 - val_mean_absolute_percentage_error: 70.8661
# Epoch 57/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 31.1492 - mean_absolute_percentage_error: 31.1492 - val_loss: 65.9583 - val_mean_absolute_percentage_error: 65.9583
# Epoch 58/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 32.3722 - mean_absolute_percentage_error: 32.3722 - val_loss: 81.5909 - val_mean_absolute_percentage_error: 81.5909
# Epoch 59/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.6202 - mean_absolute_percentage_error: 31.6202 - val_loss: 70.3141 - val_mean_absolute_percentage_error: 70.3140
# Epoch 60/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 26.9801 - mean_absolute_percentage_error: 26.9801 - val_loss: 65.6210 - val_mean_absolute_percentage_error: 65.6210
# Epoch 61/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 30.4595 - mean_absolute_percentage_error: 30.4595 - val_loss: 62.5604 - val_mean_absolute_percentage_error: 62.5604
# Epoch 62/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.5610 - mean_absolute_percentage_error: 31.5610 - val_loss: 73.7911 - val_mean_absolute_percentage_error: 73.7911
# Epoch 63/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 28.4953 - mean_absolute_percentage_error: 28.4953 - val_loss: 76.4907 - val_mean_absolute_percentage_error: 76.4908
# Epoch 64/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 25.8009 - mean_absolute_percentage_error: 25.8009 - val_loss: 67.2390 - val_mean_absolute_percentage_error: 67.2390
# Epoch 65/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.8330 - mean_absolute_percentage_error: 28.8330 - val_loss: 62.1218 - val_mean_absolute_percentage_error: 62.1218
# Epoch 66/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.5260 - mean_absolute_percentage_error: 28.5260 - val_loss: 70.5209 - val_mean_absolute_percentage_error: 70.5209
# Epoch 67/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 24.0236 - mean_absolute_percentage_error: 24.0236 - val_loss: 72.5401 - val_mean_absolute_percentage_error: 72.5401
# Epoch 68/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.3618 - mean_absolute_percentage_error: 24.3618 - val_loss: 67.6617 - val_mean_absolute_percentage_error: 67.6617
# Epoch 69/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 26.0346 - mean_absolute_percentage_error: 26.0346 - val_loss: 73.5272 - val_mean_absolute_percentage_error: 73.5272
# Epoch 70/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.9184 - mean_absolute_percentage_error: 30.9184 - val_loss: 72.7711 - val_mean_absolute_percentage_error: 72.7711
# Epoch 71/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.6350 - mean_absolute_percentage_error: 23.6350 - val_loss: 70.7173 - val_mean_absolute_percentage_error: 70.7173
# Epoch 72/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.8923 - mean_absolute_percentage_error: 24.8923 - val_loss: 70.0775 - val_mean_absolute_percentage_error: 70.0775
# Epoch 73/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.5284 - mean_absolute_percentage_error: 23.5284 - val_loss: 69.4577 - val_mean_absolute_percentage_error: 69.4577
# Epoch 74/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.4089 - mean_absolute_percentage_error: 24.4089 - val_loss: 66.2806 - val_mean_absolute_percentage_error: 66.2806
# Epoch 75/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 22.7966 - mean_absolute_percentage_error: 22.7966 - val_loss: 62.8080 - val_mean_absolute_percentage_error: 62.8080
# Epoch 76/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 27.6221 - mean_absolute_percentage_error: 27.6221 - val_loss: 76.1509 - val_mean_absolute_percentage_error: 76.1509
# Epoch 77/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.1049 - mean_absolute_percentage_error: 24.1049 - val_loss: 75.0255 - val_mean_absolute_percentage_error: 75.0255
# Epoch 78/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.9193 - mean_absolute_percentage_error: 22.9193 - val_loss: 70.5221 - val_mean_absolute_percentage_error: 70.5221
# Epoch 79/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 21.5095 - mean_absolute_percentage_error: 21.5095 - val_loss: 72.5338 - val_mean_absolute_percentage_error: 72.5338
# Epoch 80/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.2195 - mean_absolute_percentage_error: 24.2195 - val_loss: 62.5857 - val_mean_absolute_percentage_error: 62.5857
# Epoch 81/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 29.1396 - mean_absolute_percentage_error: 29.1396 - val_loss: 80.0722 - val_mean_absolute_percentage_error: 80.0722
# Epoch 82/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.6871 - mean_absolute_percentage_error: 28.6871 - val_loss: 78.8805 - val_mean_absolute_percentage_error: 78.8805
# Epoch 83/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.5954 - mean_absolute_percentage_error: 24.5954 - val_loss: 73.7775 - val_mean_absolute_percentage_error: 73.7775
# Epoch 84/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.4483 - mean_absolute_percentage_error: 23.4483 - val_loss: 61.8495 - val_mean_absolute_percentage_error: 61.8495
# Epoch 85/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 26.1509 - mean_absolute_percentage_error: 26.1509 - val_loss: 67.7867 - val_mean_absolute_percentage_error: 67.7867
# Epoch 86/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.1330 - mean_absolute_percentage_error: 23.1330 - val_loss: 71.0558 - val_mean_absolute_percentage_error: 71.0558
# Epoch 87/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.9503 - mean_absolute_percentage_error: 20.9503 - val_loss: 69.5302 - val_mean_absolute_percentage_error: 69.5302
# Epoch 88/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.5999 - mean_absolute_percentage_error: 22.5999 - val_loss: 70.5910 - val_mean_absolute_percentage_error: 70.5910
# Epoch 89/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 18.8622 - mean_absolute_percentage_error: 18.8622 - val_loss: 67.9993 - val_mean_absolute_percentage_error: 67.9993
# Epoch 90/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.5143 - mean_absolute_percentage_error: 20.5143 - val_loss: 72.4974 - val_mean_absolute_percentage_error: 72.4974
# Epoch 91/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.3500 - mean_absolute_percentage_error: 20.3500 - val_loss: 78.6223 - val_mean_absolute_percentage_error: 78.6223
# Epoch 92/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.1875 - mean_absolute_percentage_error: 20.1875 - val_loss: 69.8349 - val_mean_absolute_percentage_error: 69.8349
# Epoch 93/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 24.7522 - mean_absolute_percentage_error: 24.7522 - val_loss: 73.6025 - val_mean_absolute_percentage_error: 73.6025
# Epoch 94/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.7779 - mean_absolute_percentage_error: 20.7779 - val_loss: 76.0863 - val_mean_absolute_percentage_error: 76.0863
# Epoch 95/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.3920 - mean_absolute_percentage_error: 20.3920 - val_loss: 69.3269 - val_mean_absolute_percentage_error: 69.3269
# Epoch 96/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.2302 - mean_absolute_percentage_error: 16.2302 - val_loss: 75.9127 - val_mean_absolute_percentage_error: 75.9127
# Epoch 97/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 21.3943 - mean_absolute_percentage_error: 21.3943 - val_loss: 64.3706 - val_mean_absolute_percentage_error: 64.3706
# Epoch 98/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.6561 - mean_absolute_percentage_error: 22.6561 - val_loss: 84.5696 - val_mean_absolute_percentage_error: 84.5696
# Epoch 99/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 23.1648 - mean_absolute_percentage_error: 23.1648 - val_loss: 68.0466 - val_mean_absolute_percentage_error: 68.0466
# Epoch 100/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.0783 - mean_absolute_percentage_error: 20.0783 - val_loss: 77.3123 - val_mean_absolute_percentage_error: 77.3123
# 2024-01-24 01:32:33.610195: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_176/BiasAdd' id:22354 op device:{requested: '', assigned: ''} def:{{{node dense_176/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_176/MatMul, dense_176/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 77.31%
# Time Elapsed: 26224.442884922028

# %%
#2 Layer All ELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model3 = Sequential()

# . . . 
# Convolutional and Pooling Layers
model3.add(Conv2D(32, (3, 3), activation='elu', input_shape=(64, 64, 3)))
model3.add(MaxPooling2D((2, 2)))
model3.add(Conv2D(128, (3, 3), activation='elu'))
model3.add(MaxPooling2D((2, 2)))

# Flatten Layer
model3.add(Flatten())
# Fully Connected Layers
model3.add(Dense(128, activation='elu'))
model3.add(Dense(64, activation='elu'))

# Output Layer
model3.add(Dense(1, activation='linear'))  # Assuming house price prediction, use linear activation
# . . . . 

model3.summary()
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model3.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history3 = model3.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history3.history['loss'], label='Training Loss', color='green')
plt.plot(history3.history['val_loss'], label='Validation Loss', color='red')

plt.title('2 Layer ELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('2 Layer ELU.png')
plt.show()

#-----

prices_predicted = model3.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# Model: "sequential_87"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_248 (Conv2D)         (None, 62, 62, 32)        896
#
#  max_pooling2d_183 (MaxPooli  (None, 31, 31, 32)       0
#  ng2D)
#
#  conv2d_249 (Conv2D)         (None, 29, 29, 128)       36992
#
#  max_pooling2d_184 (MaxPooli  (None, 14, 14, 128)      0
#  ng2D)
#
#  flatten_79 (Flatten)        (None, 25088)             0
#
#  dense_177 (Dense)           (None, 128)               3211392
#
#  dense_178 (Dense)           (None, 64)                8256
#
#  dense_179 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 3,257,601
# Trainable params: 3,257,601
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 01:32:35.408717: W tensorflow/c/c_api.cc:300] Operation '{name:'total_40/Assign' id:22934 op device:{requested: '', assigned: ''} def:{{{node total_40/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](total_40, total_40/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 416/428 [============================>.] - ETA: 0s - loss: 5689.2970 - mean_absolute_percentage_error: 5689.2969
# 2024-01-24 01:32:37.630256: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_40/mul' id:22986 op device:{requested: '', assigned: ''} def:{{{node loss_40/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_40/mul/x, loss_40/dense_179_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 2s 5ms/sample - loss: 5564.2214 - mean_absolute_percentage_error: 5564.2212 - val_loss: 746.8562 - val_mean_absolute_percentage_error: 746.8563
# Epoch 2/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 564.9985 - mean_absolute_percentage_error: 564.9985 - val_loss: 340.4989 - val_mean_absolute_percentage_error: 340.4989
# Epoch 3/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 324.9472 - mean_absolute_percentage_error: 324.9472 - val_loss: 481.4497 - val_mean_absolute_percentage_error: 481.4497
# Epoch 4/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 396.5624 - mean_absolute_percentage_error: 396.5624 - val_loss: 154.3236 - val_mean_absolute_percentage_error: 154.3236
# Epoch 5/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 171.1263 - mean_absolute_percentage_error: 171.1263 - val_loss: 101.9505 - val_mean_absolute_percentage_error: 101.9505
# Epoch 6/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 135.5678 - mean_absolute_percentage_error: 135.5678 - val_loss: 182.3064 - val_mean_absolute_percentage_error: 182.3064
# Epoch 7/100
# 428/428 [==============================] - 3s 6ms/sample - loss: 152.0322 - mean_absolute_percentage_error: 152.0322 - val_loss: 147.1910 - val_mean_absolute_percentage_error: 147.1910
# Epoch 8/100
# 428/428 [==============================] - 2s 4ms/sample - loss: 153.0715 - mean_absolute_percentage_error: 153.0715 - val_loss: 96.3821 - val_mean_absolute_percentage_error: 96.3821
# Epoch 9/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 154.0160 - mean_absolute_percentage_error: 154.0160 - val_loss: 68.9172 - val_mean_absolute_percentage_error: 68.9172
# Epoch 10/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 100.4214 - mean_absolute_percentage_error: 100.4214 - val_loss: 54.2989 - val_mean_absolute_percentage_error: 54.2989
# Epoch 11/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 86.4438 - mean_absolute_percentage_error: 86.4438 - val_loss: 84.6970 - val_mean_absolute_percentage_error: 84.6970
# Epoch 12/100
# 428/428 [==============================] - 2s 4ms/sample - loss: 79.4588 - mean_absolute_percentage_error: 79.4588 - val_loss: 149.9783 - val_mean_absolute_percentage_error: 149.9783
# Epoch 13/100
# 428/428 [==============================] - 2s 4ms/sample - loss: 133.0271 - mean_absolute_percentage_error: 133.0271 - val_loss: 97.7925 - val_mean_absolute_percentage_error: 97.7924
# Epoch 14/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 169.8488 - mean_absolute_percentage_error: 169.8488 - val_loss: 204.0705 - val_mean_absolute_percentage_error: 204.0705
# Epoch 15/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 148.4994 - mean_absolute_percentage_error: 148.4994 - val_loss: 172.9041 - val_mean_absolute_percentage_error: 172.9041
# Epoch 16/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 188.3486 - mean_absolute_percentage_error: 188.3486 - val_loss: 320.8538 - val_mean_absolute_percentage_error: 320.8538
# Epoch 17/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 153.1350 - mean_absolute_percentage_error: 153.1350 - val_loss: 187.3381 - val_mean_absolute_percentage_error: 187.3381
# Epoch 18/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 164.3320 - mean_absolute_percentage_error: 164.3320 - val_loss: 96.0059 - val_mean_absolute_percentage_error: 96.0059
# Epoch 19/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 80.9313 - mean_absolute_percentage_error: 80.9313 - val_loss: 62.9985 - val_mean_absolute_percentage_error: 62.9985
# Epoch 20/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 81.8802 - mean_absolute_percentage_error: 81.8801 - val_loss: 109.6496 - val_mean_absolute_percentage_error: 109.6496
# Epoch 21/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 212.0341 - mean_absolute_percentage_error: 212.0341 - val_loss: 73.3907 - val_mean_absolute_percentage_error: 73.3907
# Epoch 22/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 151.1368 - mean_absolute_percentage_error: 151.1368 - val_loss: 145.4571 - val_mean_absolute_percentage_error: 145.4571
# Epoch 23/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 95.6918 - mean_absolute_percentage_error: 95.6918 - val_loss: 99.7452 - val_mean_absolute_percentage_error: 99.7452
# Epoch 24/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 130.1224 - mean_absolute_percentage_error: 130.1224 - val_loss: 61.0827 - val_mean_absolute_percentage_error: 61.0827
# Epoch 25/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 130.3637 - mean_absolute_percentage_error: 130.3637 - val_loss: 63.8998 - val_mean_absolute_percentage_error: 63.8998
# Epoch 26/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 99.3532 - mean_absolute_percentage_error: 99.3531 - val_loss: 152.0331 - val_mean_absolute_percentage_error: 152.0331
# Epoch 27/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 159.1075 - mean_absolute_percentage_error: 159.1075 - val_loss: 68.6399 - val_mean_absolute_percentage_error: 68.6399
# Epoch 28/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 174.2654 - mean_absolute_percentage_error: 174.2654 - val_loss: 67.4574 - val_mean_absolute_percentage_error: 67.4574
# Epoch 29/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 135.6404 - mean_absolute_percentage_error: 135.6404 - val_loss: 124.6841 - val_mean_absolute_percentage_error: 124.6841
# Epoch 30/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 74.4381 - mean_absolute_percentage_error: 74.4381 - val_loss: 84.3284 - val_mean_absolute_percentage_error: 84.3284
# Epoch 31/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 74.8219 - mean_absolute_percentage_error: 74.8219 - val_loss: 82.0660 - val_mean_absolute_percentage_error: 82.0660
# Epoch 32/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 110.5646 - mean_absolute_percentage_error: 110.5646 - val_loss: 172.4321 - val_mean_absolute_percentage_error: 172.4322
# Epoch 33/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 116.9353 - mean_absolute_percentage_error: 116.9353 - val_loss: 129.9160 - val_mean_absolute_percentage_error: 129.9160
# Epoch 34/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 119.0554 - mean_absolute_percentage_error: 119.0554 - val_loss: 79.8398 - val_mean_absolute_percentage_error: 79.8398
# Epoch 35/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 89.1874 - mean_absolute_percentage_error: 89.1874 - val_loss: 89.7429 - val_mean_absolute_percentage_error: 89.7429
# Epoch 36/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 118.4336 - mean_absolute_percentage_error: 118.4336 - val_loss: 141.4460 - val_mean_absolute_percentage_error: 141.4460
# Epoch 37/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 163.2170 - mean_absolute_percentage_error: 163.2170 - val_loss: 180.6208 - val_mean_absolute_percentage_error: 180.6208
# Epoch 38/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 96.8981 - mean_absolute_percentage_error: 96.8981 - val_loss: 58.8203 - val_mean_absolute_percentage_error: 58.8203
# Epoch 39/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 73.0873 - mean_absolute_percentage_error: 73.0873 - val_loss: 110.3862 - val_mean_absolute_percentage_error: 110.3862
# Epoch 40/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 105.5575 - mean_absolute_percentage_error: 105.5575 - val_loss: 81.1960 - val_mean_absolute_percentage_error: 81.1960
# Epoch 41/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 79.5338 - mean_absolute_percentage_error: 79.5339 - val_loss: 56.1699 - val_mean_absolute_percentage_error: 56.1699
# Epoch 42/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 48.7822 - mean_absolute_percentage_error: 48.7822 - val_loss: 77.1534 - val_mean_absolute_percentage_error: 77.1534
# Epoch 43/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 63.6607 - mean_absolute_percentage_error: 63.6607 - val_loss: 65.1242 - val_mean_absolute_percentage_error: 65.1242
# Epoch 44/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 67.7528 - mean_absolute_percentage_error: 67.7528 - val_loss: 93.2961 - val_mean_absolute_percentage_error: 93.2961
# Epoch 45/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 62.6247 - mean_absolute_percentage_error: 62.6247 - val_loss: 65.4824 - val_mean_absolute_percentage_error: 65.4824
# Epoch 46/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 145.5409 - mean_absolute_percentage_error: 145.5409 - val_loss: 60.1638 - val_mean_absolute_percentage_error: 60.1638
# Epoch 47/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 143.5117 - mean_absolute_percentage_error: 143.5117 - val_loss: 132.0317 - val_mean_absolute_percentage_error: 132.0317
# Epoch 48/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 133.8833 - mean_absolute_percentage_error: 133.8833 - val_loss: 67.8258 - val_mean_absolute_percentage_error: 67.8258
# Epoch 49/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 119.3014 - mean_absolute_percentage_error: 119.3014 - val_loss: 61.8217 - val_mean_absolute_percentage_error: 61.8217
# Epoch 50/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 121.2730 - mean_absolute_percentage_error: 121.2730 - val_loss: 68.3835 - val_mean_absolute_percentage_error: 68.3835
# Epoch 51/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 133.0131 - mean_absolute_percentage_error: 133.0131 - val_loss: 94.7262 - val_mean_absolute_percentage_error: 94.7262
# Epoch 52/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 60.9907 - mean_absolute_percentage_error: 60.9907 - val_loss: 77.5016 - val_mean_absolute_percentage_error: 77.5016
# Epoch 53/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 64.3101 - mean_absolute_percentage_error: 64.3101 - val_loss: 61.6234 - val_mean_absolute_percentage_error: 61.6234
# Epoch 54/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 122.2762 - mean_absolute_percentage_error: 122.2762 - val_loss: 87.6189 - val_mean_absolute_percentage_error: 87.6189
# Epoch 55/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 166.0460 - mean_absolute_percentage_error: 166.0460 - val_loss: 57.8697 - val_mean_absolute_percentage_error: 57.8697
# Epoch 56/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 98.3006 - mean_absolute_percentage_error: 98.3006 - val_loss: 60.5896 - val_mean_absolute_percentage_error: 60.5896
# Epoch 57/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 67.8013 - mean_absolute_percentage_error: 67.8013 - val_loss: 136.6376 - val_mean_absolute_percentage_error: 136.6376
# Epoch 58/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 101.7969 - mean_absolute_percentage_error: 101.7969 - val_loss: 58.4074 - val_mean_absolute_percentage_error: 58.4074
# Epoch 59/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 140.5059 - mean_absolute_percentage_error: 140.5059 - val_loss: 162.1598 - val_mean_absolute_percentage_error: 162.1598
# Epoch 60/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 147.7900 - mean_absolute_percentage_error: 147.7900 - val_loss: 59.6463 - val_mean_absolute_percentage_error: 59.6463
# Epoch 61/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 83.7740 - mean_absolute_percentage_error: 83.7740 - val_loss: 103.1419 - val_mean_absolute_percentage_error: 103.1419
# Epoch 62/100
# 428/428 [==============================] - 2s 4ms/sample - loss: 49.2784 - mean_absolute_percentage_error: 49.2784 - val_loss: 57.3367 - val_mean_absolute_percentage_error: 57.3367
# Epoch 63/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 87.2339 - mean_absolute_percentage_error: 87.2339 - val_loss: 167.8132 - val_mean_absolute_percentage_error: 167.8132
# Epoch 64/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 83.5500 - mean_absolute_percentage_error: 83.5500 - val_loss: 124.5330 - val_mean_absolute_percentage_error: 124.5330
# Epoch 65/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 84.4717 - mean_absolute_percentage_error: 84.4717 - val_loss: 114.0729 - val_mean_absolute_percentage_error: 114.0729
# Epoch 66/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 80.2751 - mean_absolute_percentage_error: 80.2751 - val_loss: 58.2847 - val_mean_absolute_percentage_error: 58.2847
# Epoch 67/100
# 428/428 [==============================] - 2s 4ms/sample - loss: 54.7786 - mean_absolute_percentage_error: 54.7786 - val_loss: 58.3825 - val_mean_absolute_percentage_error: 58.3825
# Epoch 68/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 60.1747 - mean_absolute_percentage_error: 60.1747 - val_loss: 63.4771 - val_mean_absolute_percentage_error: 63.4771
# Epoch 69/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 54.5492 - mean_absolute_percentage_error: 54.5492 - val_loss: 70.2304 - val_mean_absolute_percentage_error: 70.2304
# Epoch 70/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 43.6338 - mean_absolute_percentage_error: 43.6338 - val_loss: 65.6294 - val_mean_absolute_percentage_error: 65.6294
# Epoch 71/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 50.7682 - mean_absolute_percentage_error: 50.7682 - val_loss: 60.3958 - val_mean_absolute_percentage_error: 60.3958
# Epoch 72/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 72.2285 - mean_absolute_percentage_error: 72.2285 - val_loss: 54.5003 - val_mean_absolute_percentage_error: 54.5003
# Epoch 73/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 60.5906 - mean_absolute_percentage_error: 60.5906 - val_loss: 67.0490 - val_mean_absolute_percentage_error: 67.0490
# Epoch 74/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 80.7585 - mean_absolute_percentage_error: 80.7585 - val_loss: 62.4324 - val_mean_absolute_percentage_error: 62.4324
# Epoch 75/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 88.4486 - mean_absolute_percentage_error: 88.4486 - val_loss: 125.3538 - val_mean_absolute_percentage_error: 125.3538
# Epoch 76/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 69.5817 - mean_absolute_percentage_error: 69.5817 - val_loss: 68.2211 - val_mean_absolute_percentage_error: 68.2211
# Epoch 77/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 69.0332 - mean_absolute_percentage_error: 69.0332 - val_loss: 64.3834 - val_mean_absolute_percentage_error: 64.3834
# Epoch 78/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 62.5788 - mean_absolute_percentage_error: 62.5788 - val_loss: 87.9846 - val_mean_absolute_percentage_error: 87.9846
# Epoch 79/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 62.7105 - mean_absolute_percentage_error: 62.7105 - val_loss: 187.2519 - val_mean_absolute_percentage_error: 187.2519
# Epoch 80/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 170.4110 - mean_absolute_percentage_error: 170.4110 - val_loss: 61.5326 - val_mean_absolute_percentage_error: 61.5326
# Epoch 81/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 127.8091 - mean_absolute_percentage_error: 127.8091 - val_loss: 67.8065 - val_mean_absolute_percentage_error: 67.8064
# Epoch 82/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 101.1167 - mean_absolute_percentage_error: 101.1167 - val_loss: 156.3646 - val_mean_absolute_percentage_error: 156.3646
# Epoch 83/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 201.6937 - mean_absolute_percentage_error: 201.6937 - val_loss: 65.6673 - val_mean_absolute_percentage_error: 65.6673
# Epoch 84/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 223.5861 - mean_absolute_percentage_error: 223.5861 - val_loss: 109.1053 - val_mean_absolute_percentage_error: 109.1053
# Epoch 85/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 210.8213 - mean_absolute_percentage_error: 210.8213 - val_loss: 312.4199 - val_mean_absolute_percentage_error: 312.4199
# Epoch 86/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 141.8451 - mean_absolute_percentage_error: 141.8451 - val_loss: 75.4002 - val_mean_absolute_percentage_error: 75.4002
# Epoch 87/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 69.8493 - mean_absolute_percentage_error: 69.8493 - val_loss: 64.2755 - val_mean_absolute_percentage_error: 64.2755
# Epoch 88/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 81.0323 - mean_absolute_percentage_error: 81.0323 - val_loss: 80.5400 - val_mean_absolute_percentage_error: 80.5400
# Epoch 89/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 92.4742 - mean_absolute_percentage_error: 92.4742 - val_loss: 97.5587 - val_mean_absolute_percentage_error: 97.5587
# Epoch 90/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 162.9983 - mean_absolute_percentage_error: 162.9983 - val_loss: 497.9009 - val_mean_absolute_percentage_error: 497.9009
# Epoch 91/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 199.8099 - mean_absolute_percentage_error: 199.8099 - val_loss: 77.4453 - val_mean_absolute_percentage_error: 77.4454
# Epoch 92/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 61.3991 - mean_absolute_percentage_error: 61.3991 - val_loss: 60.3240 - val_mean_absolute_percentage_error: 60.3240
# Epoch 93/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 60.2992 - mean_absolute_percentage_error: 60.2992 - val_loss: 125.3085 - val_mean_absolute_percentage_error: 125.3085
# Epoch 94/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 79.4969 - mean_absolute_percentage_error: 79.4969 - val_loss: 52.2659 - val_mean_absolute_percentage_error: 52.2659
# Epoch 95/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 56.2382 - mean_absolute_percentage_error: 56.2382 - val_loss: 60.9086 - val_mean_absolute_percentage_error: 60.9086
# Epoch 96/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 127.8109 - mean_absolute_percentage_error: 127.8109 - val_loss: 71.6989 - val_mean_absolute_percentage_error: 71.6989
# Epoch 97/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 85.4168 - mean_absolute_percentage_error: 85.4168 - val_loss: 70.3758 - val_mean_absolute_percentage_error: 70.3758
# Epoch 98/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 103.1929 - mean_absolute_percentage_error: 103.1929 - val_loss: 74.2199 - val_mean_absolute_percentage_error: 74.2199
# Epoch 99/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 121.5694 - mean_absolute_percentage_error: 121.5694 - val_loss: 87.2205 - val_mean_absolute_percentage_error: 87.2205
# Epoch 100/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 91.5338 - mean_absolute_percentage_error: 91.5338 - val_loss: 51.9435 - val_mean_absolute_percentage_error: 51.9435
# 2024-01-24 01:34:34.925615: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_179/BiasAdd' id:22929 op device:{requested: '', assigned: ''} def:{{{node dense_179/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_179/MatMul, dense_179/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 51.94%
# Time Elapsed: 26345.765554189682

# %%
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history3.history['loss'], label='Training Loss', color='green')
plt.plot(history3.history['val_loss'], label='Validation Loss', color='red')

plt.title('2 Layer ELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0,600)
plt.legend()
plt.savefig('2 Layer ELU.png')
plt.show()

# %%
#ML Best  Layer All ELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1


# . . . 
# Convolutional and Pooling Layers
model4 = Sequential()
model4.add(Conv2D(32, (3, 3), activation='elu', input_shape=(64, 64, 3)))
model4.add(Conv2D(32, (3, 3), activation='elu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(64, (3, 3), activation='elu', padding='same'))
model4.add(Conv2D(64, (3, 3), activation='elu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
model4.add(MaxPooling2D((2, 2)))

model4.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
model4.add(Conv2D(128, (3, 3), activation='elu', padding='same'))


model4.add(Flatten())
model4.add(Dense(256, activation='elu'))

model4.add(Dense(1, activation='linear'))
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model4.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history4 = model4.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history4.history['loss'], label='Training Loss', color='green')
plt.plot(history4.history['val_loss'], label='Validation Loss', color='red')

plt.title('Previous Best ELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('Previous Best ELU.png')
plt.show()

#-----

prices_predicted = model4.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# /Users/hasnatchowdhury/opt/anaconda3/envs/machineLearning/lib/python3.10/site-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 13:00:11.883738: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_205/bias/Assign' id:29792 op device:{requested: '', assigned: ''} def:{{{node dense_205/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_205/bias, dense_205/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 428/428 [==============================] - ETA: 0s - loss: 4593.4710 - mean_absolute_percentage_error: 4593.4712
# /Users/hasnatchowdhury/opt/anaconda3/envs/machineLearning/lib/python3.10/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2024-01-24 13:00:21.322333: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_51/mul' id:29854 op device:{requested: '', assigned: ''} def:{{{node loss_51/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_51/mul/x, loss_51/dense_205_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 10s 23ms/sample - loss: 4593.4710 - mean_absolute_percentage_error: 4593.4712 - val_loss: 1392.7186 - val_mean_absolute_percentage_error: 1392.7188
# Epoch 2/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 2128.3437 - mean_absolute_percentage_error: 2128.3440 - val_loss: 83.3476 - val_mean_absolute_percentage_error: 83.3476
# Epoch 3/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 153.3521 - mean_absolute_percentage_error: 153.3521 - val_loss: 403.2981 - val_mean_absolute_percentage_error: 403.2981
# Epoch 4/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 157.3144 - mean_absolute_percentage_error: 157.3143 - val_loss: 118.2843 - val_mean_absolute_percentage_error: 118.2843
# Epoch 5/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 116.9740 - mean_absolute_percentage_error: 116.9740 - val_loss: 91.5347 - val_mean_absolute_percentage_error: 91.5347
# Epoch 6/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 91.7316 - mean_absolute_percentage_error: 91.7316 - val_loss: 71.5339 - val_mean_absolute_percentage_error: 71.5339
# Epoch 7/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 79.6889 - mean_absolute_percentage_error: 79.6889 - val_loss: 59.9248 - val_mean_absolute_percentage_error: 59.9248
# Epoch 8/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 63.4365 - mean_absolute_percentage_error: 63.4365 - val_loss: 59.6021 - val_mean_absolute_percentage_error: 59.6021
# Epoch 9/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 53.8044 - mean_absolute_percentage_error: 53.8044 - val_loss: 58.5186 - val_mean_absolute_percentage_error: 58.5186
# Epoch 10/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 51.7554 - mean_absolute_percentage_error: 51.7554 - val_loss: 56.4601 - val_mean_absolute_percentage_error: 56.4601
# Epoch 11/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 45.9150 - mean_absolute_percentage_error: 45.9150 - val_loss: 69.8157 - val_mean_absolute_percentage_error: 69.8157
# Epoch 12/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 60.4658 - mean_absolute_percentage_error: 60.4658 - val_loss: 56.3123 - val_mean_absolute_percentage_error: 56.3123
# Epoch 13/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 54.6144 - mean_absolute_percentage_error: 54.6144 - val_loss: 55.2291 - val_mean_absolute_percentage_error: 55.2291
# Epoch 14/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 58.1079 - mean_absolute_percentage_error: 58.1079 - val_loss: 61.6590 - val_mean_absolute_percentage_error: 61.6590
# Epoch 15/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 42.8668 - mean_absolute_percentage_error: 42.8668 - val_loss: 59.3838 - val_mean_absolute_percentage_error: 59.3838
# Epoch 16/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 44.9462 - mean_absolute_percentage_error: 44.9462 - val_loss: 62.6538 - val_mean_absolute_percentage_error: 62.6538
# Epoch 17/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 41.5669 - mean_absolute_percentage_error: 41.5668 - val_loss: 57.0649 - val_mean_absolute_percentage_error: 57.0649
# Epoch 18/100
# 428/428 [==============================] - 6s 15ms/sample - loss: 39.6067 - mean_absolute_percentage_error: 39.6067 - val_loss: 68.5210 - val_mean_absolute_percentage_error: 68.5210
# Epoch 19/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 38.6001 - mean_absolute_percentage_error: 38.6001 - val_loss: 58.4753 - val_mean_absolute_percentage_error: 58.4753
# Epoch 20/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 47.2851 - mean_absolute_percentage_error: 47.2851 - val_loss: 65.3343 - val_mean_absolute_percentage_error: 65.3343
# Epoch 21/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 43.1247 - mean_absolute_percentage_error: 43.1247 - val_loss: 55.6928 - val_mean_absolute_percentage_error: 55.6928
# Epoch 22/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 36.4763 - mean_absolute_percentage_error: 36.4763 - val_loss: 66.1903 - val_mean_absolute_percentage_error: 66.1903
# Epoch 23/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 39.8408 - mean_absolute_percentage_error: 39.8408 - val_loss: 64.5648 - val_mean_absolute_percentage_error: 64.5648
# Epoch 24/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 38.6223 - mean_absolute_percentage_error: 38.6223 - val_loss: 55.3338 - val_mean_absolute_percentage_error: 55.3338
# Epoch 25/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 41.0389 - mean_absolute_percentage_error: 41.0390 - val_loss: 66.8885 - val_mean_absolute_percentage_error: 66.8885
# Epoch 26/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 39.0248 - mean_absolute_percentage_error: 39.0248 - val_loss: 66.9532 - val_mean_absolute_percentage_error: 66.9532
# Epoch 27/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 37.8462 - mean_absolute_percentage_error: 37.8462 - val_loss: 61.8797 - val_mean_absolute_percentage_error: 61.8797
# Epoch 28/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 34.9991 - mean_absolute_percentage_error: 34.9991 - val_loss: 63.7190 - val_mean_absolute_percentage_error: 63.7190
# Epoch 29/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 43.8300 - mean_absolute_percentage_error: 43.8300 - val_loss: 65.3708 - val_mean_absolute_percentage_error: 65.3708
# Epoch 30/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 36.3498 - mean_absolute_percentage_error: 36.3498 - val_loss: 66.0584 - val_mean_absolute_percentage_error: 66.0584
# Epoch 31/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 37.3132 - mean_absolute_percentage_error: 37.3132 - val_loss: 62.0095 - val_mean_absolute_percentage_error: 62.0095
# Epoch 32/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 32.7916 - mean_absolute_percentage_error: 32.7916 - val_loss: 60.3095 - val_mean_absolute_percentage_error: 60.3095
# Epoch 33/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 35.5716 - mean_absolute_percentage_error: 35.5716 - val_loss: 71.8306 - val_mean_absolute_percentage_error: 71.8306
# Epoch 34/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 43.1414 - mean_absolute_percentage_error: 43.1414 - val_loss: 59.2116 - val_mean_absolute_percentage_error: 59.2116
# Epoch 35/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 38.9548 - mean_absolute_percentage_error: 38.9548 - val_loss: 69.6780 - val_mean_absolute_percentage_error: 69.6780
# Epoch 36/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 34.6315 - mean_absolute_percentage_error: 34.6315 - val_loss: 68.4987 - val_mean_absolute_percentage_error: 68.4987
# Epoch 37/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 33.0289 - mean_absolute_percentage_error: 33.0289 - val_loss: 73.3347 - val_mean_absolute_percentage_error: 73.3347
# Epoch 38/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 34.6603 - mean_absolute_percentage_error: 34.6603 - val_loss: 66.1224 - val_mean_absolute_percentage_error: 66.1224
# Epoch 39/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 33.6946 - mean_absolute_percentage_error: 33.6946 - val_loss: 63.5571 - val_mean_absolute_percentage_error: 63.5571
# Epoch 40/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 39.5651 - mean_absolute_percentage_error: 39.5651 - val_loss: 67.0695 - val_mean_absolute_percentage_error: 67.0695
# Epoch 41/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 34.2714 - mean_absolute_percentage_error: 34.2714 - val_loss: 62.8770 - val_mean_absolute_percentage_error: 62.8770
# Epoch 42/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 30.2335 - mean_absolute_percentage_error: 30.2335 - val_loss: 63.9947 - val_mean_absolute_percentage_error: 63.9947
# Epoch 43/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 37.0605 - mean_absolute_percentage_error: 37.0605 - val_loss: 67.1258 - val_mean_absolute_percentage_error: 67.1258
# Epoch 44/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 36.3236 - mean_absolute_percentage_error: 36.3236 - val_loss: 61.6377 - val_mean_absolute_percentage_error: 61.6377
# Epoch 45/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 34.1380 - mean_absolute_percentage_error: 34.1380 - val_loss: 70.2142 - val_mean_absolute_percentage_error: 70.2142
# Epoch 46/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 33.7955 - mean_absolute_percentage_error: 33.7955 - val_loss: 62.3751 - val_mean_absolute_percentage_error: 62.3751
# Epoch 47/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 32.8421 - mean_absolute_percentage_error: 32.8421 - val_loss: 74.7768 - val_mean_absolute_percentage_error: 74.7768
# Epoch 48/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 34.4646 - mean_absolute_percentage_error: 34.4646 - val_loss: 58.3001 - val_mean_absolute_percentage_error: 58.3001
# Epoch 49/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 35.0363 - mean_absolute_percentage_error: 35.0363 - val_loss: 69.6732 - val_mean_absolute_percentage_error: 69.6732
# Epoch 50/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 33.8500 - mean_absolute_percentage_error: 33.8500 - val_loss: 68.6468 - val_mean_absolute_percentage_error: 68.6468
# Epoch 51/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 28.7042 - mean_absolute_percentage_error: 28.7042 - val_loss: 66.8223 - val_mean_absolute_percentage_error: 66.8223
# Epoch 52/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 33.5844 - mean_absolute_percentage_error: 33.5844 - val_loss: 81.0117 - val_mean_absolute_percentage_error: 81.0117
# Epoch 53/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 36.3077 - mean_absolute_percentage_error: 36.3077 - val_loss: 62.3152 - val_mean_absolute_percentage_error: 62.3152
# Epoch 54/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 33.2323 - mean_absolute_percentage_error: 33.2323 - val_loss: 74.4934 - val_mean_absolute_percentage_error: 74.4934
# Epoch 55/100
# 428/428 [==============================] - 5s 12ms/sample - loss: 32.8144 - mean_absolute_percentage_error: 32.8144 - val_loss: 63.8143 - val_mean_absolute_percentage_error: 63.8143
# Epoch 56/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 33.3345 - mean_absolute_percentage_error: 33.3345 - val_loss: 78.0472 - val_mean_absolute_percentage_error: 78.0472
# Epoch 57/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 35.0198 - mean_absolute_percentage_error: 35.0198 - val_loss: 64.4637 - val_mean_absolute_percentage_error: 64.4637
# Epoch 58/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 33.9600 - mean_absolute_percentage_error: 33.9600 - val_loss: 73.5358 - val_mean_absolute_percentage_error: 73.5358
# Epoch 59/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 40.3254 - mean_absolute_percentage_error: 40.3254 - val_loss: 74.9419 - val_mean_absolute_percentage_error: 74.9419
# Epoch 60/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 39.7616 - mean_absolute_percentage_error: 39.7616 - val_loss: 61.8625 - val_mean_absolute_percentage_error: 61.8625
# Epoch 61/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 38.9107 - mean_absolute_percentage_error: 38.9107 - val_loss: 77.4766 - val_mean_absolute_percentage_error: 77.4766
# Epoch 62/100
# 428/428 [==============================] - 5s 12ms/sample - loss: 38.3800 - mean_absolute_percentage_error: 38.3800 - val_loss: 64.0451 - val_mean_absolute_percentage_error: 64.0451
# Epoch 63/100
# 428/428 [==============================] - 6s 15ms/sample - loss: 37.6067 - mean_absolute_percentage_error: 37.6067 - val_loss: 68.9025 - val_mean_absolute_percentage_error: 68.9025
# Epoch 64/100
# 428/428 [==============================] - 5s 13ms/sample - loss: 30.6608 - mean_absolute_percentage_error: 30.6608 - val_loss: 66.8387 - val_mean_absolute_percentage_error: 66.8387
# Epoch 65/100
# 428/428 [==============================] - 6s 13ms/sample - loss: 36.1684 - mean_absolute_percentage_error: 36.1684 - val_loss: 74.0014 - val_mean_absolute_percentage_error: 74.0014
# Epoch 66/100
# 428/428 [==============================] - 5s 12ms/sample - loss: 29.9125 - mean_absolute_percentage_error: 29.9125 - val_loss: 68.4728 - val_mean_absolute_percentage_error: 68.4728
# Epoch 67/100
# 428/428 [==============================] - 5s 12ms/sample - loss: 28.5377 - mean_absolute_percentage_error: 28.5377 - val_loss: 72.3362 - val_mean_absolute_percentage_error: 72.3362
# Epoch 68/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 29.6043 - mean_absolute_percentage_error: 29.6043 - val_loss: 64.3978 - val_mean_absolute_percentage_error: 64.3979
# Epoch 69/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 28.3598 - mean_absolute_percentage_error: 28.3598 - val_loss: 70.4587 - val_mean_absolute_percentage_error: 70.4587
# Epoch 70/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 31.4267 - mean_absolute_percentage_error: 31.4267 - val_loss: 68.4218 - val_mean_absolute_percentage_error: 68.4218
# Epoch 71/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 36.9466 - mean_absolute_percentage_error: 36.9466 - val_loss: 71.2443 - val_mean_absolute_percentage_error: 71.2443
# Epoch 72/100
# 428/428 [==============================] - 6s 15ms/sample - loss: 31.1760 - mean_absolute_percentage_error: 31.1760 - val_loss: 63.4904 - val_mean_absolute_percentage_error: 63.4904
# Epoch 73/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 28.6877 - mean_absolute_percentage_error: 28.6877 - val_loss: 73.5591 - val_mean_absolute_percentage_error: 73.5591
# Epoch 74/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 30.2639 - mean_absolute_percentage_error: 30.2639 - val_loss: 58.8924 - val_mean_absolute_percentage_error: 58.8924
# Epoch 75/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 32.2630 - mean_absolute_percentage_error: 32.2629 - val_loss: 74.3302 - val_mean_absolute_percentage_error: 74.3302
# Epoch 76/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 29.7494 - mean_absolute_percentage_error: 29.7494 - val_loss: 71.2121 - val_mean_absolute_percentage_error: 71.2122
# Epoch 77/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 29.1409 - mean_absolute_percentage_error: 29.1409 - val_loss: 61.1572 - val_mean_absolute_percentage_error: 61.1572
# Epoch 78/100
# 428/428 [==============================] - 6s 13ms/sample - loss: 29.6786 - mean_absolute_percentage_error: 29.6786 - val_loss: 75.4480 - val_mean_absolute_percentage_error: 75.4480
# Epoch 79/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 33.4051 - mean_absolute_percentage_error: 33.4051 - val_loss: 65.4551 - val_mean_absolute_percentage_error: 65.4551
# Epoch 80/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 24.4569 - mean_absolute_percentage_error: 24.4569 - val_loss: 75.1210 - val_mean_absolute_percentage_error: 75.1210
# Epoch 81/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 31.7235 - mean_absolute_percentage_error: 31.7235 - val_loss: 73.7992 - val_mean_absolute_percentage_error: 73.7992
# Epoch 82/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 26.4108 - mean_absolute_percentage_error: 26.4108 - val_loss: 59.7027 - val_mean_absolute_percentage_error: 59.7027
# Epoch 83/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 39.9584 - mean_absolute_percentage_error: 39.9584 - val_loss: 76.2702 - val_mean_absolute_percentage_error: 76.2702
# Epoch 84/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 31.2427 - mean_absolute_percentage_error: 31.2427 - val_loss: 64.8252 - val_mean_absolute_percentage_error: 64.8252
# Epoch 85/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 35.5059 - mean_absolute_percentage_error: 35.5059 - val_loss: 74.8863 - val_mean_absolute_percentage_error: 74.8863
# Epoch 86/100
# 428/428 [==============================] - 6s 14ms/sample - loss: 30.2954 - mean_absolute_percentage_error: 30.2954 - val_loss: 62.6300 - val_mean_absolute_percentage_error: 62.6300
# Epoch 87/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 30.3614 - mean_absolute_percentage_error: 30.3614 - val_loss: 74.0374 - val_mean_absolute_percentage_error: 74.0374
# Epoch 88/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 30.5809 - mean_absolute_percentage_error: 30.5809 - val_loss: 69.0137 - val_mean_absolute_percentage_error: 69.0137
# Epoch 89/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 36.2463 - mean_absolute_percentage_error: 36.2463 - val_loss: 75.1615 - val_mean_absolute_percentage_error: 75.1615
# Epoch 90/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 30.6370 - mean_absolute_percentage_error: 30.6370 - val_loss: 67.3529 - val_mean_absolute_percentage_error: 67.3529
# Epoch 91/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 32.4272 - mean_absolute_percentage_error: 32.4272 - val_loss: 78.3763 - val_mean_absolute_percentage_error: 78.3763
# Epoch 92/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 36.7455 - mean_absolute_percentage_error: 36.7455 - val_loss: 59.0005 - val_mean_absolute_percentage_error: 59.0005
# Epoch 93/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 41.7581 - mean_absolute_percentage_error: 41.7582 - val_loss: 75.7807 - val_mean_absolute_percentage_error: 75.7807
# Epoch 94/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 38.2678 - mean_absolute_percentage_error: 38.2678 - val_loss: 66.2089 - val_mean_absolute_percentage_error: 66.2089
# Epoch 95/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 34.2368 - mean_absolute_percentage_error: 34.2368 - val_loss: 65.6884 - val_mean_absolute_percentage_error: 65.6884
# Epoch 96/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 31.7562 - mean_absolute_percentage_error: 31.7562 - val_loss: 71.8108 - val_mean_absolute_percentage_error: 71.8108
# Epoch 97/100
# 428/428 [==============================] - 5s 12ms/sample - loss: 27.6489 - mean_absolute_percentage_error: 27.6489 - val_loss: 72.6816 - val_mean_absolute_percentage_error: 72.6816
# Epoch 98/100
# 428/428 [==============================] - 6s 14ms/sample - loss: 29.9178 - mean_absolute_percentage_error: 29.9178 - val_loss: 70.0379 - val_mean_absolute_percentage_error: 70.0379
# Epoch 99/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 27.1492 - mean_absolute_percentage_error: 27.1492 - val_loss: 74.4897 - val_mean_absolute_percentage_error: 74.4897
# Epoch 100/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 32.5789 - mean_absolute_percentage_error: 32.5789 - val_loss: 79.4813 - val_mean_absolute_percentage_error: 79.4813
# /Users/hasnatchowdhury/opt/anaconda3/envs/machineLearning/lib/python3.10/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-01-24 13:07:33.482460: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_205/BiasAdd' id:29797 op device:{requested: '', assigned: ''} def:{{{node dense_205/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_205/MatMul, dense_205/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 79.48%
# Time Elapsed: 67924.05389714241

# %%
#ML Best Layer Layer All RELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model5 = Sequential()
model5.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model5.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model5.add(MaxPooling2D((2, 2)))
model5.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model5.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model5.add(MaxPooling2D((2, 2)))
model5.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model5.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model5.add(MaxPooling2D((2, 2)))
model5.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model5.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model5.add(MaxPooling2D((2, 2)))
model5.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model5.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model5.add(Flatten())
model5.add(Dense(256, activation='relu'))
model5.add(Dense(1, activation='linear'))
model5.summary()
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model5.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history5 = model5.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history5.history['loss'], label='Training Loss', color='green')
plt.plot(history5.history['val_loss'], label='Validation Loss', color='red')

plt.title('Previous Best RELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('Previous Best RELU.png')
plt.show()

#-----

prices_predicted = model5.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# Model: "sequential_93"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_300 (Conv2D)         (None, 62, 62, 32)        896
#
#  conv2d_301 (Conv2D)         (None, 62, 62, 32)        9248
#
#  max_pooling2d_205 (MaxPooli  (None, 31, 31, 32)       0
#  ng2D)
#
#  conv2d_302 (Conv2D)         (None, 31, 31, 64)        18496
#
#  conv2d_303 (Conv2D)         (None, 31, 31, 64)        36928
#
#  max_pooling2d_206 (MaxPooli  (None, 15, 15, 64)       0
#  ng2D)
#
#  conv2d_304 (Conv2D)         (None, 15, 15, 128)       73856
#
#  conv2d_305 (Conv2D)         (None, 15, 15, 128)       147584
#
#  max_pooling2d_207 (MaxPooli  (None, 7, 7, 128)        0
#  ng2D)
#
#  conv2d_306 (Conv2D)         (None, 7, 7, 128)         147584
#
#  conv2d_307 (Conv2D)         (None, 7, 7, 128)         147584
#
#  max_pooling2d_208 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  conv2d_308 (Conv2D)         (None, 3, 3, 128)         147584
#
#  conv2d_309 (Conv2D)         (None, 3, 3, 128)         147584
#
#  flatten_85 (Flatten)        (None, 1152)              0
#
#  dense_190 (Dense)           (None, 256)               295168
#
#  dense_191 (Dense)           (None, 1)                 257
#
# =================================================================
# Total params: 1,172,769
# Trainable params: 1,172,769
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 01:46:26.538773: W tensorflow/c/c_api.cc:300] Operation '{name:'conv2d_305/kernel/Assign' id:25966 op device:{requested: '', assigned: ''} def:{{{node conv2d_305/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](conv2d_305/kernel, conv2d_305/kernel/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 428/428 [==============================] - ETA: 0s - loss: 95.8436 - mean_absolute_percentage_error: 95.8436
# 2024-01-24 01:46:31.224492: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_46/mul' id:26181 op device:{requested: '', assigned: ''} def:{{{node loss_46/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_46/mul/x, loss_46/dense_191_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 5s 11ms/sample - loss: 95.8436 - mean_absolute_percentage_error: 95.8436 - val_loss: 66.6224 - val_mean_absolute_percentage_error: 66.6224
# Epoch 2/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 72.0819 - mean_absolute_percentage_error: 72.0819 - val_loss: 74.5163 - val_mean_absolute_percentage_error: 74.5163
# Epoch 3/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.3778 - mean_absolute_percentage_error: 71.3778 - val_loss: 66.3721 - val_mean_absolute_percentage_error: 66.3721
# Epoch 4/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.0159 - mean_absolute_percentage_error: 71.0159 - val_loss: 68.4351 - val_mean_absolute_percentage_error: 68.4351
# Epoch 5/100
# 428/428 [==============================] - 6s 13ms/sample - loss: 71.5159 - mean_absolute_percentage_error: 71.5159 - val_loss: 69.2245 - val_mean_absolute_percentage_error: 69.2245
# Epoch 6/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 71.2551 - mean_absolute_percentage_error: 71.2551 - val_loss: 71.4122 - val_mean_absolute_percentage_error: 71.4122
# Epoch 7/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 73.7991 - mean_absolute_percentage_error: 73.7991 - val_loss: 64.6446 - val_mean_absolute_percentage_error: 64.6446
# Epoch 8/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.6759 - mean_absolute_percentage_error: 70.6759 - val_loss: 72.2354 - val_mean_absolute_percentage_error: 72.2354
# Epoch 9/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8701 - mean_absolute_percentage_error: 70.8701 - val_loss: 67.9638 - val_mean_absolute_percentage_error: 67.9638
# Epoch 10/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8066 - mean_absolute_percentage_error: 70.8066 - val_loss: 68.1432 - val_mean_absolute_percentage_error: 68.1432
# Epoch 11/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3514 - mean_absolute_percentage_error: 70.3514 - val_loss: 71.3227 - val_mean_absolute_percentage_error: 71.3227
# Epoch 12/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5042 - mean_absolute_percentage_error: 70.5042 - val_loss: 66.5351 - val_mean_absolute_percentage_error: 66.5351
# Epoch 13/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.2048 - mean_absolute_percentage_error: 71.2048 - val_loss: 69.1830 - val_mean_absolute_percentage_error: 69.1830
# Epoch 14/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.2137 - mean_absolute_percentage_error: 71.2137 - val_loss: 70.0450 - val_mean_absolute_percentage_error: 70.0450
# Epoch 15/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8279 - mean_absolute_percentage_error: 70.8279 - val_loss: 68.4244 - val_mean_absolute_percentage_error: 68.4244
# Epoch 16/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8285 - mean_absolute_percentage_error: 70.8285 - val_loss: 68.3543 - val_mean_absolute_percentage_error: 68.3543
# Epoch 17/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5312 - mean_absolute_percentage_error: 70.5312 - val_loss: 69.3132 - val_mean_absolute_percentage_error: 69.3132
# Epoch 18/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.6522 - mean_absolute_percentage_error: 70.6522 - val_loss: 66.9792 - val_mean_absolute_percentage_error: 66.9792
# Epoch 19/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.4347 - mean_absolute_percentage_error: 71.4347 - val_loss: 67.8342 - val_mean_absolute_percentage_error: 67.8342
# Epoch 20/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5224 - mean_absolute_percentage_error: 70.5224 - val_loss: 69.6004 - val_mean_absolute_percentage_error: 69.6004
# Epoch 21/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.2047 - mean_absolute_percentage_error: 71.2047 - val_loss: 70.5443 - val_mean_absolute_percentage_error: 70.5443
# Epoch 22/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.3681 - mean_absolute_percentage_error: 70.3681 - val_loss: 67.3455 - val_mean_absolute_percentage_error: 67.3455
# Epoch 23/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.4765 - mean_absolute_percentage_error: 70.4765 - val_loss: 72.3410 - val_mean_absolute_percentage_error: 72.3410
# Epoch 24/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5013 - mean_absolute_percentage_error: 70.5013 - val_loss: 68.4421 - val_mean_absolute_percentage_error: 68.4421
# Epoch 25/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.5400 - mean_absolute_percentage_error: 71.5400 - val_loss: 68.1773 - val_mean_absolute_percentage_error: 68.1773
# Epoch 26/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 71.3985 - mean_absolute_percentage_error: 71.3986 - val_loss: 68.9615 - val_mean_absolute_percentage_error: 68.9615
# Epoch 27/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8319 - mean_absolute_percentage_error: 70.8319 - val_loss: 69.0675 - val_mean_absolute_percentage_error: 69.0675
# Epoch 28/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.0301 - mean_absolute_percentage_error: 71.0301 - val_loss: 69.7436 - val_mean_absolute_percentage_error: 69.7436
# Epoch 29/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.9876 - mean_absolute_percentage_error: 70.9876 - val_loss: 68.9206 - val_mean_absolute_percentage_error: 68.9206
# Epoch 30/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.3178 - mean_absolute_percentage_error: 70.3178 - val_loss: 69.5574 - val_mean_absolute_percentage_error: 69.5574
# Epoch 31/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.3999 - mean_absolute_percentage_error: 70.3999 - val_loss: 69.2317 - val_mean_absolute_percentage_error: 69.2317
# Epoch 32/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5657 - mean_absolute_percentage_error: 70.5657 - val_loss: 70.0889 - val_mean_absolute_percentage_error: 70.0889
# Epoch 33/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.4450 - mean_absolute_percentage_error: 70.4450 - val_loss: 68.9977 - val_mean_absolute_percentage_error: 68.9977
# Epoch 34/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.4068 - mean_absolute_percentage_error: 70.4068 - val_loss: 68.7047 - val_mean_absolute_percentage_error: 68.7047
# Epoch 35/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.0468 - mean_absolute_percentage_error: 71.0468 - val_loss: 67.7778 - val_mean_absolute_percentage_error: 67.7778
# Epoch 36/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.0620 - mean_absolute_percentage_error: 71.0620 - val_loss: 68.8160 - val_mean_absolute_percentage_error: 68.8160
# Epoch 37/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.4998 - mean_absolute_percentage_error: 70.4998 - val_loss: 70.9511 - val_mean_absolute_percentage_error: 70.9511
# Epoch 38/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5859 - mean_absolute_percentage_error: 70.5859 - val_loss: 68.4437 - val_mean_absolute_percentage_error: 68.4437
# Epoch 39/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.3035 - mean_absolute_percentage_error: 70.3035 - val_loss: 69.4627 - val_mean_absolute_percentage_error: 69.4627
# Epoch 40/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.7585 - mean_absolute_percentage_error: 70.7585 - val_loss: 69.3992 - val_mean_absolute_percentage_error: 69.3992
# Epoch 41/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.4238 - mean_absolute_percentage_error: 71.4238 - val_loss: 66.4760 - val_mean_absolute_percentage_error: 66.4760
# Epoch 42/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 74.3059 - mean_absolute_percentage_error: 74.3059 - val_loss: 69.2455 - val_mean_absolute_percentage_error: 69.2455
# Epoch 43/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.7459 - mean_absolute_percentage_error: 70.7459 - val_loss: 68.1239 - val_mean_absolute_percentage_error: 68.1239
# Epoch 44/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3136 - mean_absolute_percentage_error: 70.3136 - val_loss: 71.2023 - val_mean_absolute_percentage_error: 71.2023
# Epoch 45/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.2448 - mean_absolute_percentage_error: 70.2448 - val_loss: 68.1128 - val_mean_absolute_percentage_error: 68.1128
# Epoch 46/100
# 428/428 [==============================] - 7s 16ms/sample - loss: 70.4175 - mean_absolute_percentage_error: 70.4175 - val_loss: 67.7497 - val_mean_absolute_percentage_error: 67.7497
# Epoch 47/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 70.1096 - mean_absolute_percentage_error: 70.1096 - val_loss: 71.2455 - val_mean_absolute_percentage_error: 71.2455
# Epoch 48/100
# 428/428 [==============================] - 5s 11ms/sample - loss: 70.6003 - mean_absolute_percentage_error: 70.6003 - val_loss: 67.2891 - val_mean_absolute_percentage_error: 67.2891
# Epoch 49/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 71.8801 - mean_absolute_percentage_error: 71.8801 - val_loss: 67.0567 - val_mean_absolute_percentage_error: 67.0567
# Epoch 50/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5350 - mean_absolute_percentage_error: 70.5350 - val_loss: 70.7316 - val_mean_absolute_percentage_error: 70.7316
# Epoch 51/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.0648 - mean_absolute_percentage_error: 71.0648 - val_loss: 67.2816 - val_mean_absolute_percentage_error: 67.2816
# Epoch 52/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.7011 - mean_absolute_percentage_error: 70.7011 - val_loss: 69.2502 - val_mean_absolute_percentage_error: 69.2502
# Epoch 53/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5928 - mean_absolute_percentage_error: 70.5927 - val_loss: 67.7064 - val_mean_absolute_percentage_error: 67.7064
# Epoch 54/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.4926 - mean_absolute_percentage_error: 70.4926 - val_loss: 70.8177 - val_mean_absolute_percentage_error: 70.8177
# Epoch 55/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.2680 - mean_absolute_percentage_error: 70.2681 - val_loss: 67.5641 - val_mean_absolute_percentage_error: 67.5641
# Epoch 56/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.4795 - mean_absolute_percentage_error: 70.4795 - val_loss: 68.2320 - val_mean_absolute_percentage_error: 68.2320
# Epoch 57/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.6941 - mean_absolute_percentage_error: 71.6941 - val_loss: 68.1460 - val_mean_absolute_percentage_error: 68.1460
# Epoch 58/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5871 - mean_absolute_percentage_error: 70.5871 - val_loss: 68.5330 - val_mean_absolute_percentage_error: 68.5330
# Epoch 59/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.4861 - mean_absolute_percentage_error: 70.4861 - val_loss: 68.8842 - val_mean_absolute_percentage_error: 68.8842
# Epoch 60/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.6078 - mean_absolute_percentage_error: 70.6078 - val_loss: 70.6500 - val_mean_absolute_percentage_error: 70.6500
# Epoch 61/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.6008 - mean_absolute_percentage_error: 70.6008 - val_loss: 68.2010 - val_mean_absolute_percentage_error: 68.2010
# Epoch 62/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.2899 - mean_absolute_percentage_error: 70.2899 - val_loss: 70.2698 - val_mean_absolute_percentage_error: 70.2698
# Epoch 63/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3164 - mean_absolute_percentage_error: 70.3164 - val_loss: 68.1752 - val_mean_absolute_percentage_error: 68.1752
# Epoch 64/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5754 - mean_absolute_percentage_error: 70.5754 - val_loss: 70.7781 - val_mean_absolute_percentage_error: 70.7781
# Epoch 65/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.2222 - mean_absolute_percentage_error: 70.2222 - val_loss: 67.9739 - val_mean_absolute_percentage_error: 67.9739
# Epoch 66/100
# 428/428 [==============================] - 3s 8ms/sample - loss: 70.5165 - mean_absolute_percentage_error: 70.5165 - val_loss: 68.1103 - val_mean_absolute_percentage_error: 68.1103
# Epoch 67/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.2761 - mean_absolute_percentage_error: 70.2761 - val_loss: 70.4079 - val_mean_absolute_percentage_error: 70.4079
# Epoch 68/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.7962 - mean_absolute_percentage_error: 70.7962 - val_loss: 68.1736 - val_mean_absolute_percentage_error: 68.1736
# Epoch 69/100
# 428/428 [==============================] - 4s 10ms/sample - loss: 70.5960 - mean_absolute_percentage_error: 70.5960 - val_loss: 68.6528 - val_mean_absolute_percentage_error: 68.6528
# Epoch 70/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3826 - mean_absolute_percentage_error: 70.3826 - val_loss: 68.6936 - val_mean_absolute_percentage_error: 68.6936
# Epoch 71/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.3442 - mean_absolute_percentage_error: 70.3442 - val_loss: 69.2030 - val_mean_absolute_percentage_error: 69.2030
# Epoch 72/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 70.5713 - mean_absolute_percentage_error: 70.5713 - val_loss: 69.8437 - val_mean_absolute_percentage_error: 69.8437
# Epoch 73/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.9861 - mean_absolute_percentage_error: 70.9861 - val_loss: 68.3717 - val_mean_absolute_percentage_error: 68.3716
# Epoch 74/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8394 - mean_absolute_percentage_error: 70.8394 - val_loss: 68.5128 - val_mean_absolute_percentage_error: 68.5128
# Epoch 75/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.9162 - mean_absolute_percentage_error: 70.9162 - val_loss: 67.1698 - val_mean_absolute_percentage_error: 67.1698
# Epoch 76/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.7735 - mean_absolute_percentage_error: 70.7735 - val_loss: 70.1574 - val_mean_absolute_percentage_error: 70.1574
# Epoch 77/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.4367 - mean_absolute_percentage_error: 70.4367 - val_loss: 67.6041 - val_mean_absolute_percentage_error: 67.6041
# Epoch 78/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.0911 - mean_absolute_percentage_error: 71.0911 - val_loss: 71.1868 - val_mean_absolute_percentage_error: 71.1868
# Epoch 79/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3610 - mean_absolute_percentage_error: 70.3610 - val_loss: 67.0211 - val_mean_absolute_percentage_error: 67.0211
# Epoch 80/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.6972 - mean_absolute_percentage_error: 70.6972 - val_loss: 68.5656 - val_mean_absolute_percentage_error: 68.5656
# Epoch 81/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.4836 - mean_absolute_percentage_error: 70.4836 - val_loss: 68.5628 - val_mean_absolute_percentage_error: 68.5628
# Epoch 82/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5312 - mean_absolute_percentage_error: 70.5312 - val_loss: 68.3247 - val_mean_absolute_percentage_error: 68.3247
# Epoch 83/100
# 428/428 [==============================] - 3s 8ms/sample - loss: 70.4864 - mean_absolute_percentage_error: 70.4864 - val_loss: 68.0135 - val_mean_absolute_percentage_error: 68.0135
# Epoch 84/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.4678 - mean_absolute_percentage_error: 70.4678 - val_loss: 68.9793 - val_mean_absolute_percentage_error: 68.9793
# Epoch 85/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3130 - mean_absolute_percentage_error: 70.3130 - val_loss: 68.9016 - val_mean_absolute_percentage_error: 68.9016
# Epoch 86/100
# 428/428 [==============================] - 3s 8ms/sample - loss: 70.3074 - mean_absolute_percentage_error: 70.3074 - val_loss: 69.3751 - val_mean_absolute_percentage_error: 69.3751
# Epoch 87/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5753 - mean_absolute_percentage_error: 70.5753 - val_loss: 70.0378 - val_mean_absolute_percentage_error: 70.0378
# Epoch 88/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.9319 - mean_absolute_percentage_error: 70.9319 - val_loss: 70.1129 - val_mean_absolute_percentage_error: 70.1129
# Epoch 89/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8185 - mean_absolute_percentage_error: 70.8186 - val_loss: 68.7935 - val_mean_absolute_percentage_error: 68.7935
# Epoch 90/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3701 - mean_absolute_percentage_error: 70.3701 - val_loss: 69.5378 - val_mean_absolute_percentage_error: 69.5378
# Epoch 91/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.2701 - mean_absolute_percentage_error: 70.2701 - val_loss: 69.3868 - val_mean_absolute_percentage_error: 69.3868
# Epoch 92/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.7886 - mean_absolute_percentage_error: 70.7886 - val_loss: 69.0567 - val_mean_absolute_percentage_error: 69.0567
# Epoch 93/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.3181 - mean_absolute_percentage_error: 70.3181 - val_loss: 69.9495 - val_mean_absolute_percentage_error: 69.9495
# Epoch 94/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5687 - mean_absolute_percentage_error: 70.5687 - val_loss: 69.6727 - val_mean_absolute_percentage_error: 69.6727
# Epoch 95/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 71.9572 - mean_absolute_percentage_error: 71.9572 - val_loss: 66.6591 - val_mean_absolute_percentage_error: 66.6591
# Epoch 96/100
# 428/428 [==============================] - 4s 9ms/sample - loss: 71.2706 - mean_absolute_percentage_error: 71.2706 - val_loss: 72.2015 - val_mean_absolute_percentage_error: 72.2015
# Epoch 97/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.0288 - mean_absolute_percentage_error: 70.0288 - val_loss: 67.2541 - val_mean_absolute_percentage_error: 67.2541
# Epoch 98/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.8015 - mean_absolute_percentage_error: 70.8015 - val_loss: 67.8247 - val_mean_absolute_percentage_error: 67.8247
# Epoch 99/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.1164 - mean_absolute_percentage_error: 70.1164 - val_loss: 70.5801 - val_mean_absolute_percentage_error: 70.5801
# Epoch 100/100
# 428/428 [==============================] - 4s 8ms/sample - loss: 70.5668 - mean_absolute_percentage_error: 70.5668 - val_loss: 69.0178 - val_mean_absolute_percentage_error: 69.0178
# 2024-01-24 01:52:35.641433: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_191/BiasAdd' id:26124 op device:{requested: '', assigned: ''} def:{{{node dense_191/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_191/MatMul, dense_191/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 69.02%
# Time Elapsed: 27426.25712800026

# %%
#ML2 Layer All RELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model6 = Sequential()
model6.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu', input_shape = (64, 64, 3)))
model6.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu'))
model6.add(MaxPooling2D(2,2))
model6.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'relu'))
model6.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'relu'))
model6.add(MaxPooling2D(2,2))
model6.add(Flatten())
model6.add(Dense(units = 1024, activation = 'relu'))
model6.add(Dense(units = 1024, activation = 'relu'))
model6.add(Dense(units = 1, activation = 'linear'))
opt =Adam(lr=1e-3, decay=1e-3 / 200)
model6.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history6 = model6.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history6.history['loss'], label='Training Loss', color='green')
plt.plot(history6.history['val_loss'], label='Validation Loss', color='red')

plt.title('ML2 Layer RELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('ML2 Layer RELU.png')
plt.show()

#-----

prices_predicted = model6.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 01:52:38.626014: W tensorflow/c/c_api.cc:300] Operation '{name:'training_70/Adam/dense_193/bias/m/Assign' id:27269 op device:{requested: '', assigned: ''} def:{{{node training_70/Adam/dense_193/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_70/Adam/dense_193/bias/m, training_70/Adam/dense_193/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 428/428 [==============================] - ETA: 0s - loss: 1288.4460 - mean_absolute_percentage_error: 1288.4459
# 2024-01-24 01:52:49.834802: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_47/mul' id:27044 op device:{requested: '', assigned: ''} def:{{{node loss_47/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_47/mul/x, loss_47/dense_194_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 11s 27ms/sample - loss: 1288.4460 - mean_absolute_percentage_error: 1288.4459 - val_loss: 74.6596 - val_mean_absolute_percentage_error: 74.6596
# Epoch 2/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 71.1169 - mean_absolute_percentage_error: 71.1169 - val_loss: 68.7385 - val_mean_absolute_percentage_error: 68.7385
# Epoch 3/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.4253 - mean_absolute_percentage_error: 71.4253 - val_loss: 64.2660 - val_mean_absolute_percentage_error: 64.2660
# Epoch 4/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 74.1251 - mean_absolute_percentage_error: 74.1250 - val_loss: 75.5349 - val_mean_absolute_percentage_error: 75.5349
# Epoch 5/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 74.5220 - mean_absolute_percentage_error: 74.5220 - val_loss: 65.5856 - val_mean_absolute_percentage_error: 65.5856
# Epoch 6/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 69.6722 - mean_absolute_percentage_error: 69.6721 - val_loss: 72.9177 - val_mean_absolute_percentage_error: 72.9177
# Epoch 7/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.1238 - mean_absolute_percentage_error: 71.1238 - val_loss: 69.8404 - val_mean_absolute_percentage_error: 69.8404
# Epoch 8/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 70.5070 - mean_absolute_percentage_error: 70.5070 - val_loss: 69.3877 - val_mean_absolute_percentage_error: 69.3877
# Epoch 9/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 70.9649 - mean_absolute_percentage_error: 70.9649 - val_loss: 67.3161 - val_mean_absolute_percentage_error: 67.3161
# Epoch 10/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.0433 - mean_absolute_percentage_error: 71.0433 - val_loss: 65.6511 - val_mean_absolute_percentage_error: 65.6511
# Epoch 11/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 72.2721 - mean_absolute_percentage_error: 72.2721 - val_loss: 70.0916 - val_mean_absolute_percentage_error: 70.0916
# Epoch 12/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 73.9558 - mean_absolute_percentage_error: 73.9558 - val_loss: 65.1948 - val_mean_absolute_percentage_error: 65.1948
# Epoch 13/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.9650 - mean_absolute_percentage_error: 70.9650 - val_loss: 71.4653 - val_mean_absolute_percentage_error: 71.4653
# Epoch 14/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.6147 - mean_absolute_percentage_error: 71.6147 - val_loss: 66.2800 - val_mean_absolute_percentage_error: 66.2800
# Epoch 15/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.9371 - mean_absolute_percentage_error: 71.9371 - val_loss: 67.2798 - val_mean_absolute_percentage_error: 67.2798
# Epoch 16/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 70.9173 - mean_absolute_percentage_error: 70.9173 - val_loss: 67.5403 - val_mean_absolute_percentage_error: 67.5403
# Epoch 17/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.3554 - mean_absolute_percentage_error: 71.3554 - val_loss: 69.8299 - val_mean_absolute_percentage_error: 69.8299
# Epoch 18/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 71.3716 - mean_absolute_percentage_error: 71.3716 - val_loss: 70.1185 - val_mean_absolute_percentage_error: 70.1185
# Epoch 19/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3228 - mean_absolute_percentage_error: 70.3228 - val_loss: 67.4252 - val_mean_absolute_percentage_error: 67.4252
# Epoch 20/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.1132 - mean_absolute_percentage_error: 71.1132 - val_loss: 69.8294 - val_mean_absolute_percentage_error: 69.8294
# Epoch 21/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3560 - mean_absolute_percentage_error: 70.3560 - val_loss: 69.2787 - val_mean_absolute_percentage_error: 69.2787
# Epoch 22/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.6360 - mean_absolute_percentage_error: 70.6360 - val_loss: 67.1159 - val_mean_absolute_percentage_error: 67.1160
# Epoch 23/100
# 428/428 [==============================] - 10s 23ms/sample - loss: 71.0616 - mean_absolute_percentage_error: 71.0616 - val_loss: 70.0804 - val_mean_absolute_percentage_error: 70.0804
# Epoch 24/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 71.9512 - mean_absolute_percentage_error: 71.9512 - val_loss: 71.2036 - val_mean_absolute_percentage_error: 71.2036
# Epoch 25/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.9529 - mean_absolute_percentage_error: 70.9529 - val_loss: 68.2038 - val_mean_absolute_percentage_error: 68.2038
# Epoch 26/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.0491 - mean_absolute_percentage_error: 71.0491 - val_loss: 69.2465 - val_mean_absolute_percentage_error: 69.2465
# Epoch 27/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.6148 - mean_absolute_percentage_error: 71.6148 - val_loss: 66.8955 - val_mean_absolute_percentage_error: 66.8955
# Epoch 28/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.9169 - mean_absolute_percentage_error: 71.9169 - val_loss: 69.1825 - val_mean_absolute_percentage_error: 69.1825
# Epoch 29/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.8333 - mean_absolute_percentage_error: 70.8333 - val_loss: 68.4280 - val_mean_absolute_percentage_error: 68.4280
# Epoch 30/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3758 - mean_absolute_percentage_error: 70.3758 - val_loss: 68.0233 - val_mean_absolute_percentage_error: 68.0233
# Epoch 31/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5439 - mean_absolute_percentage_error: 70.5439 - val_loss: 70.9943 - val_mean_absolute_percentage_error: 70.9943
# Epoch 32/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3743 - mean_absolute_percentage_error: 70.3743 - val_loss: 68.5070 - val_mean_absolute_percentage_error: 68.5070
# Epoch 33/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3327 - mean_absolute_percentage_error: 70.3327 - val_loss: 69.5515 - val_mean_absolute_percentage_error: 69.5515
# Epoch 34/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5805 - mean_absolute_percentage_error: 70.5805 - val_loss: 70.9351 - val_mean_absolute_percentage_error: 70.9351
# Epoch 35/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4852 - mean_absolute_percentage_error: 70.4852 - val_loss: 69.6806 - val_mean_absolute_percentage_error: 69.6806
# Epoch 36/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4343 - mean_absolute_percentage_error: 70.4343 - val_loss: 69.2020 - val_mean_absolute_percentage_error: 69.2020
# Epoch 37/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5625 - mean_absolute_percentage_error: 70.5625 - val_loss: 66.9454 - val_mean_absolute_percentage_error: 66.9454
# Epoch 38/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 71.7123 - mean_absolute_percentage_error: 71.7123 - val_loss: 67.8559 - val_mean_absolute_percentage_error: 67.8559
# Epoch 39/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.7340 - mean_absolute_percentage_error: 71.7340 - val_loss: 67.2763 - val_mean_absolute_percentage_error: 67.2763
# Epoch 40/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.6273 - mean_absolute_percentage_error: 70.6273 - val_loss: 68.8709 - val_mean_absolute_percentage_error: 68.8709
# Epoch 41/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.8725 - mean_absolute_percentage_error: 70.8725 - val_loss: 67.5589 - val_mean_absolute_percentage_error: 67.5589
# Epoch 42/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.9214 - mean_absolute_percentage_error: 70.9214 - val_loss: 68.6721 - val_mean_absolute_percentage_error: 68.6721
# Epoch 43/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.9475 - mean_absolute_percentage_error: 70.9475 - val_loss: 67.4824 - val_mean_absolute_percentage_error: 67.4824
# Epoch 44/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 71.9067 - mean_absolute_percentage_error: 71.9067 - val_loss: 67.8222 - val_mean_absolute_percentage_error: 67.8222
# Epoch 45/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 70.5097 - mean_absolute_percentage_error: 70.5097 - val_loss: 71.4801 - val_mean_absolute_percentage_error: 71.4801
# Epoch 46/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.4485 - mean_absolute_percentage_error: 71.4485 - val_loss: 67.4756 - val_mean_absolute_percentage_error: 67.4756
# Epoch 47/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5928 - mean_absolute_percentage_error: 70.5928 - val_loss: 69.7100 - val_mean_absolute_percentage_error: 69.7100
# Epoch 48/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4488 - mean_absolute_percentage_error: 70.4488 - val_loss: 68.3511 - val_mean_absolute_percentage_error: 68.3511
# Epoch 49/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.9580 - mean_absolute_percentage_error: 70.9580 - val_loss: 70.6906 - val_mean_absolute_percentage_error: 70.6906
# Epoch 50/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4352 - mean_absolute_percentage_error: 70.4352 - val_loss: 67.8104 - val_mean_absolute_percentage_error: 67.8104
# Epoch 51/100
# 428/428 [==============================] - 9s 22ms/sample - loss: 70.7356 - mean_absolute_percentage_error: 70.7356 - val_loss: 68.8048 - val_mean_absolute_percentage_error: 68.8048
# Epoch 52/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 71.7077 - mean_absolute_percentage_error: 71.7078 - val_loss: 66.3872 - val_mean_absolute_percentage_error: 66.3872
# Epoch 53/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 70.9381 - mean_absolute_percentage_error: 70.9381 - val_loss: 70.7456 - val_mean_absolute_percentage_error: 70.7456
# Epoch 54/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 70.6935 - mean_absolute_percentage_error: 70.6935 - val_loss: 67.7270 - val_mean_absolute_percentage_error: 67.7270
# Epoch 55/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3455 - mean_absolute_percentage_error: 70.3455 - val_loss: 70.0746 - val_mean_absolute_percentage_error: 70.0746
# Epoch 56/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.0492 - mean_absolute_percentage_error: 71.0492 - val_loss: 69.3477 - val_mean_absolute_percentage_error: 69.3477
# Epoch 57/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4002 - mean_absolute_percentage_error: 70.4002 - val_loss: 70.9284 - val_mean_absolute_percentage_error: 70.9284
# Epoch 58/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.9399 - mean_absolute_percentage_error: 70.9399 - val_loss: 68.1377 - val_mean_absolute_percentage_error: 68.1377
# Epoch 59/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 71.6093 - mean_absolute_percentage_error: 71.6093 - val_loss: 67.8645 - val_mean_absolute_percentage_error: 67.8645
# Epoch 60/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5410 - mean_absolute_percentage_error: 70.5410 - val_loss: 70.4038 - val_mean_absolute_percentage_error: 70.4038
# Epoch 61/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 70.3222 - mean_absolute_percentage_error: 70.3222 - val_loss: 67.7390 - val_mean_absolute_percentage_error: 67.7390
# Epoch 62/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.6204 - mean_absolute_percentage_error: 71.6204 - val_loss: 68.8359 - val_mean_absolute_percentage_error: 68.8359
# Epoch 63/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.2205 - mean_absolute_percentage_error: 70.2205 - val_loss: 69.8164 - val_mean_absolute_percentage_error: 69.8164
# Epoch 64/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.6261 - mean_absolute_percentage_error: 70.6261 - val_loss: 69.8749 - val_mean_absolute_percentage_error: 69.8749
# Epoch 65/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.2790 - mean_absolute_percentage_error: 71.2790 - val_loss: 68.3460 - val_mean_absolute_percentage_error: 68.3460
# Epoch 66/100
# 428/428 [==============================] - 10s 24ms/sample - loss: 70.2543 - mean_absolute_percentage_error: 70.2543 - val_loss: 70.4597 - val_mean_absolute_percentage_error: 70.4597
# Epoch 67/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 70.2815 - mean_absolute_percentage_error: 70.2815 - val_loss: 67.6517 - val_mean_absolute_percentage_error: 67.6517
# Epoch 68/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.1041 - mean_absolute_percentage_error: 71.1041 - val_loss: 67.5967 - val_mean_absolute_percentage_error: 67.5967
# Epoch 69/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.7433 - mean_absolute_percentage_error: 70.7433 - val_loss: 68.5475 - val_mean_absolute_percentage_error: 68.5475
# Epoch 70/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.6689 - mean_absolute_percentage_error: 70.6689 - val_loss: 69.5742 - val_mean_absolute_percentage_error: 69.5742
# Epoch 71/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.2110 - mean_absolute_percentage_error: 71.2110 - val_loss: 67.0688 - val_mean_absolute_percentage_error: 67.0688
# Epoch 72/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.1535 - mean_absolute_percentage_error: 71.1535 - val_loss: 68.8019 - val_mean_absolute_percentage_error: 68.8019
# Epoch 73/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 71.3773 - mean_absolute_percentage_error: 71.3773 - val_loss: 67.6759 - val_mean_absolute_percentage_error: 67.6759
# Epoch 74/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.2005 - mean_absolute_percentage_error: 70.2005 - val_loss: 70.7948 - val_mean_absolute_percentage_error: 70.7948
# Epoch 75/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5123 - mean_absolute_percentage_error: 70.5123 - val_loss: 70.0353 - val_mean_absolute_percentage_error: 70.0353
# Epoch 76/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5747 - mean_absolute_percentage_error: 70.5747 - val_loss: 69.1453 - val_mean_absolute_percentage_error: 69.1453
# Epoch 77/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4798 - mean_absolute_percentage_error: 70.4798 - val_loss: 69.3308 - val_mean_absolute_percentage_error: 69.3308
# Epoch 78/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.9279 - mean_absolute_percentage_error: 70.9279 - val_loss: 67.0771 - val_mean_absolute_percentage_error: 67.0771
# Epoch 79/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.6671 - mean_absolute_percentage_error: 70.6671 - val_loss: 69.1747 - val_mean_absolute_percentage_error: 69.1747
# Epoch 80/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4759 - mean_absolute_percentage_error: 70.4759 - val_loss: 69.7732 - val_mean_absolute_percentage_error: 69.7732
# Epoch 81/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.7361 - mean_absolute_percentage_error: 70.7361 - val_loss: 68.0557 - val_mean_absolute_percentage_error: 68.0557
# Epoch 82/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5219 - mean_absolute_percentage_error: 70.5219 - val_loss: 69.7369 - val_mean_absolute_percentage_error: 69.7369
# Epoch 83/100
# 428/428 [==============================] - 12s 28ms/sample - loss: 70.8314 - mean_absolute_percentage_error: 70.8314 - val_loss: 68.1512 - val_mean_absolute_percentage_error: 68.1512
# Epoch 84/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 71.6148 - mean_absolute_percentage_error: 71.6148 - val_loss: 66.5623 - val_mean_absolute_percentage_error: 66.5623
# Epoch 85/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 72.0375 - mean_absolute_percentage_error: 72.0375 - val_loss: 69.9207 - val_mean_absolute_percentage_error: 69.9207
# Epoch 86/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 71.5644 - mean_absolute_percentage_error: 71.5644 - val_loss: 66.2760 - val_mean_absolute_percentage_error: 66.2760
# Epoch 87/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 70.8485 - mean_absolute_percentage_error: 70.8485 - val_loss: 72.0115 - val_mean_absolute_percentage_error: 72.0115
# Epoch 88/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3180 - mean_absolute_percentage_error: 70.3180 - val_loss: 67.8709 - val_mean_absolute_percentage_error: 67.8709
# Epoch 89/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5394 - mean_absolute_percentage_error: 70.5394 - val_loss: 67.7910 - val_mean_absolute_percentage_error: 67.7910
# Epoch 90/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.1919 - mean_absolute_percentage_error: 70.1919 - val_loss: 70.6454 - val_mean_absolute_percentage_error: 70.6454
# Epoch 91/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.8225 - mean_absolute_percentage_error: 70.8225 - val_loss: 69.7413 - val_mean_absolute_percentage_error: 69.7413
# Epoch 92/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 70.4907 - mean_absolute_percentage_error: 70.4907 - val_loss: 70.3171 - val_mean_absolute_percentage_error: 70.3171
# Epoch 93/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.6803 - mean_absolute_percentage_error: 70.6803 - val_loss: 68.1120 - val_mean_absolute_percentage_error: 68.1120
# Epoch 94/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.8334 - mean_absolute_percentage_error: 70.8334 - val_loss: 69.9716 - val_mean_absolute_percentage_error: 69.9716
# Epoch 95/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3593 - mean_absolute_percentage_error: 70.3593 - val_loss: 68.5149 - val_mean_absolute_percentage_error: 68.5149
# Epoch 96/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4931 - mean_absolute_percentage_error: 70.4931 - val_loss: 70.8339 - val_mean_absolute_percentage_error: 70.8339
# Epoch 97/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.5416 - mean_absolute_percentage_error: 70.5416 - val_loss: 67.6311 - val_mean_absolute_percentage_error: 67.6311
# Epoch 98/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 70.4766 - mean_absolute_percentage_error: 70.4766 - val_loss: 69.1088 - val_mean_absolute_percentage_error: 69.1087
# Epoch 99/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.3594 - mean_absolute_percentage_error: 70.3594 - val_loss: 68.5536 - val_mean_absolute_percentage_error: 68.5536
# Epoch 100/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 70.4005 - mean_absolute_percentage_error: 70.4005 - val_loss: 69.8288 - val_mean_absolute_percentage_error: 69.8288
# 2024-01-24 02:06:38.689923: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_194/BiasAdd' id:26987 op device:{requested: '', assigned: ''} def:{{{node dense_194/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_194/MatMul, dense_194/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 69.83%
# Time Elapsed: 28269.304249048233

# %%
#ML2 Layer All ELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model7 = Sequential()
model7.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'elu', input_shape = (64, 64, 3)))
model7.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'elu'))
model7.add(MaxPooling2D(2,2))
model7.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'elu'))
model7.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'elu'))
model7.add(MaxPooling2D(2,2))
model7.add(Flatten())
model7.add(Dense(units = 1024, activation = 'elu'))
model7.add(Dense(units = 1024, activation = 'elu'))
model7.add(Dense(units = 1, activation = 'linear'))
opt =Adam(lr=1e-3, decay=1e-3 / 200)
model7.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history7 = model7.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history7.history['loss'], label='Training Loss', color='green')
plt.plot(history7.history['val_loss'], label='Validation Loss', color='red')

plt.title('ML2 Layer ELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('ML2 Layer ELU.png')
plt.show()

#-----

prices_predicted = model7.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 02:06:42.267682: W tensorflow/c/c_api.cc:300] Operation '{name:'training_72/Adam/iter/Assign' id:27854 op device:{requested: '', assigned: ''} def:{{{node training_72/Adam/iter/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_INT64, validate_shape=false](training_72/Adam/iter, training_72/Adam/iter/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 428/428 [==============================] - ETA: 0s - loss: 38773.3353 - mean_absolute_percentage_error: 38773.3359
# 2024-01-24 02:06:52.059470: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_48/mul' id:27725 op device:{requested: '', assigned: ''} def:{{{node loss_48/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_48/mul/x, loss_48/dense_197_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 10s 23ms/sample - loss: 38773.3353 - mean_absolute_percentage_error: 38773.3359 - val_loss: 4388.3931 - val_mean_absolute_percentage_error: 4388.3931
# Epoch 2/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 9862.0401 - mean_absolute_percentage_error: 9862.0410 - val_loss: 22360.0383 - val_mean_absolute_percentage_error: 22360.0371
# Epoch 3/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 8785.7639 - mean_absolute_percentage_error: 8785.7637 - val_loss: 6219.9645 - val_mean_absolute_percentage_error: 6219.9648
# Epoch 4/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 3024.1673 - mean_absolute_percentage_error: 3024.1672 - val_loss: 1218.0158 - val_mean_absolute_percentage_error: 1218.0159
# Epoch 5/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 1424.4031 - mean_absolute_percentage_error: 1424.4032 - val_loss: 2603.6650 - val_mean_absolute_percentage_error: 2603.6650
# Epoch 6/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 3194.2624 - mean_absolute_percentage_error: 3194.2622 - val_loss: 28466.0815 - val_mean_absolute_percentage_error: 28466.0820
# Epoch 7/100
# 428/428 [==============================] - 10s 22ms/sample - loss: 38184.8147 - mean_absolute_percentage_error: 38184.8125 - val_loss: 1856.4541 - val_mean_absolute_percentage_error: 1856.4540
# Epoch 8/100
# 428/428 [==============================] - 15s 35ms/sample - loss: 5017.9572 - mean_absolute_percentage_error: 5017.9575 - val_loss: 1583.0258 - val_mean_absolute_percentage_error: 1583.0258
# Epoch 9/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 2328.8464 - mean_absolute_percentage_error: 2328.8464 - val_loss: 5345.5306 - val_mean_absolute_percentage_error: 5345.5308
# Epoch 10/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 2096.8110 - mean_absolute_percentage_error: 2096.8108 - val_loss: 2364.5245 - val_mean_absolute_percentage_error: 2364.5244
# Epoch 11/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 2127.9649 - mean_absolute_percentage_error: 2127.9648 - val_loss: 1909.6033 - val_mean_absolute_percentage_error: 1909.6033
# Epoch 12/100
# 428/428 [==============================] - 10s 23ms/sample - loss: 1408.3210 - mean_absolute_percentage_error: 1408.3212 - val_loss: 1150.1500 - val_mean_absolute_percentage_error: 1150.1500
# Epoch 13/100
# 428/428 [==============================] - 9s 22ms/sample - loss: 1607.6935 - mean_absolute_percentage_error: 1607.6935 - val_loss: 533.0437 - val_mean_absolute_percentage_error: 533.0437
# Epoch 14/100
# 428/428 [==============================] - 10s 23ms/sample - loss: 1160.7650 - mean_absolute_percentage_error: 1160.7651 - val_loss: 1022.9676 - val_mean_absolute_percentage_error: 1022.9677
# Epoch 15/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 1822.6082 - mean_absolute_percentage_error: 1822.6082 - val_loss: 1733.6473 - val_mean_absolute_percentage_error: 1733.6472
# Epoch 16/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 2968.1826 - mean_absolute_percentage_error: 2968.1826 - val_loss: 4114.7195 - val_mean_absolute_percentage_error: 4114.7197
# Epoch 17/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 2697.0109 - mean_absolute_percentage_error: 2697.0110 - val_loss: 1140.2519 - val_mean_absolute_percentage_error: 1140.2520
# Epoch 18/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 5335.0435 - mean_absolute_percentage_error: 5335.0439 - val_loss: 5610.5506 - val_mean_absolute_percentage_error: 5610.5508
# Epoch 19/100
# 428/428 [==============================] - 9s 22ms/sample - loss: 3045.7506 - mean_absolute_percentage_error: 3045.7510 - val_loss: 4125.8958 - val_mean_absolute_percentage_error: 4125.8960
# Epoch 20/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 917.5324 - mean_absolute_percentage_error: 917.5323 - val_loss: 232.9938 - val_mean_absolute_percentage_error: 232.9938
# Epoch 21/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 2201.4187 - mean_absolute_percentage_error: 2201.4187 - val_loss: 2674.7490 - val_mean_absolute_percentage_error: 2674.7490
# Epoch 22/100
# 428/428 [==============================] - 12s 27ms/sample - loss: 1646.7364 - mean_absolute_percentage_error: 1646.7363 - val_loss: 254.9895 - val_mean_absolute_percentage_error: 254.9895
# Epoch 23/100
# 428/428 [==============================] - 9s 22ms/sample - loss: 2319.2828 - mean_absolute_percentage_error: 2319.2830 - val_loss: 517.6254 - val_mean_absolute_percentage_error: 517.6253
# Epoch 24/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 824.4572 - mean_absolute_percentage_error: 824.4571 - val_loss: 256.4559 - val_mean_absolute_percentage_error: 256.4559
# Epoch 25/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 645.9095 - mean_absolute_percentage_error: 645.9095 - val_loss: 191.7661 - val_mean_absolute_percentage_error: 191.7661
# Epoch 26/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 334.5021 - mean_absolute_percentage_error: 334.5021 - val_loss: 108.9401 - val_mean_absolute_percentage_error: 108.9401
# Epoch 27/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 405.6627 - mean_absolute_percentage_error: 405.6627 - val_loss: 1113.2563 - val_mean_absolute_percentage_error: 1113.2563
# Epoch 28/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 1514.4900 - mean_absolute_percentage_error: 1514.4899 - val_loss: 287.4422 - val_mean_absolute_percentage_error: 287.4422
# Epoch 29/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 1491.8812 - mean_absolute_percentage_error: 1491.8810 - val_loss: 1925.2647 - val_mean_absolute_percentage_error: 1925.2648
# Epoch 30/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 2380.4305 - mean_absolute_percentage_error: 2380.4304 - val_loss: 863.5013 - val_mean_absolute_percentage_error: 863.5013
# Epoch 31/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 851.9346 - mean_absolute_percentage_error: 851.9346 - val_loss: 1420.4821 - val_mean_absolute_percentage_error: 1420.4822
# Epoch 32/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 1507.7600 - mean_absolute_percentage_error: 1507.7599 - val_loss: 2008.5131 - val_mean_absolute_percentage_error: 2008.5129
# Epoch 33/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 1999.5910 - mean_absolute_percentage_error: 1999.5909 - val_loss: 70.5724 - val_mean_absolute_percentage_error: 70.5724
# Epoch 34/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 942.1166 - mean_absolute_percentage_error: 942.1167 - val_loss: 85.4650 - val_mean_absolute_percentage_error: 85.4650
# Epoch 35/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 352.1032 - mean_absolute_percentage_error: 352.1032 - val_loss: 87.7725 - val_mean_absolute_percentage_error: 87.7725
# Epoch 36/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 217.2707 - mean_absolute_percentage_error: 217.2707 - val_loss: 229.3709 - val_mean_absolute_percentage_error: 229.3709
# Epoch 37/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 926.0417 - mean_absolute_percentage_error: 926.0417 - val_loss: 1028.1321 - val_mean_absolute_percentage_error: 1028.1322
# Epoch 38/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 1280.7388 - mean_absolute_percentage_error: 1280.7388 - val_loss: 1378.1254 - val_mean_absolute_percentage_error: 1378.1255
# Epoch 39/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 1462.5034 - mean_absolute_percentage_error: 1462.5034 - val_loss: 663.2574 - val_mean_absolute_percentage_error: 663.2574
# Epoch 40/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 611.3822 - mean_absolute_percentage_error: 611.3823 - val_loss: 360.1452 - val_mean_absolute_percentage_error: 360.1452
# Epoch 41/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 536.8952 - mean_absolute_percentage_error: 536.8952 - val_loss: 851.8793 - val_mean_absolute_percentage_error: 851.8793
# Epoch 42/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 881.8013 - mean_absolute_percentage_error: 881.8013 - val_loss: 397.1865 - val_mean_absolute_percentage_error: 397.1865
# Epoch 43/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 692.1674 - mean_absolute_percentage_error: 692.1674 - val_loss: 615.9923 - val_mean_absolute_percentage_error: 615.9922
# Epoch 44/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 787.4346 - mean_absolute_percentage_error: 787.4346 - val_loss: 1150.8764 - val_mean_absolute_percentage_error: 1150.8763
# Epoch 45/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 480.8231 - mean_absolute_percentage_error: 480.8231 - val_loss: 598.2231 - val_mean_absolute_percentage_error: 598.2231
# Epoch 46/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 543.8640 - mean_absolute_percentage_error: 543.8640 - val_loss: 574.0355 - val_mean_absolute_percentage_error: 574.0355
# Epoch 47/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 1042.1808 - mean_absolute_percentage_error: 1042.1808 - val_loss: 1095.1604 - val_mean_absolute_percentage_error: 1095.1605
# Epoch 48/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 1337.7748 - mean_absolute_percentage_error: 1337.7748 - val_loss: 616.2123 - val_mean_absolute_percentage_error: 616.2123
# Epoch 49/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 561.6524 - mean_absolute_percentage_error: 561.6523 - val_loss: 121.7805 - val_mean_absolute_percentage_error: 121.7805
# Epoch 50/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 1012.0104 - mean_absolute_percentage_error: 1012.0104 - val_loss: 363.8292 - val_mean_absolute_percentage_error: 363.8292
# Epoch 51/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 438.7575 - mean_absolute_percentage_error: 438.7575 - val_loss: 66.2470 - val_mean_absolute_percentage_error: 66.2469
# Epoch 52/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 134.4034 - mean_absolute_percentage_error: 134.4035 - val_loss: 195.0519 - val_mean_absolute_percentage_error: 195.0519
# Epoch 53/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 267.5105 - mean_absolute_percentage_error: 267.5105 - val_loss: 245.4678 - val_mean_absolute_percentage_error: 245.4678
# Epoch 54/100
# 428/428 [==============================] - 10s 23ms/sample - loss: 370.8465 - mean_absolute_percentage_error: 370.8465 - val_loss: 128.9334 - val_mean_absolute_percentage_error: 128.9334
# Epoch 55/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 658.7905 - mean_absolute_percentage_error: 658.7905 - val_loss: 513.4976 - val_mean_absolute_percentage_error: 513.4976
# Epoch 56/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 579.3125 - mean_absolute_percentage_error: 579.3125 - val_loss: 245.8789 - val_mean_absolute_percentage_error: 245.8790
# Epoch 57/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 390.3283 - mean_absolute_percentage_error: 390.3283 - val_loss: 135.4746 - val_mean_absolute_percentage_error: 135.4746
# Epoch 58/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 192.5629 - mean_absolute_percentage_error: 192.5629 - val_loss: 109.2279 - val_mean_absolute_percentage_error: 109.2279
# Epoch 59/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 259.0419 - mean_absolute_percentage_error: 259.0419 - val_loss: 606.9409 - val_mean_absolute_percentage_error: 606.9409
# Epoch 60/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 305.2519 - mean_absolute_percentage_error: 305.2519 - val_loss: 806.7279 - val_mean_absolute_percentage_error: 806.7279
# Epoch 61/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 472.5724 - mean_absolute_percentage_error: 472.5724 - val_loss: 440.3958 - val_mean_absolute_percentage_error: 440.3958
# Epoch 62/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 354.5940 - mean_absolute_percentage_error: 354.5940 - val_loss: 641.8745 - val_mean_absolute_percentage_error: 641.8745
# Epoch 63/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 408.4428 - mean_absolute_percentage_error: 408.4428 - val_loss: 231.9603 - val_mean_absolute_percentage_error: 231.9603
# Epoch 64/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 876.4740 - mean_absolute_percentage_error: 876.4740 - val_loss: 725.6698 - val_mean_absolute_percentage_error: 725.6697
# Epoch 65/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 824.2112 - mean_absolute_percentage_error: 824.2112 - val_loss: 1083.9408 - val_mean_absolute_percentage_error: 1083.9408
# Epoch 66/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 622.9004 - mean_absolute_percentage_error: 622.9004 - val_loss: 400.5151 - val_mean_absolute_percentage_error: 400.5151
# Epoch 67/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 633.1514 - mean_absolute_percentage_error: 633.1514 - val_loss: 266.3915 - val_mean_absolute_percentage_error: 266.3915
# Epoch 68/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 220.9347 - mean_absolute_percentage_error: 220.9347 - val_loss: 402.7120 - val_mean_absolute_percentage_error: 402.7120
# Epoch 69/100
# 428/428 [==============================] - 10s 23ms/sample - loss: 442.7612 - mean_absolute_percentage_error: 442.7612 - val_loss: 344.5181 - val_mean_absolute_percentage_error: 344.5181
# Epoch 70/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 202.4588 - mean_absolute_percentage_error: 202.4588 - val_loss: 61.5758 - val_mean_absolute_percentage_error: 61.5758
# Epoch 71/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 165.9589 - mean_absolute_percentage_error: 165.9589 - val_loss: 181.0331 - val_mean_absolute_percentage_error: 181.0331
# Epoch 72/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 117.8890 - mean_absolute_percentage_error: 117.8890 - val_loss: 73.5213 - val_mean_absolute_percentage_error: 73.5213
# Epoch 73/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 152.3396 - mean_absolute_percentage_error: 152.3396 - val_loss: 79.8877 - val_mean_absolute_percentage_error: 79.8877
# Epoch 74/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 168.9957 - mean_absolute_percentage_error: 168.9957 - val_loss: 93.3416 - val_mean_absolute_percentage_error: 93.3416
# Epoch 75/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 235.5136 - mean_absolute_percentage_error: 235.5136 - val_loss: 181.2063 - val_mean_absolute_percentage_error: 181.2063
# Epoch 76/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 190.4813 - mean_absolute_percentage_error: 190.4813 - val_loss: 348.6253 - val_mean_absolute_percentage_error: 348.6254
# Epoch 77/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 242.1571 - mean_absolute_percentage_error: 242.1571 - val_loss: 68.7224 - val_mean_absolute_percentage_error: 68.7224
# Epoch 78/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 272.4010 - mean_absolute_percentage_error: 272.4010 - val_loss: 533.3177 - val_mean_absolute_percentage_error: 533.3177
# Epoch 79/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 523.8389 - mean_absolute_percentage_error: 523.8389 - val_loss: 530.1898 - val_mean_absolute_percentage_error: 530.1898
# Epoch 80/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 579.8055 - mean_absolute_percentage_error: 579.8055 - val_loss: 137.9710 - val_mean_absolute_percentage_error: 137.9710
# Epoch 81/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 330.1327 - mean_absolute_percentage_error: 330.1327 - val_loss: 81.6948 - val_mean_absolute_percentage_error: 81.6948
# Epoch 82/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 163.2508 - mean_absolute_percentage_error: 163.2508 - val_loss: 263.8380 - val_mean_absolute_percentage_error: 263.8380
# Epoch 83/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 229.5947 - mean_absolute_percentage_error: 229.5947 - val_loss: 233.4029 - val_mean_absolute_percentage_error: 233.4029
# Epoch 84/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 373.4820 - mean_absolute_percentage_error: 373.4820 - val_loss: 1163.3059 - val_mean_absolute_percentage_error: 1163.3058
# Epoch 85/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 1015.9290 - mean_absolute_percentage_error: 1015.9289 - val_loss: 983.2369 - val_mean_absolute_percentage_error: 983.2369
# Epoch 86/100
# 428/428 [==============================] - 9s 20ms/sample - loss: 826.1753 - mean_absolute_percentage_error: 826.1752 - val_loss: 103.5726 - val_mean_absolute_percentage_error: 103.5727
# Epoch 87/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 443.9271 - mean_absolute_percentage_error: 443.9271 - val_loss: 630.6114 - val_mean_absolute_percentage_error: 630.6114
# Epoch 88/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 257.8601 - mean_absolute_percentage_error: 257.8601 - val_loss: 340.1655 - val_mean_absolute_percentage_error: 340.1655
# Epoch 89/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 330.9483 - mean_absolute_percentage_error: 330.9483 - val_loss: 332.4365 - val_mean_absolute_percentage_error: 332.4365
# Epoch 90/100
# 428/428 [==============================] - 10s 23ms/sample - loss: 339.8730 - mean_absolute_percentage_error: 339.8730 - val_loss: 234.1534 - val_mean_absolute_percentage_error: 234.1534
# Epoch 91/100
# 428/428 [==============================] - 9s 21ms/sample - loss: 184.6008 - mean_absolute_percentage_error: 184.6008 - val_loss: 67.8721 - val_mean_absolute_percentage_error: 67.8721
# Epoch 92/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 125.3721 - mean_absolute_percentage_error: 125.3721 - val_loss: 243.8477 - val_mean_absolute_percentage_error: 243.8477
# Epoch 93/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 246.5085 - mean_absolute_percentage_error: 246.5085 - val_loss: 109.7697 - val_mean_absolute_percentage_error: 109.7697
# Epoch 94/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 260.3610 - mean_absolute_percentage_error: 260.3610 - val_loss: 80.8054 - val_mean_absolute_percentage_error: 80.8054
# Epoch 95/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 152.1244 - mean_absolute_percentage_error: 152.1244 - val_loss: 203.7732 - val_mean_absolute_percentage_error: 203.7732
# Epoch 96/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 315.1019 - mean_absolute_percentage_error: 315.1019 - val_loss: 170.4962 - val_mean_absolute_percentage_error: 170.4962
# Epoch 97/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 212.8812 - mean_absolute_percentage_error: 212.8813 - val_loss: 104.3227 - val_mean_absolute_percentage_error: 104.3227
# Epoch 98/100
# 428/428 [==============================] - 8s 20ms/sample - loss: 246.2624 - mean_absolute_percentage_error: 246.2624 - val_loss: 267.6901 - val_mean_absolute_percentage_error: 267.6901
# Epoch 99/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 294.6969 - mean_absolute_percentage_error: 294.6969 - val_loss: 373.9167 - val_mean_absolute_percentage_error: 373.9167
# Epoch 100/100
# 428/428 [==============================] - 8s 19ms/sample - loss: 196.5121 - mean_absolute_percentage_error: 196.5121 - val_loss: 251.0929 - val_mean_absolute_percentage_error: 251.0928
# 2024-01-24 02:21:15.498537: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_197/BiasAdd' id:27668 op device:{requested: '', assigned: ''} def:{{{node dense_197/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_197/MatMul, dense_197/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 251.09%
# Time Elapsed: 29146.13321685791

# %%
model7.summary()
# Out:
# Model: "sequential_95"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_314 (Conv2D)         (None, 62, 62, 64)        1792
#
#  conv2d_315 (Conv2D)         (None, 60, 60, 64)        36928
#
#  max_pooling2d_211 (MaxPooli  (None, 30, 30, 64)       0
#  ng2D)
#
#  conv2d_316 (Conv2D)         (None, 28, 28, 128)       73856
#
#  conv2d_317 (Conv2D)         (None, 26, 26, 128)       147584
#
#  max_pooling2d_212 (MaxPooli  (None, 13, 13, 128)      0
#  ng2D)
#
#  flatten_87 (Flatten)        (None, 21632)             0
#
#  dense_195 (Dense)           (None, 1024)              22152192
#
#  dense_196 (Dense)           (None, 1024)              1049600
#
#  dense_197 (Dense)           (None, 1)                 1025
#
# =================================================================
# Total params: 23,462,977
# Trainable params: 23,462,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
#4 Layer All RELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model8 = Sequential()
model8.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model8.add(MaxPooling2D((2, 2)))
model8.add(Conv2D(64, (3, 3), activation='relu'))
model8.add(MaxPooling2D((2, 2)))
model8.add(Conv2D(128, (3, 3), activation='relu'))
model8.add(MaxPooling2D((2, 2)))
model8.add(Conv2D(256, (3, 3), activation='relu'))
model8.add(MaxPooling2D((2, 2)))
model8.add(Flatten())
model8.add(Dense(512, activation='relu'))
model8.add(Dense(256, activation='relu'))
model8.add(Dense(1, activation='linear'))

opt =Adam(lr=1e-3, decay=1e-3 / 200)
model8.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history8 = model8.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history8.history['loss'], label='Training Loss', color='green')
plt.plot(history8.history['val_loss'], label='Validation Loss', color='red')

plt.title('4 Layer All RELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('4 Layer All RELU.png')
plt.show()

#-----

prices_predicted = model8.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 02:21:21.333017: W tensorflow/c/c_api.cc:300] Operation '{name:'training_74/Adam/conv2d_319/bias/m/Assign' id:28577 op device:{requested: '', assigned: ''} def:{{{node training_74/Adam/conv2d_319/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_74/Adam/conv2d_319/bias/m, training_74/Adam/conv2d_319/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 416/428 [============================>.] - ETA: 0s - loss: 134.0364 - mean_absolute_percentage_error: 134.0363
# 2024-01-24 02:21:23.727762: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_49/mul' id:28404 op device:{requested: '', assigned: ''} def:{{{node loss_49/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_49/mul/x, loss_49/dense_200_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 2s 5ms/sample - loss: 132.3963 - mean_absolute_percentage_error: 132.3963 - val_loss: 65.5815 - val_mean_absolute_percentage_error: 65.5815
# Epoch 2/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 71.7947 - mean_absolute_percentage_error: 71.7947 - val_loss: 73.3355 - val_mean_absolute_percentage_error: 73.3355
# Epoch 3/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 68.7766 - mean_absolute_percentage_error: 68.7766 - val_loss: 61.6524 - val_mean_absolute_percentage_error: 61.6524
# Epoch 4/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 65.2641 - mean_absolute_percentage_error: 65.2641 - val_loss: 75.2451 - val_mean_absolute_percentage_error: 75.2451
# Epoch 5/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 70.2445 - mean_absolute_percentage_error: 70.2444 - val_loss: 73.2192 - val_mean_absolute_percentage_error: 73.2192
# Epoch 6/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 68.8761 - mean_absolute_percentage_error: 68.8761 - val_loss: 69.0487 - val_mean_absolute_percentage_error: 69.0487
# Epoch 7/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 64.6786 - mean_absolute_percentage_error: 64.6786 - val_loss: 64.1866 - val_mean_absolute_percentage_error: 64.1866
# Epoch 8/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 66.4354 - mean_absolute_percentage_error: 66.4354 - val_loss: 62.8441 - val_mean_absolute_percentage_error: 62.8441
# Epoch 9/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 63.4623 - mean_absolute_percentage_error: 63.4623 - val_loss: 54.9226 - val_mean_absolute_percentage_error: 54.9226
# Epoch 10/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 56.2316 - mean_absolute_percentage_error: 56.2316 - val_loss: 58.9087 - val_mean_absolute_percentage_error: 58.9087
# Epoch 11/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 58.9051 - mean_absolute_percentage_error: 58.9051 - val_loss: 63.1950 - val_mean_absolute_percentage_error: 63.1950
# Epoch 12/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 65.0725 - mean_absolute_percentage_error: 65.0725 - val_loss: 57.6685 - val_mean_absolute_percentage_error: 57.6685
# Epoch 13/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 59.0609 - mean_absolute_percentage_error: 59.0609 - val_loss: 56.9195 - val_mean_absolute_percentage_error: 56.9195
# Epoch 14/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 58.8910 - mean_absolute_percentage_error: 58.8910 - val_loss: 56.7003 - val_mean_absolute_percentage_error: 56.7003
# Epoch 15/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 53.8191 - mean_absolute_percentage_error: 53.8191 - val_loss: 54.9904 - val_mean_absolute_percentage_error: 54.9904
# Epoch 16/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 47.4531 - mean_absolute_percentage_error: 47.4531 - val_loss: 54.9560 - val_mean_absolute_percentage_error: 54.9560
# Epoch 17/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 50.5075 - mean_absolute_percentage_error: 50.5075 - val_loss: 54.1528 - val_mean_absolute_percentage_error: 54.1528
# Epoch 18/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 47.1680 - mean_absolute_percentage_error: 47.1680 - val_loss: 57.4192 - val_mean_absolute_percentage_error: 57.4192
# Epoch 19/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 45.5443 - mean_absolute_percentage_error: 45.5443 - val_loss: 55.3070 - val_mean_absolute_percentage_error: 55.3070
# Epoch 20/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.7405 - mean_absolute_percentage_error: 41.7405 - val_loss: 58.6499 - val_mean_absolute_percentage_error: 58.6499
# Epoch 21/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 39.7243 - mean_absolute_percentage_error: 39.7243 - val_loss: 60.2819 - val_mean_absolute_percentage_error: 60.2819
# Epoch 22/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 35.4417 - mean_absolute_percentage_error: 35.4417 - val_loss: 58.1641 - val_mean_absolute_percentage_error: 58.1641
# Epoch 23/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 38.0789 - mean_absolute_percentage_error: 38.0789 - val_loss: 56.4299 - val_mean_absolute_percentage_error: 56.4299
# Epoch 24/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.7514 - mean_absolute_percentage_error: 41.7514 - val_loss: 64.8543 - val_mean_absolute_percentage_error: 64.8543
# Epoch 25/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.8447 - mean_absolute_percentage_error: 41.8447 - val_loss: 62.6677 - val_mean_absolute_percentage_error: 62.6677
# Epoch 26/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.0094 - mean_absolute_percentage_error: 41.0094 - val_loss: 61.0773 - val_mean_absolute_percentage_error: 61.0774
# Epoch 27/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.2910 - mean_absolute_percentage_error: 32.2910 - val_loss: 60.9998 - val_mean_absolute_percentage_error: 60.9998
# Epoch 28/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 29.1183 - mean_absolute_percentage_error: 29.1183 - val_loss: 63.7902 - val_mean_absolute_percentage_error: 63.7902
# Epoch 29/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.6724 - mean_absolute_percentage_error: 30.6724 - val_loss: 54.8042 - val_mean_absolute_percentage_error: 54.8042
# Epoch 30/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 29.5837 - mean_absolute_percentage_error: 29.5836 - val_loss: 57.8665 - val_mean_absolute_percentage_error: 57.8666
# Epoch 31/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.5754 - mean_absolute_percentage_error: 28.5754 - val_loss: 70.8576 - val_mean_absolute_percentage_error: 70.8576
# Epoch 32/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.8782 - mean_absolute_percentage_error: 30.8782 - val_loss: 58.4352 - val_mean_absolute_percentage_error: 58.4352
# Epoch 33/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.7403 - mean_absolute_percentage_error: 28.7403 - val_loss: 64.5246 - val_mean_absolute_percentage_error: 64.5246
# Epoch 34/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 25.0787 - mean_absolute_percentage_error: 25.0787 - val_loss: 63.9861 - val_mean_absolute_percentage_error: 63.9861
# Epoch 35/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 26.6198 - mean_absolute_percentage_error: 26.6198 - val_loss: 78.5287 - val_mean_absolute_percentage_error: 78.5287
# Epoch 36/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 29.0065 - mean_absolute_percentage_error: 29.0065 - val_loss: 56.3963 - val_mean_absolute_percentage_error: 56.3963
# Epoch 37/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 26.5267 - mean_absolute_percentage_error: 26.5267 - val_loss: 62.1774 - val_mean_absolute_percentage_error: 62.1774
# Epoch 38/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.7217 - mean_absolute_percentage_error: 22.7217 - val_loss: 63.3502 - val_mean_absolute_percentage_error: 63.3502
# Epoch 39/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.4920 - mean_absolute_percentage_error: 22.4920 - val_loss: 58.4938 - val_mean_absolute_percentage_error: 58.4938
# Epoch 40/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 19.2308 - mean_absolute_percentage_error: 19.2308 - val_loss: 67.7655 - val_mean_absolute_percentage_error: 67.7654
# Epoch 41/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 22.3955 - mean_absolute_percentage_error: 22.3955 - val_loss: 58.5136 - val_mean_absolute_percentage_error: 58.5136
# Epoch 42/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 21.7449 - mean_absolute_percentage_error: 21.7449 - val_loss: 74.4330 - val_mean_absolute_percentage_error: 74.4330
# Epoch 43/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 19.8891 - mean_absolute_percentage_error: 19.8891 - val_loss: 62.2355 - val_mean_absolute_percentage_error: 62.2355
# Epoch 44/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 20.8895 - mean_absolute_percentage_error: 20.8895 - val_loss: 78.0875 - val_mean_absolute_percentage_error: 78.0875
# Epoch 45/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 19.7000 - mean_absolute_percentage_error: 19.7000 - val_loss: 65.1455 - val_mean_absolute_percentage_error: 65.1455
# Epoch 46/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 21.1636 - mean_absolute_percentage_error: 21.1636 - val_loss: 64.9355 - val_mean_absolute_percentage_error: 64.9355
# Epoch 47/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 19.0265 - mean_absolute_percentage_error: 19.0265 - val_loss: 68.6022 - val_mean_absolute_percentage_error: 68.6022
# Epoch 48/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 17.4381 - mean_absolute_percentage_error: 17.4381 - val_loss: 63.2860 - val_mean_absolute_percentage_error: 63.2860
# Epoch 49/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 18.7069 - mean_absolute_percentage_error: 18.7069 - val_loss: 74.5538 - val_mean_absolute_percentage_error: 74.5538
# Epoch 50/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 17.7113 - mean_absolute_percentage_error: 17.7113 - val_loss: 61.8750 - val_mean_absolute_percentage_error: 61.8750
# Epoch 51/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.6650 - mean_absolute_percentage_error: 16.6650 - val_loss: 67.7393 - val_mean_absolute_percentage_error: 67.7393
# Epoch 52/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.8425 - mean_absolute_percentage_error: 16.8425 - val_loss: 69.4395 - val_mean_absolute_percentage_error: 69.4395
# Epoch 53/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.8412 - mean_absolute_percentage_error: 15.8412 - val_loss: 69.8173 - val_mean_absolute_percentage_error: 69.8173
# Epoch 54/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.8003 - mean_absolute_percentage_error: 16.8003 - val_loss: 64.7838 - val_mean_absolute_percentage_error: 64.7838
# Epoch 55/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.9659 - mean_absolute_percentage_error: 16.9659 - val_loss: 84.9723 - val_mean_absolute_percentage_error: 84.9723
# Epoch 56/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 17.7864 - mean_absolute_percentage_error: 17.7864 - val_loss: 66.1816 - val_mean_absolute_percentage_error: 66.1816
# Epoch 57/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.4770 - mean_absolute_percentage_error: 15.4770 - val_loss: 72.0727 - val_mean_absolute_percentage_error: 72.0727
# Epoch 58/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.4078 - mean_absolute_percentage_error: 15.4078 - val_loss: 68.1908 - val_mean_absolute_percentage_error: 68.1908
# Epoch 59/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.5362 - mean_absolute_percentage_error: 15.5362 - val_loss: 68.6337 - val_mean_absolute_percentage_error: 68.6337
# Epoch 60/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.0258 - mean_absolute_percentage_error: 14.0258 - val_loss: 70.5179 - val_mean_absolute_percentage_error: 70.5179
# Epoch 61/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.5980 - mean_absolute_percentage_error: 14.5980 - val_loss: 72.9186 - val_mean_absolute_percentage_error: 72.9186
# Epoch 62/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.9805 - mean_absolute_percentage_error: 13.9805 - val_loss: 68.8441 - val_mean_absolute_percentage_error: 68.8441
# Epoch 63/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 15.0629 - mean_absolute_percentage_error: 15.0629 - val_loss: 65.1869 - val_mean_absolute_percentage_error: 65.1869
# Epoch 64/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.2973 - mean_absolute_percentage_error: 14.2973 - val_loss: 68.7872 - val_mean_absolute_percentage_error: 68.7872
# Epoch 65/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.8459 - mean_absolute_percentage_error: 13.8459 - val_loss: 64.5227 - val_mean_absolute_percentage_error: 64.5227
# Epoch 66/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.1269 - mean_absolute_percentage_error: 13.1269 - val_loss: 87.1182 - val_mean_absolute_percentage_error: 87.1182
# Epoch 67/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 16.1834 - mean_absolute_percentage_error: 16.1834 - val_loss: 69.1312 - val_mean_absolute_percentage_error: 69.1312
# Epoch 68/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.5831 - mean_absolute_percentage_error: 12.5831 - val_loss: 69.7659 - val_mean_absolute_percentage_error: 69.7659
# Epoch 69/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.8597 - mean_absolute_percentage_error: 12.8597 - val_loss: 71.0358 - val_mean_absolute_percentage_error: 71.0358
# Epoch 70/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.0396 - mean_absolute_percentage_error: 13.0396 - val_loss: 64.8134 - val_mean_absolute_percentage_error: 64.8134
# Epoch 71/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.0341 - mean_absolute_percentage_error: 12.0341 - val_loss: 72.8065 - val_mean_absolute_percentage_error: 72.8065
# Epoch 72/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.0062 - mean_absolute_percentage_error: 13.0062 - val_loss: 82.6113 - val_mean_absolute_percentage_error: 82.6113
# Epoch 73/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 14.0465 - mean_absolute_percentage_error: 14.0465 - val_loss: 65.0989 - val_mean_absolute_percentage_error: 65.0989
# Epoch 74/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 13.6446 - mean_absolute_percentage_error: 13.6446 - val_loss: 77.2542 - val_mean_absolute_percentage_error: 77.2542
# Epoch 75/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.6477 - mean_absolute_percentage_error: 11.6477 - val_loss: 74.3132 - val_mean_absolute_percentage_error: 74.3132
# Epoch 76/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 12.2564 - mean_absolute_percentage_error: 12.2564 - val_loss: 71.4899 - val_mean_absolute_percentage_error: 71.4899
# Epoch 77/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.8763 - mean_absolute_percentage_error: 11.8763 - val_loss: 73.8063 - val_mean_absolute_percentage_error: 73.8063
# Epoch 78/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.7845 - mean_absolute_percentage_error: 10.7845 - val_loss: 75.8625 - val_mean_absolute_percentage_error: 75.8625
# Epoch 79/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.6037 - mean_absolute_percentage_error: 10.6037 - val_loss: 75.3344 - val_mean_absolute_percentage_error: 75.3344
# Epoch 80/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.5882 - mean_absolute_percentage_error: 10.5882 - val_loss: 68.1860 - val_mean_absolute_percentage_error: 68.1860
# Epoch 81/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.3716 - mean_absolute_percentage_error: 10.3716 - val_loss: 75.7154 - val_mean_absolute_percentage_error: 75.7154
# Epoch 82/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.0450 - mean_absolute_percentage_error: 10.0450 - val_loss: 69.1670 - val_mean_absolute_percentage_error: 69.1670
# Epoch 83/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.4669 - mean_absolute_percentage_error: 10.4669 - val_loss: 70.1854 - val_mean_absolute_percentage_error: 70.1854
# Epoch 84/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.9727 - mean_absolute_percentage_error: 9.9727 - val_loss: 73.1355 - val_mean_absolute_percentage_error: 73.1356
# Epoch 85/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.4583 - mean_absolute_percentage_error: 9.4583 - val_loss: 70.9069 - val_mean_absolute_percentage_error: 70.9069
# Epoch 86/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.8606 - mean_absolute_percentage_error: 9.8606 - val_loss: 72.9454 - val_mean_absolute_percentage_error: 72.9454
# Epoch 87/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.0813 - mean_absolute_percentage_error: 10.0813 - val_loss: 62.6193 - val_mean_absolute_percentage_error: 62.6193
# Epoch 88/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.2515 - mean_absolute_percentage_error: 10.2515 - val_loss: 78.2667 - val_mean_absolute_percentage_error: 78.2667
# Epoch 89/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.4865 - mean_absolute_percentage_error: 11.4865 - val_loss: 85.0801 - val_mean_absolute_percentage_error: 85.0801
# Epoch 90/100
# 428/428 [==============================] - 2s 5ms/sample - loss: 10.7394 - mean_absolute_percentage_error: 10.7394 - val_loss: 70.2967 - val_mean_absolute_percentage_error: 70.2967
# Epoch 91/100
# 428/428 [==============================] - 2s 4ms/sample - loss: 10.1919 - mean_absolute_percentage_error: 10.1919 - val_loss: 70.5723 - val_mean_absolute_percentage_error: 70.5723
# Epoch 92/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 11.2561 - mean_absolute_percentage_error: 11.2561 - val_loss: 75.5611 - val_mean_absolute_percentage_error: 75.5611
# Epoch 93/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.7955 - mean_absolute_percentage_error: 10.7955 - val_loss: 83.0166 - val_mean_absolute_percentage_error: 83.0166
# Epoch 94/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.6047 - mean_absolute_percentage_error: 10.6047 - val_loss: 71.1092 - val_mean_absolute_percentage_error: 71.1092
# Epoch 95/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 9.6549 - mean_absolute_percentage_error: 9.6549 - val_loss: 89.7641 - val_mean_absolute_percentage_error: 89.7641
# Epoch 96/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.5051 - mean_absolute_percentage_error: 10.5051 - val_loss: 67.2757 - val_mean_absolute_percentage_error: 67.2757
# Epoch 97/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 11.9449 - mean_absolute_percentage_error: 11.9449 - val_loss: 77.1741 - val_mean_absolute_percentage_error: 77.1741
# Epoch 98/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 10.5308 - mean_absolute_percentage_error: 10.5308 - val_loss: 70.0853 - val_mean_absolute_percentage_error: 70.0853
# Epoch 99/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 9.0811 - mean_absolute_percentage_error: 9.0811 - val_loss: 69.1497 - val_mean_absolute_percentage_error: 69.1497
# Epoch 100/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 8.8713 - mean_absolute_percentage_error: 8.8713 - val_loss: 77.1593 - val_mean_absolute_percentage_error: 77.1593
# 2024-01-24 02:22:58.919169: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_200/BiasAdd' id:28347 op device:{requested: '', assigned: ''} def:{{{node dense_200/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_200/MatMul, dense_200/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 77.16%
# Time Elapsed: 29249.57018518448

# %%
#4 Layer All ELU

import tensorflow as tf
import time
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
from keras.models import load_model

tf.random.set_seed(1234)

start_time = time.time()

chanDim = -1
model9 = Sequential()
model9.add(Conv2D(32, (3, 3), activation='elu', input_shape=(64, 64, 3)))
model9.add(MaxPooling2D((2, 2)))
model9.add(Conv2D(64, (3, 3), activation='elu'))
model9.add(MaxPooling2D((2, 2)))
model9.add(Conv2D(128, (3, 3), activation='elu'))
model9.add(MaxPooling2D((2, 2)))
model9.add(Conv2D(256, (3, 3), activation='elu'))
model9.add(MaxPooling2D((2, 2)))
model9.add(Flatten())
model9.add(Dense(512, activation='elu'))
model9.add(Dense(256, activation='elu'))
model9.add(Dense(1, activation='linear'))

opt =Adam(lr=1e-3, decay=1e-3 / 200)
model9.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history9 = model9.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
start_time = time.time()

# Plot all metrics on the same graph
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history9.history['loss'], label='Training Loss', color='green')
plt.plot(history9.history['val_loss'], label='Validation Loss', color='red')

plt.title('4 Layer All ELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('4 Layer All ELU.png')
plt.show()

#-----

prices_predicted = model9.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
print("Time Elapsed: " + str(start_time - end_time))
# Out:
# [INFO] training model...
# Train on 428 samples, validate on 106 samples
# 2024-01-24 02:23:01.313542: W tensorflow/c/c_api.cc:300] Operation '{name:'training_76/Adam/conv2d_325/bias/v/Assign' id:29346 op device:{requested: '', assigned: ''} def:{{{node training_76/Adam/conv2d_325/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training_76/Adam/conv2d_325/bias/v, training_76/Adam/conv2d_325/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 416/428 [============================>.] - ETA: 0s - loss: 1656.1750 - mean_absolute_percentage_error: 1656.1750
# 2024-01-24 02:23:03.493537: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_50/mul' id:29069 op device:{requested: '', assigned: ''} def:{{{node loss_50/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_50/mul/x, loss_50/dense_203_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 428/428 [==============================] - 2s 5ms/sample - loss: 1619.0505 - mean_absolute_percentage_error: 1619.0505 - val_loss: 111.6650 - val_mean_absolute_percentage_error: 111.6650
# Epoch 2/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 145.4385 - mean_absolute_percentage_error: 145.4385 - val_loss: 67.9702 - val_mean_absolute_percentage_error: 67.9702
# Epoch 3/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 114.1943 - mean_absolute_percentage_error: 114.1943 - val_loss: 64.9071 - val_mean_absolute_percentage_error: 64.9071
# Epoch 4/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 85.7993 - mean_absolute_percentage_error: 85.7993 - val_loss: 76.2606 - val_mean_absolute_percentage_error: 76.2607
# Epoch 5/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 68.9165 - mean_absolute_percentage_error: 68.9165 - val_loss: 61.5499 - val_mean_absolute_percentage_error: 61.5499
# Epoch 6/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 65.0955 - mean_absolute_percentage_error: 65.0955 - val_loss: 56.5018 - val_mean_absolute_percentage_error: 56.5018
# Epoch 7/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 61.8667 - mean_absolute_percentage_error: 61.8667 - val_loss: 61.2480 - val_mean_absolute_percentage_error: 61.2480
# Epoch 8/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 66.2774 - mean_absolute_percentage_error: 66.2774 - val_loss: 66.3365 - val_mean_absolute_percentage_error: 66.3365
# Epoch 9/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 72.3306 - mean_absolute_percentage_error: 72.3306 - val_loss: 67.1435 - val_mean_absolute_percentage_error: 67.1435
# Epoch 10/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 60.7102 - mean_absolute_percentage_error: 60.7102 - val_loss: 58.0426 - val_mean_absolute_percentage_error: 58.0426
# Epoch 11/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 51.4900 - mean_absolute_percentage_error: 51.4900 - val_loss: 92.4366 - val_mean_absolute_percentage_error: 92.4366
# Epoch 12/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 68.1293 - mean_absolute_percentage_error: 68.1293 - val_loss: 61.3459 - val_mean_absolute_percentage_error: 61.3459
# Epoch 13/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 60.4594 - mean_absolute_percentage_error: 60.4594 - val_loss: 64.7182 - val_mean_absolute_percentage_error: 64.7182
# Epoch 14/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 65.7456 - mean_absolute_percentage_error: 65.7456 - val_loss: 59.0037 - val_mean_absolute_percentage_error: 59.0037
# Epoch 15/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 52.6688 - mean_absolute_percentage_error: 52.6688 - val_loss: 70.2148 - val_mean_absolute_percentage_error: 70.2148
# Epoch 16/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 50.0649 - mean_absolute_percentage_error: 50.0649 - val_loss: 67.4449 - val_mean_absolute_percentage_error: 67.4449
# Epoch 17/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 45.5862 - mean_absolute_percentage_error: 45.5862 - val_loss: 58.7035 - val_mean_absolute_percentage_error: 58.7035
# Epoch 18/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 43.9719 - mean_absolute_percentage_error: 43.9719 - val_loss: 55.7839 - val_mean_absolute_percentage_error: 55.7839
# Epoch 19/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 49.6349 - mean_absolute_percentage_error: 49.6349 - val_loss: 63.6673 - val_mean_absolute_percentage_error: 63.6673
# Epoch 20/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 51.2178 - mean_absolute_percentage_error: 51.2178 - val_loss: 57.2670 - val_mean_absolute_percentage_error: 57.2670
# Epoch 21/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.0329 - mean_absolute_percentage_error: 40.0329 - val_loss: 65.5858 - val_mean_absolute_percentage_error: 65.5858
# Epoch 22/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 46.8069 - mean_absolute_percentage_error: 46.8069 - val_loss: 66.3720 - val_mean_absolute_percentage_error: 66.3720
# Epoch 23/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 46.2869 - mean_absolute_percentage_error: 46.2869 - val_loss: 61.2055 - val_mean_absolute_percentage_error: 61.2055
# Epoch 24/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 46.1997 - mean_absolute_percentage_error: 46.1997 - val_loss: 72.6579 - val_mean_absolute_percentage_error: 72.6579
# Epoch 25/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 43.0732 - mean_absolute_percentage_error: 43.0732 - val_loss: 74.6548 - val_mean_absolute_percentage_error: 74.6548
# Epoch 26/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 50.7962 - mean_absolute_percentage_error: 50.7962 - val_loss: 69.2457 - val_mean_absolute_percentage_error: 69.2457
# Epoch 27/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 50.1648 - mean_absolute_percentage_error: 50.1648 - val_loss: 65.0116 - val_mean_absolute_percentage_error: 65.0116
# Epoch 28/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 44.4673 - mean_absolute_percentage_error: 44.4673 - val_loss: 60.3108 - val_mean_absolute_percentage_error: 60.3108
# Epoch 29/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.7780 - mean_absolute_percentage_error: 40.7780 - val_loss: 69.7987 - val_mean_absolute_percentage_error: 69.7987
# Epoch 30/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 47.1698 - mean_absolute_percentage_error: 47.1698 - val_loss: 57.3086 - val_mean_absolute_percentage_error: 57.3086
# Epoch 31/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 47.6051 - mean_absolute_percentage_error: 47.6051 - val_loss: 60.0027 - val_mean_absolute_percentage_error: 60.0027
# Epoch 32/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 46.0967 - mean_absolute_percentage_error: 46.0967 - val_loss: 55.8510 - val_mean_absolute_percentage_error: 55.8511
# Epoch 33/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 62.2791 - mean_absolute_percentage_error: 62.2791 - val_loss: 58.0473 - val_mean_absolute_percentage_error: 58.0473
# Epoch 34/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 44.2697 - mean_absolute_percentage_error: 44.2697 - val_loss: 61.3599 - val_mean_absolute_percentage_error: 61.3599
# Epoch 35/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 51.1828 - mean_absolute_percentage_error: 51.1828 - val_loss: 73.5124 - val_mean_absolute_percentage_error: 73.5124
# Epoch 36/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 44.7655 - mean_absolute_percentage_error: 44.7655 - val_loss: 80.4224 - val_mean_absolute_percentage_error: 80.4224
# Epoch 37/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 49.9533 - mean_absolute_percentage_error: 49.9533 - val_loss: 63.2481 - val_mean_absolute_percentage_error: 63.2481
# Epoch 38/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 43.1754 - mean_absolute_percentage_error: 43.1754 - val_loss: 69.7173 - val_mean_absolute_percentage_error: 69.7173
# Epoch 39/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 51.4043 - mean_absolute_percentage_error: 51.4043 - val_loss: 87.6164 - val_mean_absolute_percentage_error: 87.6164
# Epoch 40/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 43.7093 - mean_absolute_percentage_error: 43.7093 - val_loss: 62.9984 - val_mean_absolute_percentage_error: 62.9984
# Epoch 41/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 43.3855 - mean_absolute_percentage_error: 43.3855 - val_loss: 69.2593 - val_mean_absolute_percentage_error: 69.2593
# Epoch 42/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.1325 - mean_absolute_percentage_error: 40.1325 - val_loss: 78.9741 - val_mean_absolute_percentage_error: 78.9741
# Epoch 43/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 42.7900 - mean_absolute_percentage_error: 42.7900 - val_loss: 78.0647 - val_mean_absolute_percentage_error: 78.0647
# Epoch 44/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 42.0549 - mean_absolute_percentage_error: 42.0549 - val_loss: 67.3242 - val_mean_absolute_percentage_error: 67.3242
# Epoch 45/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.1747 - mean_absolute_percentage_error: 40.1747 - val_loss: 65.0607 - val_mean_absolute_percentage_error: 65.0607
# Epoch 46/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 42.3576 - mean_absolute_percentage_error: 42.3576 - val_loss: 75.3157 - val_mean_absolute_percentage_error: 75.3158
# Epoch 47/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 38.3868 - mean_absolute_percentage_error: 38.3868 - val_loss: 86.6103 - val_mean_absolute_percentage_error: 86.6103
# Epoch 48/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 50.6045 - mean_absolute_percentage_error: 50.6045 - val_loss: 82.6259 - val_mean_absolute_percentage_error: 82.6259
# Epoch 49/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 36.8846 - mean_absolute_percentage_error: 36.8846 - val_loss: 80.8851 - val_mean_absolute_percentage_error: 80.8851
# Epoch 50/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 49.8514 - mean_absolute_percentage_error: 49.8514 - val_loss: 67.1867 - val_mean_absolute_percentage_error: 67.1867
# Epoch 51/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.8410 - mean_absolute_percentage_error: 37.8410 - val_loss: 66.5294 - val_mean_absolute_percentage_error: 66.5294
# Epoch 52/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 42.0223 - mean_absolute_percentage_error: 42.0223 - val_loss: 63.1600 - val_mean_absolute_percentage_error: 63.1600
# Epoch 53/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.6985 - mean_absolute_percentage_error: 37.6985 - val_loss: 72.7153 - val_mean_absolute_percentage_error: 72.7153
# Epoch 54/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 39.0417 - mean_absolute_percentage_error: 39.0417 - val_loss: 75.7248 - val_mean_absolute_percentage_error: 75.7248
# Epoch 55/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 35.2395 - mean_absolute_percentage_error: 35.2396 - val_loss: 77.8784 - val_mean_absolute_percentage_error: 77.8784
# Epoch 56/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 38.0574 - mean_absolute_percentage_error: 38.0574 - val_loss: 68.4111 - val_mean_absolute_percentage_error: 68.4111
# Epoch 57/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 35.7206 - mean_absolute_percentage_error: 35.7206 - val_loss: 69.5668 - val_mean_absolute_percentage_error: 69.5668
# Epoch 58/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 35.2565 - mean_absolute_percentage_error: 35.2565 - val_loss: 69.8323 - val_mean_absolute_percentage_error: 69.8323
# Epoch 59/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.2493 - mean_absolute_percentage_error: 31.2493 - val_loss: 67.9116 - val_mean_absolute_percentage_error: 67.9116
# Epoch 60/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.8419 - mean_absolute_percentage_error: 40.8419 - val_loss: 63.4333 - val_mean_absolute_percentage_error: 63.4333
# Epoch 61/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.9075 - mean_absolute_percentage_error: 41.9075 - val_loss: 93.7343 - val_mean_absolute_percentage_error: 93.7343
# Epoch 62/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 46.0289 - mean_absolute_percentage_error: 46.0289 - val_loss: 74.0266 - val_mean_absolute_percentage_error: 74.0266
# Epoch 63/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.2397 - mean_absolute_percentage_error: 40.2397 - val_loss: 69.2571 - val_mean_absolute_percentage_error: 69.2571
# Epoch 64/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 42.5894 - mean_absolute_percentage_error: 42.5894 - val_loss: 72.7691 - val_mean_absolute_percentage_error: 72.7691
# Epoch 65/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 39.2192 - mean_absolute_percentage_error: 39.2192 - val_loss: 66.9893 - val_mean_absolute_percentage_error: 66.9893
# Epoch 66/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.0646 - mean_absolute_percentage_error: 40.0646 - val_loss: 67.4987 - val_mean_absolute_percentage_error: 67.4987
# Epoch 67/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 29.8447 - mean_absolute_percentage_error: 29.8447 - val_loss: 63.1934 - val_mean_absolute_percentage_error: 63.1934
# Epoch 68/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.7781 - mean_absolute_percentage_error: 37.7781 - val_loss: 66.8319 - val_mean_absolute_percentage_error: 66.8319
# Epoch 69/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 34.6749 - mean_absolute_percentage_error: 34.6749 - val_loss: 63.9505 - val_mean_absolute_percentage_error: 63.9505
# Epoch 70/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.1908 - mean_absolute_percentage_error: 37.1908 - val_loss: 67.8654 - val_mean_absolute_percentage_error: 67.8654
# Epoch 71/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 33.8697 - mean_absolute_percentage_error: 33.8697 - val_loss: 63.5894 - val_mean_absolute_percentage_error: 63.5894
# Epoch 72/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.8277 - mean_absolute_percentage_error: 40.8277 - val_loss: 61.4049 - val_mean_absolute_percentage_error: 61.4049
# Epoch 73/100
# 428/428 [==============================] - 1s 3ms/sample - loss: 36.9106 - mean_absolute_percentage_error: 36.9106 - val_loss: 63.9139 - val_mean_absolute_percentage_error: 63.9139
# Epoch 74/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.5686 - mean_absolute_percentage_error: 41.5686 - val_loss: 71.4033 - val_mean_absolute_percentage_error: 71.4033
# Epoch 75/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 39.2174 - mean_absolute_percentage_error: 39.2174 - val_loss: 72.5929 - val_mean_absolute_percentage_error: 72.5929
# Epoch 76/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.4738 - mean_absolute_percentage_error: 37.4738 - val_loss: 77.8120 - val_mean_absolute_percentage_error: 77.8120
# Epoch 77/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 38.4655 - mean_absolute_percentage_error: 38.4655 - val_loss: 64.7917 - val_mean_absolute_percentage_error: 64.7917
# Epoch 78/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.5404 - mean_absolute_percentage_error: 31.5404 - val_loss: 73.1922 - val_mean_absolute_percentage_error: 73.1922
# Epoch 79/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.2090 - mean_absolute_percentage_error: 37.2090 - val_loss: 66.1985 - val_mean_absolute_percentage_error: 66.1985
# Epoch 80/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.4257 - mean_absolute_percentage_error: 31.4257 - val_loss: 71.5911 - val_mean_absolute_percentage_error: 71.5911
# Epoch 81/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.2967 - mean_absolute_percentage_error: 30.2967 - val_loss: 73.9989 - val_mean_absolute_percentage_error: 73.9989
# Epoch 82/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.6318 - mean_absolute_percentage_error: 31.6318 - val_loss: 66.1657 - val_mean_absolute_percentage_error: 66.1657
# Epoch 83/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.0398 - mean_absolute_percentage_error: 32.0398 - val_loss: 68.7239 - val_mean_absolute_percentage_error: 68.7239
# Epoch 84/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 33.3703 - mean_absolute_percentage_error: 33.3703 - val_loss: 77.1933 - val_mean_absolute_percentage_error: 77.1933
# Epoch 85/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 34.1785 - mean_absolute_percentage_error: 34.1785 - val_loss: 73.7200 - val_mean_absolute_percentage_error: 73.7200
# Epoch 86/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 30.6187 - mean_absolute_percentage_error: 30.6187 - val_loss: 70.7480 - val_mean_absolute_percentage_error: 70.7480
# Epoch 87/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 29.6325 - mean_absolute_percentage_error: 29.6325 - val_loss: 71.0641 - val_mean_absolute_percentage_error: 71.0641
# Epoch 88/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 29.8111 - mean_absolute_percentage_error: 29.8111 - val_loss: 61.8545 - val_mean_absolute_percentage_error: 61.8545
# Epoch 89/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.8238 - mean_absolute_percentage_error: 31.8238 - val_loss: 69.2025 - val_mean_absolute_percentage_error: 69.2025
# Epoch 90/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 31.0542 - mean_absolute_percentage_error: 31.0542 - val_loss: 68.2716 - val_mean_absolute_percentage_error: 68.2716
# Epoch 91/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 38.6966 - mean_absolute_percentage_error: 38.6966 - val_loss: 75.9390 - val_mean_absolute_percentage_error: 75.9390
# Epoch 92/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 25.5742 - mean_absolute_percentage_error: 25.5742 - val_loss: 69.0483 - val_mean_absolute_percentage_error: 69.0483
# Epoch 93/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 40.7121 - mean_absolute_percentage_error: 40.7121 - val_loss: 72.3925 - val_mean_absolute_percentage_error: 72.3925
# Epoch 94/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 37.0415 - mean_absolute_percentage_error: 37.0415 - val_loss: 74.1093 - val_mean_absolute_percentage_error: 74.1093
# Epoch 95/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 41.0933 - mean_absolute_percentage_error: 41.0933 - val_loss: 69.2311 - val_mean_absolute_percentage_error: 69.2310
# Epoch 96/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.1136 - mean_absolute_percentage_error: 32.1136 - val_loss: 85.7241 - val_mean_absolute_percentage_error: 85.7241
# Epoch 97/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.7184 - mean_absolute_percentage_error: 32.7184 - val_loss: 66.9604 - val_mean_absolute_percentage_error: 66.9604
# Epoch 98/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 28.5874 - mean_absolute_percentage_error: 28.5874 - val_loss: 69.4377 - val_mean_absolute_percentage_error: 69.4377
# Epoch 99/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 32.1033 - mean_absolute_percentage_error: 32.1033 - val_loss: 72.6428 - val_mean_absolute_percentage_error: 72.6428
# Epoch 100/100
# 428/428 [==============================] - 1s 2ms/sample - loss: 25.5217 - mean_absolute_percentage_error: 25.5217 - val_loss: 67.6768 - val_mean_absolute_percentage_error: 67.6768
# 2024-01-24 02:24:44.239168: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_203/BiasAdd' id:29012 op device:{requested: '', assigned: ''} def:{{{node dense_203/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_203/MatMul, dense_203/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Predicting house prices - Estimation Error: 67.68%
# Time Elapsed: 29355.082978010178

# %%
model9.summary()
# Out:
# Model: "sequential_97"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_322 (Conv2D)         (None, 62, 62, 32)        896
#
#  max_pooling2d_217 (MaxPooli  (None, 31, 31, 32)       0
#  ng2D)
#
#  conv2d_323 (Conv2D)         (None, 29, 29, 64)        18496
#
#  max_pooling2d_218 (MaxPooli  (None, 14, 14, 64)       0
#  ng2D)
#
#  conv2d_324 (Conv2D)         (None, 12, 12, 128)       73856
#
#  max_pooling2d_219 (MaxPooli  (None, 6, 6, 128)        0
#  ng2D)
#
#  conv2d_325 (Conv2D)         (None, 4, 4, 256)         295168
#
#  max_pooling2d_220 (MaxPooli  (None, 2, 2, 256)        0
#  ng2D)
#
#  flatten_89 (Flatten)        (None, 1024)              0
#
#  dense_201 (Dense)           (None, 512)               524800
#
#  dense_202 (Dense)           (None, 256)               131328
#
#  dense_203 (Dense)           (None, 1)                 257
#
# =================================================================
# Total params: 1,044,801
# Trainable params: 1,044,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(12, 7))

# Plot mean absolute percentage error

# Plot loss
plt.plot(history9.history['loss'], label='Training Loss', color='green')
plt.plot(history9.history['val_loss'], label='Validation Loss', color='red')

plt.title('4 Layer All ELU')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0,175)
plt.legend()
plt.savefig('4 Layer All ELU.png')
plt.show()

#-----

# %% [markdown]
# The metric used in this problem to evaluate the performance is the same we used for training the model, the mean absolute percentage error. Mean absolute percentage error is defined as $\frac{100}{n} \sum_n \frac{|\hat{y} - y|}{|y|}$ where $y$ is the ground-truth, $\hat{y}$ is the estimation of the model and `n` the number of elements in the set we are evaluating.

# %% [markdown]
# **Report**:
#
#
# *   Propose a CNN architecture that has an estimation error in the validation set below 75%.
#   We want an estimation error close to zero.
# *   Present a figure showing the training and validation loss vs the number of training epochs for different architectural design choices. Discuss the gap between the training and validation loss depending on the proposed architecture.
# *   Report a table with results when using any of the other images from the house (kitchen, bedroom, and bathroom).
